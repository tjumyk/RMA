# %%
#!/usr/bin/python
import numpy as np
import scipy.sparse
import pickle
import xgboost as xgb
import csv
from collections import defaultdict
import redis
import json
import time
import sklearn.utils
### simple example
# load file from text file, also binary buffer generated by xgboost
# dtrain = xgb.DMatrix('./demo/rank_aida/mq2008.train')

# dtest = xgb.DMatrix('./demo/rank_aida/mq2008.test')
# Out:
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
conn = redis.Redis(password='unswkg', host='43.240.97.73', port=8379, decode_responses=True)

def get_feature_results(exp_id, d_t, data_source='aida_conll'):
    fea_res = conn.lrange('result:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t), 0, -1)
    fea_vecs = [json.loads(res) for res in fea_res]
    return fea_vecs

# %%
def get_dataset_info(exp_id, d_t, data_source='aida_conll', can_size=50):
    valid_mens_size = conn.scard('valid_qry_ids:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    no_g_can_info_size = conn.scard('no_g_candidate_info:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    missed_g_candidate_size = conn.scard('missed_g_candidate:::::' + str(exp_id) + ':::::' + data_source + 
                                         ':::::' + str(d_t) + ':::::' + str(can_size))
    no_candidate_size = conn.scard('no_candidate:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    return valid_mens_size, no_candidate_size, no_g_can_info_size, missed_g_candidate_size

# %%
def fetch_all_features(exp_id, data_type, data_source='aida_conll'):
    res_feas = get_feature_results(exp_id, data_type, data_source)
    res_feas_ids = [[res[0].strip('(').split(', ')[0]] + res[1:-1] + [res[-1]] for res in res_feas]
    res_feas_ids = np.array(res_feas_ids, dtype=np.float64)
    return res_feas_ids

# %%
def fetch_all_features_delete_max_prior(exp_id, data_type, data_source='aida_conll'):
    res_feas = get_feature_results(exp_id, data_type, data_source)
    res_feas_ids = [[res[0].strip('(').split(', ')[0]] + res[1:2] + [res[2] if res[2]!=0 else res[1]] + res[3:] for res in res_feas]
    res_feas_ids = np.array(res_feas_ids, dtype=np.float64)
    return res_feas_ids

# %%
def trans_data(data):
    d_np = data[:, 1:-1]
    print(d_np)
    d_labels = data[:, -1]
    print(d_labels)
    idxs = np.where(d_labels == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_labels)) - idxs
    print(d_groups)
    xgb_data = xgb.DMatrix(data=d_np, label=d_labels)
    xgb_data.set_group(d_groups)
    return xgb_data

# %%
def combine_features(original_feas, new_features):
    men_id_feas_dict = defaultdict(list)
    print("Building idx for new features...")
    for fea in new_features:
        men_id_feas_dict[fea[0]].append(fea)
    comb_feas = None
    pre_men_id = 0
    print("Combine original and new features...")
    for fea_idx, fea in enumerate(original_feas):
        if pre_men_id == fea[0]:
            continue
        else:
            pre_men_id = fea[0]
            fea_size = len(men_id_feas_dict[fea[0]])
            res = np.append(original_feas[fea_idx: fea_idx + fea_size, :-1], np.array(men_id_feas_dict[fea[0]])[:, 1:], axis=1)
            comb_feas = np.concatenate((comb_feas, res), axis=0) if comb_feas is not None else res
    return comb_feas

# %%
def evalerror(preds, dt, d_tal_size):
    d_l = dt.get_label()
    idxs = np.where(d_l == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_l)) - idxs
    matched_ids = []
    q_id = 0
    for x in d_groups:
        pre_res = preds[q_id: x + q_id]
        if(preds[q_id] == max(pre_res)):
            if len([x for x in pre_res if x == preds[q_id]]) == 1:
                matched_ids.append(q_id)
        q_id += x
    precision = float(len(matched_ids)) / len(d_groups)
    recall = float(len(matched_ids)) / d_tal_size
    f1 = 2 * precision * recall / (precision + recall)
    return len(matched_ids), precision, recall, f1

# %%
from collections import defaultdict
def evalerror_detail_log(preds, dt, d_tal_size):
    d_l = dt.get_label()
    idxs = np.where(d_l == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_l)) - idxs
    correct_results = {}
    wrong_results = {}
    duplicates_results = {}
    group_info = {}
    matched_ids = []
    q_id = 0
    for x in d_groups:
        pre_res = preds[q_id: x + q_id]
        if(preds[q_id] == max(pre_res)):
            correct_results[q_id] = pre_res
            if len([x for x in pre_res if x == preds[q_id]]) == 1:
                matched_ids.append(q_id)
            else:
                duplicates_results[q_id] = pre_res
        else:
            wrong_results[q_id] = pre_res
        q_id += x
    precision = float(len(matched_ids)) / len(d_groups)
    recall = float(len(matched_ids)) / d_tal_size
    f1 = 2 * precision * recall / (precision + recall)
    return len(matched_ids), precision, recall, f1, correct_results, wrong_results, duplicates_results

# %%
from collections import defaultdict
from ast import literal_eval
def get_groups_results(preds, dt, d_tal_size, res_features):
    d_l = dt.get_label()
    idxs = np.where(d_l == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_l)) - idxs
#     correct_results = {}
#     wrong_results = {}
#     duplicates_results = {}
#     group_info = {}
#     matched_ids = []
    correct_res_groups = []
    wrong_res_groups = []
    dup_res_groups = []
    q_id = 0
    for x in d_groups:
        pre_res = preds[q_id: x + q_id]
        pre_res_feas = res_features[q_id: x + q_id]
        pred_q_id, pred_ent = literal_eval(res_features[q_id+np.argmax(pre_res)][0])
        
        if(preds[q_id] == max(pre_res)):
            correct_res_groups.append([pred_q_id, pred_ent])
        else:
            wrong_res_groups.append([pred_q_id, pred_ent])
        q_id += x
#     precision = float(len(matched_ids)) / len(d_groups)
#     recall = float(len(matched_ids)) / d_tal_size
#     f1 = 2 * precision * recall / (precision + recall)
    return correct_res_groups, wrong_res_groups

# %%
valid_mens_size, no_candidate_size, no_g_can_info_size, missed_g_candidate_size = get_dataset_info('basic_feature_phrases_tf_idf_entropy_reduced_fea', 'test', 'wiki_uiuc')

# %%
d_train_ori = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'train', 'aida_conll')
d_test_a_ori = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'testa', 'aida_conll')

# %%
n_estimators = range(100, 5000, 400)
max_depth = [4, 6, 8, 10, 12]

# %%
for x in n_estimators:
    num_round = x
    for dep in max_depth:
        param = {'max_depth':dep, 'eta':0.01, 'silent':0, 'objective':'rank:pairwise', 'min_child_weight':0.01}
        bst = xgb.train(param, dtrain, num_round)
        preds = bst.predict(dtrain)
        a = evalerror(preds, dtrain, 18541)
        print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[0], a[1]))
        preds = bst.predict(dtest)
        a = evalerror(preds, dtest, 4485)
        print("n_estimators: {}, max_depth: {}, acc_testing: {}, corr_num: {}".format(num_round, dep, a[0], a[1]))
        print("---------------------------------")
# Out:
# n_estimators: 100, max_depth: 4, acc_training: 0.7711558168383582, corr_num: 14298
# n_estimators: 100, max_depth: 4, acc_testing: 0.7163879598662207, corr_num: 3213
# ---------------------------------
# n_estimators: 100, max_depth: 6, acc_training: 0.8203441022598565, corr_num: 15210
# n_estimators: 100, max_depth: 6, acc_testing: 0.7868450390189521, corr_num: 3529
# ---------------------------------
# n_estimators: 100, max_depth: 8, acc_training: 0.879564209050213, corr_num: 16308
# n_estimators: 100, max_depth: 8, acc_testing: 0.8133779264214047, corr_num: 3648
# ---------------------------------
# n_estimators: 100, max_depth: 10, acc_training: 0.9209859230893696, corr_num: 17076
# n_estimators: 100, max_depth: 10, acc_testing: 0.8251950947603122, corr_num: 3701
# ---------------------------------
# n_estimators: 500, max_depth: 4, acc_training: 0.8502238282724772, corr_num: 15764
# n_estimators: 500, max_depth: 4, acc_testing: 0.8013377926421404, corr_num: 3594
# ---------------------------------
# n_estimators: 500, max_depth: 6, acc_training: 0.8929399708753574, corr_num: 16556
# n_estimators: 500, max_depth: 6, acc_testing: 0.8401337792642141, corr_num: 3768
# ---------------------------------
# n_estimators: 500, max_depth: 8, acc_training: 0.9354403753842835, corr_num: 17344
# n_estimators: 500, max_depth: 8, acc_testing: 0.8479375696767001, corr_num: 3803
# ---------------------------------
# n_estimators: 500, max_depth: 10, acc_training: 0.9666684644841163, corr_num: 17923
# n_estimators: 500, max_depth: 10, acc_testing: 0.8416945373467113, corr_num: 3775
# ---------------------------------
# n_estimators: 900, max_depth: 4, acc_training: 0.8740089531308991, corr_num: 16205
# n_estimators: 900, max_depth: 4, acc_testing: 0.8323299888517279, corr_num: 3733
# ---------------------------------
# n_estimators: 900, max_depth: 6, acc_training: 0.9174262445391295, corr_num: 17010
# n_estimators: 900, max_depth: 6, acc_testing: 0.8552954292084727, corr_num: 3836
# ---------------------------------
# n_estimators: 900, max_depth: 8, acc_training: 0.960519928806429, corr_num: 17809
# n_estimators: 900, max_depth: 8, acc_testing: 0.862876254180602, corr_num: 3870
# ---------------------------------
# n_estimators: 900, max_depth: 10, acc_training: 0.9795048810743757, corr_num: 18161
# n_estimators: 900, max_depth: 10, acc_testing: 0.8564102564102564, corr_num: 3841
# ---------------------------------
# n_estimators: 1300, max_depth: 4, acc_training: 0.8929399708753574, corr_num: 16556
# n_estimators: 1300, max_depth: 4, acc_testing: 0.8535117056856187, corr_num: 3828
# ---------------------------------
# n_estimators: 1300, max_depth: 6, acc_training: 0.9357100480017259, corr_num: 17349
# n_estimators: 1300, max_depth: 6, acc_testing: 0.862876254180602, corr_num: 3870
# ---------------------------------
# n_estimators: 1300, max_depth: 8, acc_training: 0.9720619168329648, corr_num: 18023
# n_estimators: 1300, max_depth: 8, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 1300, max_depth: 10, acc_training: 0.9815004584434497, corr_num: 18198
# n_estimators: 1300, max_depth: 10, acc_testing: 0.8597547380156075, corr_num: 3856
# ---------------------------------
# n_estimators: 1700, max_depth: 4, acc_training: 0.8996817863114179, corr_num: 16681
# n_estimators: 1700, max_depth: 4, acc_testing: 0.8615384615384616, corr_num: 3864
# ---------------------------------
# n_estimators: 1700, max_depth: 6, acc_training: 0.9457418693705841, corr_num: 17535
# n_estimators: 1700, max_depth: 6, acc_testing: 0.869788182831661, corr_num: 3901
# ---------------------------------
# n_estimators: 1700, max_depth: 8, acc_training: 0.9771856965643708, corr_num: 18118
# n_estimators: 1700, max_depth: 8, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 1700, max_depth: 10, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 1700, max_depth: 10, acc_testing: 0.8617614269788183, corr_num: 3865
# ---------------------------------
# n_estimators: 2100, max_depth: 4, acc_training: 0.9047516315193356, corr_num: 16775
# n_estimators: 2100, max_depth: 4, acc_testing: 0.8633221850613155, corr_num: 3872
# ---------------------------------
# n_estimators: 2100, max_depth: 6, acc_training: 0.9528072919475756, corr_num: 17666
# n_estimators: 2100, max_depth: 6, acc_testing: 0.8740245261984393, corr_num: 3920
# ---------------------------------
# n_estimators: 2100, max_depth: 8, acc_training: 0.9790194703629793, corr_num: 18152
# n_estimators: 2100, max_depth: 8, acc_testing: 0.8724637681159421, corr_num: 3913
# ---------------------------------
# n_estimators: 2100, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2100, max_depth: 10, acc_testing: 0.8653288740245262, corr_num: 3881
# ---------------------------------
# n_estimators: 2500, max_depth: 4, acc_training: 0.9131654171835392, corr_num: 16931
# n_estimators: 2500, max_depth: 4, acc_testing: 0.8662207357859532, corr_num: 3885
# ---------------------------------
# n_estimators: 2500, max_depth: 6, acc_training: 0.9581468097729356, corr_num: 17765
# n_estimators: 2500, max_depth: 6, acc_testing: 0.8749163879598663, corr_num: 3924
# ---------------------------------
# n_estimators: 2500, max_depth: 8, acc_training: 0.9806375060676339, corr_num: 18182
# n_estimators: 2500, max_depth: 8, acc_testing: 0.8735785953177257, corr_num: 3918
# ---------------------------------
# n_estimators: 2500, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2500, max_depth: 10, acc_testing: 0.8655518394648829, corr_num: 3882
# ---------------------------------
# n_estimators: 2900, max_depth: 4, acc_training: 0.9192060838142495, corr_num: 17043
# n_estimators: 2900, max_depth: 4, acc_testing: 0.8691192865105909, corr_num: 3898
# ---------------------------------
# n_estimators: 2900, max_depth: 6, acc_training: 0.962299768081549, corr_num: 17842
# n_estimators: 2900, max_depth: 6, acc_testing: 0.8778149386845039, corr_num: 3937
# ---------------------------------
# n_estimators: 2900, max_depth: 8, acc_training: 0.9812307858260072, corr_num: 18193
# n_estimators: 2900, max_depth: 8, acc_testing: 0.8735785953177257, corr_num: 3918
# ---------------------------------
# n_estimators: 2900, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2900, max_depth: 10, acc_testing: 0.8651059085841695, corr_num: 3880
# ---------------------------------
# n_estimators: 3300, max_depth: 4, acc_training: 0.9238444528342592, corr_num: 17129
# n_estimators: 3300, max_depth: 4, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 3300, max_depth: 6, acc_training: 0.9659673156787659, corr_num: 17910
# n_estimators: 3300, max_depth: 6, acc_testing: 0.8784838350055741, corr_num: 3940
# ---------------------------------
# n_estimators: 3300, max_depth: 8, acc_training: 0.9815004584434497, corr_num: 18198
# n_estimators: 3300, max_depth: 8, acc_testing: 0.8722408026755852, corr_num: 3912
# ---------------------------------
# n_estimators: 3300, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 3300, max_depth: 10, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 3700, max_depth: 4, acc_training: 0.9272423278140338, corr_num: 17192
# n_estimators: 3700, max_depth: 4, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 3700, max_depth: 6, acc_training: 0.9683943692357478, corr_num: 17955
# n_estimators: 3700, max_depth: 6, acc_testing: 0.8791527313266444, corr_num: 3943
# ---------------------------------
# n_estimators: 3700, max_depth: 8, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 3700, max_depth: 8, acc_testing: 0.8711259754738016, corr_num: 3907
# ---------------------------------
# n_estimators: 3700, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 3700, max_depth: 10, acc_testing: 0.8675585284280937, corr_num: 3891
# ---------------------------------
# n_estimators: 4100, max_depth: 4, acc_training: 0.9311256135052047, corr_num: 17264
# n_estimators: 4100, max_depth: 4, acc_testing: 0.8740245261984393, corr_num: 3920
# ---------------------------------
# n_estimators: 4100, max_depth: 6, acc_training: 0.9709832263631951, corr_num: 18003
# n_estimators: 4100, max_depth: 6, acc_testing: 0.8804905239687848, corr_num: 3949
# ---------------------------------
# n_estimators: 4100, max_depth: 8, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 4100, max_depth: 8, acc_testing: 0.8709030100334448, corr_num: 3906
# ---------------------------------
# n_estimators: 4100, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4100, max_depth: 10, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 4500, max_depth: 4, acc_training: 0.9352246372903296, corr_num: 17340
# n_estimators: 4500, max_depth: 4, acc_testing: 0.8746934225195094, corr_num: 3923
# ---------------------------------
# n_estimators: 4500, max_depth: 6, acc_training: 0.972763065638315, corr_num: 18036
# n_estimators: 4500, max_depth: 6, acc_testing: 0.8793756967670011, corr_num: 3944
# ---------------------------------
# n_estimators: 4500, max_depth: 8, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4500, max_depth: 8, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 4500, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4500, max_depth: 10, acc_testing: 0.867335562987737, corr_num: 3890
# ---------------------------------
# n_estimators: 4900, max_depth: 4, acc_training: 0.9377595598942884, corr_num: 17387
# n_estimators: 4900, max_depth: 4, acc_testing: 0.8764771460423635, corr_num: 3931
# ---------------------------------
# n_estimators: 4900, max_depth: 6, acc_training: 0.9743811013429696, corr_num: 18066
# n_estimators: 4900, max_depth: 6, acc_testing: 0.8798216276477147, corr_num: 3946
# ---------------------------------
# n_estimators: 4900, max_depth: 8, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4900, max_depth: 8, acc_testing: 0.8711259754738016, corr_num: 3907
# ---------------------------------
# n_estimators: 4900, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4900, max_depth: 10, acc_testing: 0.8677814938684504, corr_num: 3892
# ---------------------------------

# %%
d_train_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'train', 'aida_conll')
d_test_a_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'testa', 'aida_conll')
d_test_b_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'testb', 'aida_conll')

# %%
# d_test_a_ori_sup = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new_sup', 'testa', 'aida_conll')
d_test_b_ori_sup = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new_sup', 'testb', 'aida_conll')

# %%
d_train_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'train', 'aida_conll')
d_test_a_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'testa', 'aida_conll')
d_test_b_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'testb', 'aida_conll')

# %%
# d_test_a_new_coref_sup = fetch_all_features('basic_feature_coref_smooth_sup', 'testa', 'aida_conll')
d_test_b_new_coref_sup = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50_sup', 'testb', 'aida_conll')

# %%
d_train_new_coref = fetch_all_features_delete_max_prior('basic_feature_coref_smooth', 'train', 'aida_conll')
d_test_a_new_coref = fetch_all_features_delete_max_prior('basic_feature_coref_smooth', 'testa', 'aida_conll')
d_test_b_new_coref = fetch_all_features_delete_max_prior('basic_feature_coref_smooth', 'testb', 'aida_conll')

# %%
d_test_a_ori_sup[0]
# Out:
# array([  3.94595000e+05,   2.50000000e-01,   2.00000000e+02,
#          2.50000000e-01,   4.23910687e-07,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   1.00000000e+00])

# %% [markdown]
# ### MSNBC_NEW

# %%
d_train_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'test', 'msnbc_new')
d_train_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'test', 'msnbc_new')
d_train_comb = combine_features(d_train_ori, d_train_new_coref)
# Out:
# Building idx for new features...
# Combine original and new features...

# %%
dtrain_xgboost = trans_data(d_train_comb)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 656)
        
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(4600, 9, a[2], a[0]))
# Out:
# [[  8.64742739e-01   8.64742739e-01   5.63000000e+02 ...,   1.00000000e+00
#     1.00000000e+00   1.00000000e+00]
#  [  1.50234086e-02   8.64742739e-01   5.63000000e+02 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.67004402e-02   8.64742739e-01   5.63000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  1.98581560e-03   2.01418440e-01   7.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.98581560e-03   2.01418440e-01   7.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.98581560e-03   2.01418440e-01   7.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# [ 1.  0.  0. ...,  0.  0.  0.]
# [50  2  9 50  2  1  4 50  1  2  4  2 50  2  2  4 50 50  3  2  1  1 27  2  1
#  50  4 50  2  9 50 50  1  3 50  4 50  2 50  1 50  1  9  1  1 50  1 50 50 50
#   2  2  4 10  1  8 50  1  2 50  2  4  2  1  4  4 27  4  4  2  1  2  4  4  2
#   3  1 38  1  1 50  3  1 50  4 10 12  3  1 23  2 33  4  1  4  1  9 50 50  8
#   2 50 50  3  4  1 50 50 12  1 17  1  3  1  1  2  4 11  2  2  2 50 50  8  9
#  50  3 24  1 50  2 50  1 14  7 50  1  4  3 12  3  2  4  9 50  2  4 12  9 50
#  50 23 50  5  3 50  6 50  3 50  1  3 50  4 50 11  9 50 11 28  6 11 50  2 50
#   9  1 50  1 38 50  2 50  2  1 42 23 50 50 50 50  1 27 16 50  3  2  1 35  4
#  50 50  2  6 50  1 50  1 50 50  5  9  3 50  3  2  8 50 50 29 35  3 50 50 35
#   2  1  7  2 10 16  1 12 50  2  8 50  4 31  7  1 50 35 50  1 50 50 50  1  1
#  50  1  8 50  8  1 50  6 50 50 50 50  1 50  1  7  1 50  1  1 50 50 11  5 50
#  50 33 50  1 50 50 10 50  1 50  5 50 50 50 50 50 10 50  9 10 50 50  1  1  2
#   1  1 50 50 19  4 38  1  8 50 50 15 50 50 50  3  2 50 50 50  1  1  3  1  9
#  16  1 10 24 50 50 50 50 50 50  1  1 50  9  1  6 10 46 50 50  1 24  1 50 50
#   7 34  1  1  4  2  4  1  1  1  1 15 40 24  9  4  3  2 11 34 50  4  4  4 11
#  23 50  2 28 50 50  5  5  6  1 12 12  1 50  3 13  9  1 50 15 46 50  2 50  1
#  50 48 50  6  3 50 50  1 28 50  7 50  1  9  2  2 35 50 50 50  1  2  1  1 50
#   1  7 50  8 50 50 50  2  1  1 50 10 50 50 50 50  1 32  1 35  1 50 32 44 50
#  50  2  1 23 15  7 28 50  9 50 15 35 50  1  2 17 50  1  1 50 33 50  2  2 50
#  50 50 50 13 11 50 50  1  1 12 14  3 50 50  2  2 50  1  1 50  1 50  1 11 23
#   4 11 50 46 50  5 11 50  6 50 50 50 50 50 20  5  1 23  1 14 23 50 13 50 15
#  14 11  2 12  5 50 50  1 13 50 12 12 17 50  4 12 50 11 50 12 32  1 15  1 27
#   1  1 50 44 23  6 50 50 50  8 50 50 40  3  1 50  3  3 50  9 12 13  2  6 50
#   1  6 50 38  1 50 50 50 35 50  1 11  1 13 50 50  2 50 27 50 50 50 46 50 50
#  50 50 15 17  8 15  1 13 50 13 50 50 16 50  2 50 23 12 23 26 13 11 12 50 43
#   1  1 50]
# n_estimators: 4600, max_depth: 9, acc_training: 0.885670731707317, corr_num: 581

# %% [markdown]
# ### AQU_NEW

# %%
d_train_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'test', 'aquaint_new')
d_train_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'test', 'aquaint_new')
d_train_comb = combine_features(d_train_ori, d_train_new_coref)
dtrain_xgboost = trans_data(d_train_comb)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 727)
        
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format
#  50  9 50  8 24 50  2 50  5 50 50  1 50 50  1 50  1  3 12 22  1 22  1 50  9
#   1 25 50 16  3 50 50  7 50  1  9 27 50  1 38  1 13 37  1 50 21 50 38  2 50
#   8 24  1 50 28  6 50 11  1 12 13 19 41 50  2 50 14  3 50 11 36 50  4  5 50
#  50 16  9  6  4  1  3  3 50 50 50 42 12  1 50 50 16  1  6 33 50 50  2  1 50
#  50  1]
# n_estimators: 4600, max_depth: 9, acc_training: 0.8376891334250344, corr_num: 609

# %% [markdown]
# ### ACE

# %%
d_train_ori = fetch_all_features('basic_context_emnlp17_spacy_sm_50_new', 'test', 'ace2014_uiuc')
d_train_new_coref = fetch_all_features('basic_features_coref_emnlp17_spacy_sm_50', 'test', 'ace2014_uiuc')
d_train_comb = combine_features(d_train_ori, d_train_new_coref)
dtrain_xgboost = trans_data(d_train_comb)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 257)
        
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(4600, 9, a[2], a[0]))
# Out:
# Building idx for new features...
# Combine original and new features...
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  9.96146435e-01   9.96146435e-01   2.00000000e+00 ...,   1.00000000e+00
#     1.00000000e+00   1.00000000e+00]
#  [  3.85356455e-03   9.96146435e-01   2.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  8.94934670e-04   6.28065151e-01   1.79000000e+02 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  7.15947736e-04   6.28065151e-01   1.79000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   6.28065151e-01   1.79000000e+02 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# [ 1.  1.  0. ...,  0.  0.  0.]
# [ 1  2  2  1  3  1  4 50  1 50  1 50  1  1  1 50 50 50 50 14  1  1  2  2 50
#  20 20  2  8  1  9 20 21  5  1  2 16  1  1  3 50  2  5  2 50 50 50 50 30  9
#   2 50 50 27  4 47  5 50 27  1  2 50 20 50 50 25 20 50 50 50 50 50 25 50 20
#  50 50 24 20 50 50 50 16  1 20 18  8  2 50 25 23 50 50  1 17 50 27  1 20  7
#  50 50 42 50 20 27  2 50 27 19  2  9 50  9 42 45 50 20 50 50 50 20  1 50  4
#   2 24  1 50 30 19 50 50  3 50 20  1 50 50 19 50  3  1 16 14 50  2  3  4 50
#   3 50 50 50 50  2  1 50  1 50 50 50 50 50 50 50  4  8 50 50 50 23 26 18  3
#  50 49  9 49 50 20 50 50 50 50 50 50 50 50 50 50  5  2 20 50 11 50 50 50 50
#   1  2  1 50 50 50 50  1 50 50 50 50  1 50  1 50 50 49 50 50 50  1  1 50  4
#  50 50 50 50 50 50]
# n_estimators: 4600, max_depth: 9, acc_training: 0.8132295719844358, corr_num: 209

# %%
d_train_comb = combine_features(d_train_ori, d_train_new_coref)
d_test_a_comb = combine_features(d_test_a_ori, d_test_a_new_coref)
d_test_b_comb = combine_features(d_test_b_ori, d_test_b_new_coref)
# Out:
# Building idx for new features...
# Combine original and new features...
# Building idx for new features...
# Combine original and new features...
# Building idx for new features...
# Combine original and new features...

# %%
# d_test_a_comb_sup = combine_features(d_test_a_ori_sup, d_test_a_new_coref_sup)
d_test_b_comb_sup = combine_features(d_test_b_ori_sup, d_test_b_new_coref_sup)
# Out:
# Building idx for new features...
# Combine original and new features...

# %%
dtrain_xgboost = trans_data(d_train_comb)
dtest_a_xgboost = trans_data(d_test_a_comb)
dtest_b_xgboost = trans_data(d_test_b_comb)
# Out:
# [[  6.42493639e-02   7.70356234e-01   2.70000000e+01 ...,   0.00000000e+00
#     1.00000000e+00   0.00000000e+00]
#  [  7.70356234e-01   7.70356234e-01   2.70000000e+01 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  4.45292621e-03   7.70356234e-01   2.70000000e+01 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  9.15667063e-05   9.66669719e-01   5.30000000e+01 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   9.66669719e-01   5.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   9.66669719e-01   5.30000000e+01 ...,   0.00000000e+00
#     1.00000000e+00   0.00000000e+00]]
# [ 1.  0.  0. ...,  0.  0.  0.]
# [22  1 50 ...,  9 25 38]
# [[ 0.99036145  0.99036145  4.         ...,  0.          0.          0.        ]
#  [ 0.          0.99036145  4.         ...,  0.          0.          0.        ]
#  [ 0.78378378  0.78378378  3.         ...,  1.          1.          1.        ]
#  ...,
#  [ 0.          0.25        7.         ...,  0.          1.          0.        ]
#  [ 0.          0.25        7.         ...,  0.          1.          0.        ]
#  [ 0.08333333  0.25        7.         ...,  0.          1.          0.        ]]
# [ 1.  0.  1. ...,  0.  0.  0.]
# [ 2  2  4 ...,  6 17  6]
# [[  9.81661273e-01   9.81661273e-01   1.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   9.81661273e-01   1.30000000e+01 ...,   0.00000000e+00
#     1.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   9.81661273e-01   1.30000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  4.76530855e-04   9.44245890e-01   7.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  9.99430199e-01   9.99430199e-01   2.00000000e+00 ...,   1.00000000e+00
#     1.00000000e+00   1.00000000e+00]
#  [  0.00000000e+00   9.99430199e-01   2.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# [ 1.  0.  0. ...,  0.  1.  0.]
# [10  1  3 ...,  9 14  2]

# %%
# dtest_a_xgboost_sup = trans_data(d_test_a_comb_sup)
dtest_b_xgboost_sup = trans_data(d_test_b_comb_sup)
# Out:
# [[  6.71836929e-01   6.71836929e-01   3.44000000e+02 ...,   1.00000000e+00
#     1.00000000e+00   1.00000000e+00]
#  [  1.85356867e-01   6.71836929e-01   3.44000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  2.41873180e-02   6.71836929e-01   3.44000000e+02 ...,   1.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  0.00000000e+00   3.09178744e-01   1.10000000e+01 ...,   0.00000000e+00
#     1.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   3.09178744e-01   1.10000000e+01 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   3.09178744e-01   1.10000000e+01 ...,   0.00000000e+00
#     1.00000000e+00   0.00000000e+00]]
# [ 1.  0.  0. ...,  0.  0.  0.]
# [50 50 50 50 50 50  4 50 50 50 50 50 50 50 50 14 50 50 50 50 50 50 50 50 50
#  50 50 50 50 50 50 50 50 50 14 50 50 50 50 50 50 50 50 50 50 50 50 50 50 50
#   5 50  7 50 50 50 50 50 49 49 50 49 50 50 50 50 50 50 50 50 50 50]

# %%
n_estimators = range(4500, 6000, 200)
max_depth = [4, 6]

# %%
for x in n_estimators:
    num_round = x
    for dep in max_depth:
        param = {'max_depth':dep, 'eta':0.01, 'silent':1, 'objective':'rank:pairwise', 'min_child_weight':0.01}
        bst = xgb.train(param, dtrain_xgboost, num_round)
        preds = bst.predict(dtrain_xgboost)
        a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
        print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        preds = bst.predict(dtest_a_xgboost)
        a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)
        
        print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        preds = bst.predict(dtest_b_xgboost)
        a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
        print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        print("---------------------------------")
# Out:
# n_estimators: 4500, max_depth: 4, acc_training: 0.9442317027129066, corr_num: 17507
# n_estimators: 4500, max_depth: 4, acc_validation: 0.8845752452515132, corr_num: 4238
# n_estimators: 4500, max_depth: 4, acc_test: 0.8662207357859532, corr_num: 3885
# ---------------------------------
# n_estimators: 4500, max_depth: 6, acc_training: 0.9721158513564533, corr_num: 18024
# n_estimators: 4500, max_depth: 6, acc_validation: 0.891880609476101, corr_num: 4273
# n_estimators: 4500, max_depth: 6, acc_test: 0.8644370122630992, corr_num: 3877
# ---------------------------------
# n_estimators: 4700, max_depth: 4, acc_training: 0.9455261312766302, corr_num: 17531
# n_estimators: 4700, max_depth: 4, acc_validation: 0.8841577958672511, corr_num: 4236
# n_estimators: 4700, max_depth: 4, acc_test: 0.8662207357859532, corr_num: 3885
# ---------------------------------
# n_estimators: 4700, max_depth: 6, acc_training: 0.972763065638315, corr_num: 18036
# n_estimators: 4700, max_depth: 6, acc_validation: 0.8920893341682321, corr_num: 4274
# n_estimators: 4700, max_depth: 6, acc_test: 0.8648829431438128, corr_num: 3879
# ---------------------------------
# n_estimators: 4900, max_depth: 4, acc_training: 0.9467126907933768, corr_num: 17553
# n_estimators: 4900, max_depth: 4, acc_validation: 0.8847839699436444, corr_num: 4239
# n_estimators: 4900, max_depth: 4, acc_test: 0.8677814938684504, corr_num: 3892
# ---------------------------------
# n_estimators: 4900, max_depth: 6, acc_training: 0.973194541826223, corr_num: 18044
# n_estimators: 4900, max_depth: 6, acc_validation: 0.8925067835524942, corr_num: 4276
# n_estimators: 4900, max_depth: 6, acc_test: 0.8648829431438128, corr_num: 3879
# ---------------------------------
# n_estimators: 5100, max_depth: 4, acc_training: 0.9474677741222156, corr_num: 17567
# n_estimators: 5100, max_depth: 4, acc_validation: 0.886662492172824, corr_num: 4248
# n_estimators: 5100, max_depth: 4, acc_test: 0.8677814938684504, corr_num: 3892
# ---------------------------------
# n_estimators: 5100, max_depth: 6, acc_training: 0.9734642144436654, corr_num: 18049
# n_estimators: 5100, max_depth: 6, acc_validation: 0.8927155082446253, corr_num: 4277
# n_estimators: 5100, max_depth: 6, acc_test: 0.8642140468227425, corr_num: 3876
# ---------------------------------
# n_estimators: 5300, max_depth: 4, acc_training: 0.9485464645919853, corr_num: 17587
# n_estimators: 5300, max_depth: 4, acc_validation: 0.886662492172824, corr_num: 4248
# n_estimators: 5300, max_depth: 4, acc_test: 0.867335562987737, corr_num: 3890
# ---------------------------------
# n_estimators: 5300, max_depth: 6, acc_training: 0.9740574942020387, corr_num: 18060
# n_estimators: 5300, max_depth: 6, acc_validation: 0.8935504070131497, corr_num: 4281
# n_estimators: 5300, max_depth: 6, acc_test: 0.8653288740245262, corr_num: 3881
# ---------------------------------
# n_estimators: 5500, max_depth: 4, acc_training: 0.9490318753033817, corr_num: 17596
# n_estimators: 5500, max_depth: 4, acc_validation: 0.8860363180964308, corr_num: 4245
# n_estimators: 5500, max_depth: 4, acc_test: 0.8659977703455964, corr_num: 3884
# ---------------------------------
# n_estimators: 5500, max_depth: 6, acc_training: 0.9744350358664581, corr_num: 18067
# n_estimators: 5500, max_depth: 6, acc_validation: 0.8929242329367564, corr_num: 4278
# n_estimators: 5500, max_depth: 6, acc_test: 0.8646599777034559, corr_num: 3878
# ---------------------------------
# n_estimators: 5700, max_depth: 4, acc_training: 0.9496790895852435, corr_num: 17608
# n_estimators: 5700, max_depth: 4, acc_validation: 0.8868712168649551, corr_num: 4249
# n_estimators: 5700, max_depth: 4, acc_test: 0.8671125975473801, corr_num: 3889
# ---------------------------------
# n_estimators: 5700, max_depth: 6, acc_training: 0.9744350358664581, corr_num: 18067
# n_estimators: 5700, max_depth: 6, acc_validation: 0.8931329576288874, corr_num: 4279
# n_estimators: 5700, max_depth: 6, acc_test: 0.8648829431438128, corr_num: 3879
# ---------------------------------
# n_estimators: 5900, max_depth: 4, acc_training: 0.951189256242921, corr_num: 17636
# n_estimators: 5900, max_depth: 4, acc_validation: 0.8874973909413484, corr_num: 4252
# n_estimators: 5900, max_depth: 4, acc_test: 0.8675585284280937, corr_num: 3891
# ---------------------------------
# n_estimators: 5900, max_depth: 6, acc_training: 0.974758643007389, corr_num: 18073
# n_estimators: 5900, max_depth: 6, acc_validation: 0.8933416823210186, corr_num: 4280
# n_estimators: 5900, max_depth: 6, acc_test: 0.8653288740245262, corr_num: 3881
# ---------------------------------

# %%
for x in n_estimators:
    num_round = x
    for dep in max_depth:
        param = {'max_depth':dep, 'eta':0.01, 'silent':1, 'objective':'rank:pairwise', 'min_child_weight':0.01, 'nthread': 1, 'tree_method': 'gpu_exact'}
        bst = xgb.train(param, dtrain_xgboost, num_round)
        preds = bst.predict(dtrain_xgboost)
        a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
        print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        preds = bst.predict(dtest_a_xgboost)
        a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)
        
        print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        preds = bst.predict(dtest_b_xgboost)
        a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
        print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
        print("---------------------------------")

# %%
num_round = 5300
dep = 6
param = {'max_depth':dep, 'eta':0.01, 'silent':1, 'objective':'rank:pairwise', 'min_child_weight':0.01}
bst = xgb.train(param, dtrain_xgboost, num_round)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_a_xgboost)
a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_b_xgboost)
a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_training: 0.973194541826223, corr_num: 18044
# n_estimators: 4900, max_depth: 6, acc_validation: 0.8925067835524942, corr_num: 4276
# n_estimators: 4900, max_depth: 6, acc_test: 0.8648829431438128, corr_num: 3879

# %%
num_round = 4900
dep = 6
param = {'max_depth':dep, 'eta':0.01, 'silent':1, 'objective':'rank:pairwise', 'min_child_weight':0.01}
bst = xgb.train(param, dtrain_xgboost, num_round)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_a_xgboost)
a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_b_xgboost)
a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_training: 0.9778868453697211, corr_num: 18131
# n_estimators: 4900, max_depth: 6, acc_validation: 0.9018993946983929, corr_num: 4321
# n_estimators: 4900, max_depth: 6, acc_test: 0.8909698996655518, corr_num: 3996

# %%
num_round = 4900
dep = 6
param = {'max_depth':dep, 'eta':0.01, 'silent':1, 'objective':'rank:pairwise', 'min_child_weight':0.01}
bst = xgb.train(param, dtrain_xgboost, num_round)
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_a_xgboost)
a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_b_xgboost)
a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_training: 0.9778868453697211, corr_num: 18131
# n_estimators: 4900, max_depth: 6, acc_validation: 0.9010644959298685, corr_num: 4317
# n_estimators: 4900, max_depth: 6, acc_test: 0.8916387959866221, corr_num: 3999

# %% [markdown]
# ### Save Model

# %%
model_name = './4900_6_coref_new_emnlp17.mdl'
with open(model_name, 'wb') as f:
    pickle.dump(bst, f)
model = pickle.load(open(model_name, 'rb'))

# %% [markdown]
# ### Load Model

# %%
model_name = './4900_6_coref_new_emnlp17.mdl'
# with open(model_name, 'wb') as f:
#     pickle.dump(bst, f)
bst = pickle.load(open(model_name, 'rb'))

# %%
bst = model
num_round = 4900
dep = 6
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_a_xgboost)
a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
preds = bst.predict(dtest_b_xgboost)
a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-de2226feb465> in <module>()
#       2 preds = bst.predict(dtrain_xgboost)
#       3 a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
# ----> 4 print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
#       5 preds = bst.predict(dtest_a_xgboost)
#       6 a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)
#
# NameError: name 'num_round' is not defined

# %%
preds = bst.predict(dtrain_xgboost)
a = evalerror_detail_log(preds, dtrain_xgboost, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_training: 0.973194541826223, corr_num: 18044

# %%
preds = bst.predict(dtest_a_xgboost)
a = evalerror_detail_log(preds, dtest_a_xgboost, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_validation: 0.8925067835524942, corr_num: 4276

# %%
preds = bst.predict(dtest_b_xgboost)
a = evalerror_detail_log(preds, dtest_b_xgboost, 4485)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_test: 0.8648829431438128, corr_num: 3879

# %%
preds = model.predict(dtest_b_xgboost_sup)
a = evalerror_detail_log(preds, dtest_b_xgboost_sup, 72)
print("n_estimators: {}, max_depth: {}, acc_test: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_test: 0.4166666666666667, corr_num: 30

# %%
preds = bst.predict(dtest_a_xgboost_sup)
a = evalerror_detail_log(preds, dtest_a_xgboost_sup, 4791)

print("n_estimators: {}, max_depth: {}, acc_validation: {}, corr_num: {}".format(num_round, dep, a[2], a[0]))
# Out:
# n_estimators: 4900, max_depth: 6, acc_validation: 0.00459194322688374, corr_num: 22

# %%
correct_results, wrong_results, duplicates_results = a[4:]

# %%
a = defaultdict(int)
for key, val in correct_results.items():
    if len(val) > 1:
        sec_min_val, max_val = np.partition(val.flatten(), -2)[-2:]
        a[np.around(max_val - sec_min_val)] += 1
    else:
        a[-1] += 1

# %%
wrong_results
# Out:
# {1817: array([ 3.46489286,  5.94406986, -2.15280509, -1.62277627, -3.74623871,
#         -3.45709157, -0.81793737, -0.17089349, -7.06788254, -2.24846005,
#         -6.54027748, -5.44907999, -5.52147865, -3.80868721, -8.48096561,
#         -3.02596974, -4.20868683, -5.9231863 , -7.33772373, -6.77054358,
#         -5.15116453, -4.84742975, -2.09021401, -3.14463091, -7.04716349,
#         -6.78057384, -6.34314919, -3.88976622, -5.48023224, -1.77633905,
#         -6.01265097, -5.74459934, -7.10257101, -4.7161088 , -3.90336609,
#         -4.75348091, -3.62490845, -7.20770931, -6.8720088 , -6.79844809,
#         -5.46988392, -6.09507847, -6.52263021, -5.51145744, -6.46151447,
#         -4.47971916, -4.40637875, -5.90191555, -3.74564075, -3.97176743], dtype=float32),
#  2303: array([-0.29991245,  3.24367809,  6.95483208,  0.14999327, -3.93358278,
#         -3.5220871 , -1.72681236, -2.48062563, -3.72181034, -3.50116205,
#         -9.11799812, -5.23912621, -7.08251953, -3.49358535, -2.21721101,
#         -4.60701799, -5.9740243 , -5.0534873 , -4.38098717, -7.05800867,
#         -7.58811092, -4.09232378, -6.48317146, -6.08311844, -5.09167385,
#         -7.47498751, -4.13060379, -6.52899599, -6.93339539, -7.34493589,
#         -4.29677486, -6.3858366 , -7.45193481, -2.96735406, -7.21849489,
#         -3.36329913, -6.7900629 , -6.65160704, -6.04894066, -7.60348511,
#         -7.47960424, -3.75927019, -7.65503979, -6.08848238, -6.05215454,
#         -5.26996946, -3.3359108 , -0.18924588, -7.21473742, -6.85783339], dtype=float32),
#         -8.57613277, -6.47275257, -6.805089  , -6.20671749, -8.97943497,
#         -9.38128757, -8.54324913, -8.98441029, -6.11874628, -8.22570705,
#         -9.35320377, -9.54915333, -9.31011009, -7.08964205, -7.7356472 ,
#         -7.00038099, -7.61148167, -7.33570385, -8.04695797, -8.28173733,
#         -8.10041046, -9.20954132, -6.87279272, -9.16660404, -7.23382092], dtype=float32),
#  113744: array([-0.78211164,  0.80772054, -2.1579752 , -0.32238102, -0.60097754,
#         -2.80446458,  0.05794194, -7.56037045, -5.99346685, -7.27715302,
#         -4.20375204, -1.24597859, -6.23052597, -4.01978159, -7.41804934,
#         -4.03339863, -3.15880013, -6.07858753, -6.43470764, -6.28138065,
#         -6.29201126, -5.49974537, -5.69601107, -6.97950411, -6.20066977,
#         -4.05934   , -7.18475533, -6.13118792, -7.2432456 , -5.5829854 ,
#         -6.02586937, -7.76556873, -5.82785606, -7.82229614, -6.83069944,
#         -6.95493793, -6.18561363, -6.13505268, -6.56788111, -5.96647263,
#         -5.2383256 , -6.52919245, -8.05663109, -8.04608059, -6.00761127,
#         -8.39158535, -6.69223261, -6.99512672, -3.83000755, -4.59338665], dtype=float32)}

# %%
sec_count = 0
pos_g_ent_dict = defaultdict(int)
b = defaultdict(int)
for key, val in wrong_results.items():
    if len(val) > 1:
        predicted_g_val = val[0]
        sec_min_val, max_val = np.partition(val.flatten(), -2)[-2:]
        r_sorted_arr = np.sort(val)[::-1]
#         print(val)
#         print(r_sorted_arr)
#         print(predicted_g_val)
        pos_g_ent_dict[np.where(r_sorted_arr==predicted_g_val)[0][0] + 1] += 1
        if sec_min_val == predicted_g_val:
            sec_count += 1
            b[np.round(max_val - sec_min_val)] += 1
    else:
        b[-1] += 1

# %%
b, sec_count, pos_g_ent_dict
# Out:
# (defaultdict(int,
#              {0.0: 93, 1.0: 95, 2.0: 59, 3.0: 40, 4.0: 20, 5.0: 10, 6.0: 8}),
#  325,
#  defaultdict(int,
#              {2: 325,
#               3: 84,
#               4: 44,
#               5: 15,
#               6: 9,
#               7: 1,
#               8: 5,
#               9: 9,
#               11: 3,
#               12: 2,
#               13: 1,
#               15: 1,
#               20: 1}))

# %%
res_feas_train = get_feature_results('basic_context_emnlp17_spacy_sm_50_new', 'train', 'aida_conll')

# %%
correct_res_groups_train, wrong_res_groups_train = get_groups_results(preds, dtrain_xgboost, 4485, res_feas_train)
res_groups_train = correct_res_groups_train + wrong_res_groups_train

# %%
res_feas = get_feature_results('basic_context_emnlp17_spacy_sm_50_new', 'testb', 'aida_conll')

# %%
res_feas_testa = get_feature_results('basic_context_emnlp17_spacy_sm_50_new', 'testa', 'aida_conll')
correct_res_groups_testa, wrong_res_groups_teata = get_groups_results(preds, dtest_a_xgboost, 4485, res_feas_testa)
res_groups_testa = wrong_res_groups_teata + correct_res_groups_testa

# %%
res_feas_testa_sup = get_feature_results('basic_context_emnlp17_spacy_sm_50_new', 'testa', 'aida_conll')
correct_res_groups_testa_sup, wrong_res_groups_testa_sup = get_groups_results(preds, dtest_a_xgboost_sup, 4485, res_feas_testa_sup)
res_groups_testa_sup = correct_res_groups_testa_sup + wrong_res_groups_testa_sup

# %%
res_feas_sup = get_feature_results('basic_context_emnlp17_spacy_sm_50_new_sup', 'testb', 'aida_conll')

# %%
res_feas_sup = get_feature_results('basic_feature_phrases_tf_idf_entropy_conll_new_sup', 'testb', 'aida_conll')

# %%
correct_res_groups_sup, wrong_res_groups_sup = get_groups_results(preds, dtest_b_xgboost_sup, 4485, res_feas_sup)

# %%
correct_res_groups, wrong_res_groups = get_groups_results(preds, dtest_b_xgboost, 4485, res_feas)

# %%
res_groups = wrong_res_groups + correct_res_groups

# %%
len(res_groups), len(wrong_res_groups), len(correct_res_groups)
# Out:
# (4413, 529, 3884)

# %%
len(res_groups_train), len(wrong_res_groups_teata), len(correct_res_groups_testa)
# Out:
# (18289, 417, 4282)

# %%
res_groups_sup = wrong_res_groups_sup + correct_res_groups_sup

# %%
len(res_groups_testa_sup), len(wrong_res_groups_sup), len(correct_res_groups_sup)
# Out:
# (63, 27, 12)

# %%
res_groups_all = res_groups_sup + res_groups

# %%
res_groups_all_testa = res_groups_testa_sup + res_groups_testa

# %%
res_groups_all[1]
# Out:
# [402624, 'Doug_Young_(politician)']

# %%
b,
# Out:
# defaultdict(int,
#             {0.0: 93, 1.0: 95, 2.0: 59, 3.0: 40, 4.0: 20, 5.0: 10, 6.0: 8})

# %%
a = np.array([[1,2,3], [3,4,5]])
b = preds

# %%
b = [[x] for x in b]

# %%
b
# Out:
# [[7.6260376],
#  [-2.5330014],
#  [-0.30230969],
#  [-4.5123949],
#  [-2.0348978],
#  [-4.8573437],
#  [-6.1133637],
#  [-4.5007944],
#  [-6.5985532],
#  [-3.9538832],
#  [-7.1643362],
#  [-6.4183216],
#  [-6.5762491],
#  [-7.4794302],
#  [-8.6036835],
#  [-0.82126439],
#  [-6.3083239],
#  [-2.5340505],
#  [-8.4449863],
#  [-8.0378199],
#  [-6.0816531],
#  [-7.5646687],
#  [0.25881904],
#  [-0.72283721],
#  [-5.4358535],
#  [-6.6092129],
#  [-6.0309629],
#  [-7.3560228],
#  [-5.6431432],
#  [-3.9456396],
#  [-7.7461538],
#  [-7.0247436],
#  [-7.4351721],
#  [-6.6617227],
#  [-7.0173063],
#  [-7.0897193],
#  [-6.4403439],
#  [-8.0451384],
#  [-7.1473503],
#  [-7.8827915],
#  [-7.5456095],
#  [-6.4282899],
#  [-9.3209114],
#  [-6.7522607],
#  [-7.7339535],
#  [-5.4057603],
#  [-7.419415],
#  [-6.0206695],
#  [-5.6320443],
#  [-1.8580008],
#  [-2.4665985],
#  [-2.3149827],
#  [-2.4665985],
#  [7.6260376],
#  [-2.5330014],
#  [-0.30230969],
#  [-4.5123949],
#  [-2.0348978],
#  [-4.8573437],
#  [-6.1133637],
#  [-4.5007944],
#  [-6.5985532],
#  [-3.9538832],
#  [-7.1643362],
#  [-6.4183216],
#  [-6.5762491],
#  [-7.4794302],
#  [-8.6036835],
#  [-0.82126439],
#  [-6.3083239],
#  [-2.5340505],
#  [-8.4449863],
#  [-8.6558027],
#  [-9.064312],
#  [-8.6329899],
#  [-8.3701744],
#  [-9.1909809],
#  [-9.1353407],
#  [-9.4841061],
#  [6.7752595],
#  [-4.8357887],
#  [-1.6393535],
#  [-2.8100142],
#  [-2.6009552],
#  [-3.7579446],
#  [-5.5848794],
#  [-3.0272095],
#  [-4.4774365],
#  [-3.2943034],
#  [-6.1708198],
#  [-7.9263887],
#  [-2.41327],
#  [-5.217535],
#  [-5.6704402],
#  [-8.0781422],
#  [-5.4913745],
#  [-5.6635785],
#  [-7.2787929],
#  [-9.9867964],
#  [-8.2833862],
#  [-4.2332592],
#  [-9.8949852],
#  [-9.306284],
#  [-9.8206987],
#  [-5.8666029],
#  [-6.9059711],
#  [-5.6238403],
#  [-5.6593657],
#  [-5.7363381],
#  [-3.85817],
#  [-1.1821294],
#  [-4.7974668],
#  [-10.265555],
#  [-2.2846291],
#  [-6.9008613],
#  [-7.7247572],
#  [-9.836297],
#  [-7.5036335],
#  [-6.75633],
#  [-6.9806004],
#  [-6.0471325],
#  [-8.9233351],
#  [-2.9370399],
#  [-6.9451904],
#  [-3.9177012],
#  [-5.5256019],
#  [-5.6128373],
#  [-5.6463928],
#  [-4.4056664],
#  [-3.7631516],
#  [0.68658525],
#  [-3.8702211],
#  [-7.4280705],
#  [-7.0282092],
#  [-5.6862974],
#  [-0.0188815],
#  [-5.6315885],
#  [-5.8058271],
#  [-5.2327447],
#  [-6.3932233],
#  [-8.0794325],
#  [-7.719595],
#  [-8.20156],
#  [-8.5460358],
#  ...]

# %%
res = np.append(res_feas, b, axis=1)

# %%
fea_id = res[0][0].strip('(').split(', ')
query_id, ent = fea_id

# %%
print(query_id, ent)
# Out:
# 403215 'Japan')

# %%
def get_men_ents_tokens_idf_redis(men):
    ent_tok_dict = conn.hmget('idf:::50', men)[0]
    return json.loads(ent_tok_dict) if ent_tok_dict else {}

def get_men_ents_tokens_entropy_redis(men):
    ent_tok_dict = conn.hmget('entropy:::50', men)[0]
    return json.loads(ent_tok_dict) if ent_tok_dict else {}

def get_men_ents_tokens_tf_redis(men):
    ent_tok_dict = conn.hmget('tf:::50', men)[0]
    return json.loads(ent_tok_dict) if ent_tok_dict else {}

def get_men_tokens_redis(data_source, doc_id):
    if data_source == 'aida_conll':
        data_source = 'conll'
    tokens = conn.hmget('men-tok-ner-spacy-' + data_source, doc_id)[0]
    return json.loads(tokens) if tokens else {}

# %%
import psycopg2
conn_psql = psycopg2.connect(database='zding', user='zding', password='dingzishuo', host='43.240.96.216',
                                     port=5432)

# %%
def fetch_mention_by_q_id(q_id):
    cur = conn_psql.cursor()
    sql = "SELECT aida_conll.surfaceform, aida_conll.doc_id FROM aida_conll WHERE aida_conll.id=%s AND annotation != 'NIL';"
    cur.execute(sql % q_id)
    row = cur.fetchone()
    cur.close()
    return row

# %%
def fetch_mention_ent_by_q_id(q_id):
    cur = conn_psql.cursor()
    sql = "SELECT aida_conll.surfaceform, aida_conll.annotation, aida_conll.doc_id FROM aida_conll WHERE aida_conll.id=%s AND annotation != 'NIL';"
    cur.execute(sql % q_id)
    row = cur.fetchone()
    cur.close()
    return row

def fetch_mention_count_by_doc_id(q_id):
    cur = conn_psql.cursor()
    sql = "SELECT count(*) FROM aida_conll WHERE aida_conll.doc_id=%s AND annotation != 'NIL';"
    cur.execute(sql , (q_id,))
    row = cur.fetchone()
    cur.close()
    return row

def fetch_ents_by_doc_id(q_id):
    cur = conn_psql.cursor()
    sql = "SELECT annotation FROM aida_conll WHERE aida_conll.doc_id=%s AND annotation != 'NIL';"
    cur.execute(sql , (q_id,))
    row = cur.fetchall()
    cur.close()
    return row

def fetch_men_ents_by_doc_id(q_id):
    cur = conn_psql.cursor()
    sql = "SELECT id, annotation FROM aida_conll WHERE aida_conll.doc_id=%s AND annotation != 'NIL';"
    cur.execute(sql ,(q_id,))
    row = cur.fetchall()
    cur.close()
    return row

def fetch_q_ids_docs():
    cur = conn_psql.cursor()
    sql = "SELECT id, doc_id FROM aida_conll WHERE annotation != 'NIL';"
    cur.execute(sql)
    row = cur.fetchall()
    cur.close()
    return row

# %%
def fetch_ent_cates_by_ent_id(q_id):
    q_id = 'http://en.wikipedia.org/wiki/' + q_id
    cur = conn_psql.cursor()
    sql = "SELECT labels FROM dbpedia_ontology WHERE wikipedia_url=%s;"
    cur.execute(sql, (q_id,))
    row = cur.fetchone()
    cur.close()
    return row

# %%
def fetch_doc_ids_by_data_type(data_type):
    cur = conn_psql.cursor()
    sql = "SELECT distinct aida_conll.doc_id FROM aida_conll WHERE aida_conll.type=\'%s\';"
    cur.execute(sql % data_type)
    rows = cur.fetchall()
    cur.close()
    return rows

# %%
# men, doc_id = fetch_mention_by_q_id(404048)
# ent_tok_idf = get_men_ents_tokens_idf_redis(men)
# a = get_men_tokens_redis('aida_conll', doc_id)
# fetch_mention_count_by_doc_id('1190 NFL')[0]
# b = fetch_ent_cates_by_ent_id('Indonesia_national_football_team')
# "sports team" in b[0]
# doc_ids = [x[0] for x in fetch_doc_ids_by_data_type('testb')]
q_docs_dict = dict(fetch_q_ids_docs())

# %%
print(q_docs_dict[403215])
# Out:
# 1270 Japan

# %%
res_groups_train[1]
# Out:
# [385458, 'Harry_Decheiver']

# %%
from collections import defaultdict
doc_id_q_ent_lists_dict = defaultdict(list)

for q_ent in res_groups_all:
    doc_id_q_ent_lists_dict[q_docs_dict[q_ent[0]]].append(q_ent)
#     print(q_ent[0])
#     print(q_docs_dict[q_ent[0]])
#     break

# %%
for key, vals in doc_id_q_ent_lists_dict.items():
    print("Saving doc " + key)
    conn.hset('doc-predicted-ents-coref-new', key, json.dumps(vals))
# Out:
# Saving doc 1271 Lebanon
# Saving doc 1241 Multinational
# Saving doc 1190 NFL
# Saving doc 1210 SQUASH
# Saving doc 1365 RUGBY
# Saving doc 1191 NFL
# Saving doc 1253 Russia
# Saving doc 1168 CRICKET
# Saving doc 1369 SOCCER
# Saving doc 1327 Court
# Saving doc 1366 SOCCER
# Saving doc 1330 NZ
# Saving doc 1343 Ahold
# Saving doc 1383 NBA
# Saving doc 1372 SOCCER
# Saving doc 1353 BOBSLEIGH-SHIMER
# Saving doc 1178 CRICKET
# Saving doc 1310 U.S.
# Saving doc 1312 Cyberspace
# Saving doc 1270 Japan
# Saving doc 1370 SOCCER
# Saving doc 1199 SOCCER
# Saving doc 1373 SOCCER
# Saving doc 1368 SOCCER
# Saving doc 1349 ALPINE
# Saving doc 1251 Russia
# Saving doc 1182 CRICKET
# Saving doc 1228 RTRS
# Saving doc 1263 Chile
# Saving doc 1177 CRICKET
# Saving doc 1163 SOCCER
# Saving doc 1183 CRICKET
# Saving doc 1165 SOCCER
# Saving doc 1378 CRICKET
# Saving doc 1179 CRICKET
# Saving doc 1180 CRICKET
# Saving doc 1344 ALPINE
# Saving doc 1302 Two
# Saving doc 1267 Burmese
# Saving doc 1166 FREESTYLE
# Saving doc 1227 Electronic
# Saving doc 1278 Man
# Saving doc 1304 Turkey
# Saving doc 1305 Three
# Saving doc 1356 CRICKET
# Saving doc 1374 RUGBY
# Saving doc 1351 NORDIC
# Saving doc 1173 RUGBY
# Saving doc 1170 SOCCER
# Saving doc 1289 Spain
# Saving doc 1352 ALPINE
# Saving doc 1306 Texas
# Saving doc 1201 SOCCER
# Saving doc 1379 CRICKET
# Saving doc 1214 RADIO
# Saving doc 1375 RUGBY
# Saving doc 1209 BASKETBALL
# Saving doc 1347 GOLF
# Saving doc 1348 ALPINE
# Saving doc 1167 SOCCER
# Saving doc 1172 BASKETBALL
# Saving doc 1229 Cricket
# Saving doc 1354 SKIING-CHINESE
# Saving doc 1206 SOCCER
# Saving doc 1222 Woman
# Saving doc 1300 OPEC
# Saving doc 1355 BOBSLEIGH-WORLD
# Saving doc 1376 GOLF
# Saving doc 1361 ALPINE
# Saving doc 1211 SQUASH
# Saving doc 1326 British
# Saving doc 1175 SOCCER
# Saving doc 1272 Texas
# Saving doc 1358 SKI
# Saving doc 1189 NBA
# Saving doc 1380 SOCCER
# Saving doc 1238 Wall
# Saving doc 1290 Mussolini
# Saving doc 1301 Relations
# Saving doc 1239 Russ
# Saving doc 1377 SOCCER
# Saving doc 1362 SOCCER
# Saving doc 1212 GUNMEN
# Saving doc 1246 Five
# Saving doc 1381 SOCCER
# Saving doc 1285 Half
# Saving doc 1382 SOCCER
# Saving doc 1261 Mexican
# Saving doc 1250 Polish
# Saving doc 1303 PLO
# Saving doc 1360 SPEED
# Saving doc 1234 Clean
# Saving doc 1181 CRICKET
# Saving doc 1367 RUGBY
# Saving doc 1164 RUGBY
# Saving doc 1207 GUNMEN
# Saving doc 1204 SOCCER
# Saving doc 1391 SOCCER
# Saving doc 1185 SOCCER
# Saving doc 1315 Italian
# Saving doc 1186 NHL
# Saving doc 1392 SOCCER
# Saving doc 1384 NBA
# Saving doc 1264 Indonesia
# Saving doc 1226 Major
# Saving doc 1256 Bomb
# Saving doc 1216 POLAND
# Saving doc 1331 RTRS
# Saving doc 1205 SOCCER
# Saving doc 1208 SOCCER
# Saving doc 1235 Dirty
# Saving doc 1316 Denmark
# Saving doc 1317 Moslem
# Saving doc 1294 Hindu
# Saving doc 1217 INTERVIEW-ZYWIEC
# Saving doc 1318 Belgian
# Saving doc 1322 EU
# Saving doc 1323 Frankfurt
# Saving doc 1187 NHL
# Saving doc 1324 John
# Saving doc 1266 Government
# Saving doc 1297 London
# Saving doc 1385 NHL
# Saving doc 1393 SOCCER
# Saving doc 1386 NHL
# Saving doc 1188 NFL
# Saving doc 1192 NCAA
# Saving doc 1333 Thai
# Saving doc 1277 Iowa-S
# Saving doc 1245 Ex-minister
# Saving doc 1325 Timah
# Saving doc 1288 Four
# Saving doc 1194 SOCCER
# Saving doc 1345 ALPINE
# Saving doc 1169 SOCCER
# Saving doc 1313 Italy
# Saving doc 1341 FEATURE
# Saving doc 1299 Italy
# Saving doc 1252 Estonian
# Saving doc 1259 Plastic
# Saving doc 1279 Canadian
# Saving doc 1364 SOCCER
# Saving doc 1371 SOCCER
# Saving doc 1387 NHL
# Saving doc 1280 NYMEX
# Saving doc 1195 SOCCER
# Saving doc 1346 ALPINE
# Saving doc 1268 Union
# Saving doc 1196 SOCCER
# Saving doc 1218 HAVEL
# Saving doc 1342 Japan
# Saving doc 1171 SOCCER
# Saving doc 1197 SOCCER
# Saving doc 1281 U.S.
# Saving doc 1219 UK-US
# Saving doc 1215 CZECH
# Saving doc 1307 Kansas
# Saving doc 1220 Tambang
# Saving doc 1309 ACCESS
# Saving doc 1282 CBOT
# Saving doc 1221 Telkom
# Saving doc 1174 GOLF
# Saving doc 1198 SOCCER
# Saving doc 1357 FREESTYLE
# Saving doc 1254 Yeltsin
# Saving doc 1260 Daily
# Saving doc 1350 ALPINE
# Saving doc 1230 Manitoba
# Saving doc 1202 SOCCER
# Saving doc 1283 Clinton
# Saving doc 1284 Action
# Saving doc 1334 Chinese
# Saving doc 1273 USDA
# Saving doc 1269 Indian
# Saving doc 1335 South
# Saving doc 1336 Foreign
# Saving doc 1255 Bomb
# Saving doc 1203 SOCCER
# Saving doc 1176 SOCCER
# Saving doc 1291 German
# Saving doc 1274 BALANCE
# Saving doc 1240 Zimbabwe
# Saving doc 1223 Britain
# Saving doc 1363 SOCCER
# Saving doc 1337 EPA
# Saving doc 1359 BADMINTON
# Saving doc 1247 WEATHER
# Saving doc 1248 Skinheads
# Saving doc 1338 Sangetsu
# Saving doc 1339 Bre-X
# Saving doc 1231 Canadian
# Saving doc 1314 Third
# Saving doc 1249 Albanian
# Saving doc 1184 BADMINTON
# Saving doc 1286 Iowa-S
# Saving doc 1340 Honda
# Saving doc 1311 School
# Saving doc 1275 14
# Saving doc 1232 New
# Saving doc 1287 Nebraska
# Saving doc 1242 Mauritius
# Saving doc 1233 New
# Saving doc 1243 U.N.
# Saving doc 1328 Australian
# Saving doc 1213 HAVEL
# Saving doc 1388 BOXING
# Saving doc 1244 Senegal
# Saving doc 1200 TENNIS
# Saving doc 1389 SOCCER
# Saving doc 1329 NZ
# Saving doc 1390 SOCCER
# Saving doc 1262 Brazil
# Saving doc 1224 Med
# Saving doc 1292 Italy
# Saving doc 1293 EU
# Saving doc 1225 New
# Saving doc 1276 New
# Saving doc 1257 Hungary
# Saving doc 1258 Mexico
# Saving doc 1332 Burmese
# Saving doc 1236 NYC
# Saving doc 1319 Port
# Saving doc 1320 German
# Saving doc 1237 USDA
# Saving doc 1321 Munich
# Saving doc 1265 China
# Saving doc 1295 Indian
# Saving doc 1296 LUXEMBOURG
# Saving doc 1298 UK
# Saving doc 1193 SOCCER

# %%
lists_doc = json.loads(conn.hget('doc-predicted-ents-coref-new', '1188 NFL'))

# %%
lists_doc
# Out:
# [[401370, 'Indianapolis_Colts'],
#  [401381, 'Kansas_City_Royals'],
#  [401382, 'Cincinnati_Reds'],
#  [401384, 'Philadelphia_Eagles'],
#  [401389, 'Philadelphia_Eagles'],
#  [401368, 'National_Football_League'],
#  [401369, 'Philadelphia_Eagles'],
#  [401371, 'Indianapolis_Colts'],
#  [401372, 'Philadelphia_Eagles'],
#  [401373, 'Marshall_Faulk'],
#  [401374, 'Jason_Belser'],
#  [401375, 'Indianapolis_Colts'],
#  [401376, 'Philadelphia_Eagles'],
#  [401377, 'Paul_Justin'],
#  [401378, 'Jim_Harbaugh'],
#  [401379, 'Indianapolis_Colts'],
#  [401380, 'Indianapolis_Colts'],
#  [401383, 'Philadelphia_Eagles'],
#  [401385, 'Dallas_Cowboys'],
#  [401386, 'Washington_Redskins'],
#  [401387, 'New_York_Jets'],
#  [401388, 'Arizona'],
#  [401390, 'Green_Bay_Packers'],
#  [401391, 'Indianapolis_Colts'],
#  [401392, 'Tony_Siragusa'],
#  [401393, 'Ray_Buchanan'],
#  [401394, 'Quentin_Coryatt'],
#  [401395, 'Marshall_Faulk'],
#  [401396, 'Paul_Justin'],
#  [401397, 'Jim_Harbaugh'],
#  [401398, 'Paul_Justin'],
#  [401399, 'Kerwin_Bell'],
#  [401400, 'Miami_Dolphins'],
#  [401401, 'National_Football_League'],
#  [401402, 'Marvin_Harrison'],
#  [401403, 'Philadelphia_Eagles'],
#  [401404, 'Troy_Vincent'],
#  [401405, 'Marshall_Faulk'],
#  [401406, 'Philadelphia_Eagles'],
#  [401407, 'Ty_Detmer'],
#  [401408, 'Ricky_Watters']]

# %%
from ast import literal_eval
import os
import re
for key, val in wrong_results.items():
    q_id = literal_eval(res[key][0])[0]
    if not os.path.exists(os.path.join('./tmp_result_plus_coref', str(q_id))):
        os.makedirs(os.path.join('./tmp_result_plus_coref', str(q_id)))
    men, doc_id = fetch_mention_by_q_id(q_id)
    ent_tok_idf = get_men_ents_tokens_idf_redis(men)
    ent_tok_tf = get_men_ents_tokens_tf_redis(men)
    ent_tok_entropy = get_men_ents_tokens_entropy_redis(men)
    men_toks_idx = get_men_tokens_redis('aida_conll', doc_id)
    try:
#         ent_escaped = re.sub(r'[\'\"–\/Žşáí-ţ]', '_', ent)
        with open(os.path.join('./tmp_result_plus_coref', str(q_id), 'mention_' + men + '.csv'), 'w', encoding='utf-8') as f:
            csv_wtr = csv.writer(f)
            csv_wtr.writerow(["token", "tf"])
            for tok, idxs in men_toks_idx.items():
                 csv_wtr.writerow([tok, len(idxs)])
    except:
        print(men)
    for ent, tok_idfs in ent_tok_idf.items():
        try:
            ent_escaped = re.sub(r'[\'\"–\/Žşáí-ţ]', '_', ent)
            with open(os.path.join('./tmp_result_plus_coref', str(q_id), ent_escaped + '.csv'), 'w', encoding='utf-8') as f:
                csv_wtr = csv.writer(f)
                csv_wtr.writerow(["token", "tf", "idf", "entropy"])
                for tok, idf in tok_idfs.items():
                     csv_wtr.writerow([tok, ent_tok_tf[ent][tok], idf, ent_tok_entropy[ent][tok]])
        except:
            print(ent)
#     break
#     print(literal_eval(res[key][0])[0])

# %%
from ast import literal_eval
import os
import re
for key, val in wrong_results.items():
    q_id = literal_eval(res[key][0])[0]
    if not os.path.exists(os.path.join('./tmp_result_plus_coref', str(q_id))):
        os.makedirs(os.path.join('./tmp_result_plus_coref', str(q_id)))
    men, doc_id = fetch_mention_by_q_id(q_id)
    ent_tok_idf = get_men_ents_tokens_idf_redis(men)
    ent_tok_tf = get_men_ents_tokens_tf_redis(men)
    ent_tok_entropy = get_men_ents_tokens_entropy_redis(men)
    men_toks_idx = get_men_tokens_redis('aida_conll', doc_id)
#     print(men_toks_idx)
    try:
        with open(os.path.join('./tmp_result_plus_coref', str(q_id), 'men_ent_common_toks.csv'), 'w', encoding='utf-8') as f:
            csv_wtr = csv.writer(f)
            csv_wtr.writerow(["token"] + list(ent_tok_idf.keys()))
#             print(men_toks_idx.items())
            for tok, idxs in men_toks_idx.items():
                csv_wtr.writerow([tok] + [' '.join([str(ent_tok_tf[ent].get(tok, ''))[:6], str(ent_tok_idf[ent].get(tok, ''))[:5], str(ent_tok_entropy[ent].get(tok,''))[:5]]) for ent in ent_tok_idf.keys()])
    except:
        print(men)

# %%
import csv

# %%
with open("correct_features_score_new_coref.csv", 'w', encoding='utf-8') as f:
    csv_writer = csv.writer(f)
    for key, val in correct_results.items():
        new_queries = []
        tmp_ori_res = res[key: key+len(val)]
        tmp_new_res = d_test_b_comb[key: key+len(val)]
#         print(len(tmp_ori_res))
#         print(float(tmp_new_res[0][1]))
#         print(float(tmp_ori_res[0][1]))
        if float(tmp_new_res[0][1]) != float(tmp_ori_res[0][1]):
            print(tmp_new_res[0][1])
            print(tmp_ori_res[0][1])
            print("ERROR@!")
            break
        for new_query_id, new_query in enumerate(tmp_ori_res):
#             print(type(list(new_query[:1])))
#             print(list(tmp_new_res[new_query_id])[1:])
#             print(new_query[-1:])
            query = list(new_query[:1]) + list(tmp_new_res[new_query_id][1:]) + list(new_query[-1:])
            new_queries.append(query)
        csv_writer.writerows(new_queries)
#         break

# %%
with open("wrong_features_score_new_coref.csv", 'a', encoding='utf-8') as f:
    csv_writer = csv.writer(f)
    for key, val in wrong_results.items():
        new_queries = []
        tmp_ori_res = res[key: key+len(val)]
        tmp_new_res = d_test_b_comb[key: key+len(val)]
#         print(len(tmp_ori_res))
#         print(float(tmp_new_res[0][1]))
#         print(float(tmp_ori_res[0][1]))
        if float(tmp_new_res[0][1]) != float(tmp_ori_res[0][1]):
            print(tmp_new_res[0][1])
            print(tmp_ori_res[0][1])
            print("ERROR@!")
            break
        for new_query_id, new_query in enumerate(tmp_ori_res):
#             print(type(list(new_query[:1])))
#             print(list(tmp_new_res[new_query_id])[1:])
#             print(new_query[-1:])
            query = list(new_query[:1]) + list(tmp_new_res[new_query_id][1:]) + list(new_query[-1:])
            new_queries.append(query)
        csv_writer.writerows(new_queries)

# %%
correct_results

# %%
from xgboost import plot_importance
from matplotlib import pyplot

# %%
plot_importance(model, importance_type='cover', title='Feature Importance - cover')
pyplot.show()
plot_importance(model, importance_type='weight', title='Feature Importance - weight')
pyplot.show()
plot_importance(model, importance_type='gain', title='Feature Importance - gain')
pyplot.show()

# %%
plot_importance(model, importance_type='cover', title='Feature Importance - cover')
pyplot.show()
plot_importance(model, importance_type='weight', title='Feature Importance - weight')
pyplot.show()
plot_importance(model, importance_type='gain', title='Feature Importance - gain')
pyplot.show()

# %%
import pickle
from xgboost import plot_tree
model_name = './no_poly_4900_6.mdl'
# with open(model_name, 'wb') as f:
#     pickle.dump(model, f)
model = pickle.load(open(model_name, 'rb'))
# plot_tree(model, num_trees=0)

# %%
from xgboost import plot_importance
from matplotlib import pyplot
from graphviz import Digraph

# %%
# from xgboost import plot_tree
# import matplotlib.pyplot as plt
from matplotlib import pyplot
# import pydot
# plt.figure(figsize=(20,15))
# xgb.plot_tree(model)
# plt.show()
# from matplotlib.pylab import rcParams
# xgb.plot_tree(model, num_trees=2)
##set up the parameters
# rcParams['figure.figsize'] = 10,5
# xgb.to_graphviz(model, num_trees=0)
plot_tree(model)
pyplot.show()
# xgb.to_graphviz(model, num_trees=0, rankdir='LR')
# Out:
# Format: "png" not recognized. Use one of: canon cmap cmapx cmapx_np dot dot_json eps fig gv imap imap_np ismap json json0 mp pic plain plain-ext pov ps ps2 svg svgz tk vml vmlz xdot xdot1.2 xdot1.4 xdot_json
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-240239c95fc5> in <module>()
#      11 # rcParams['figure.figsize'] = 10,5
#      12 # xgb.to_graphviz(model, num_trees=0)
# ---> 13 plot_tree(model)
#      14 pyplot.show()
#      15 # xgb.to_graphviz(model, num_trees=0, rankdir='LR')
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/site-packages/xgboost/plotting.py in plot_tree(booster, num_trees, rankdir, ax, **kwargs)
#     246
#     247     s = BytesIO()
# --> 248     s.write(g.pipe(format='png'))
#     249     s.seek(0)
#     250     img = image.imread(s)
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/site-packages/graphviz/files.py in pipe(self, format)
#     122         data = text_type(self.source).encode(self._encoding)
#     123
# --> 124         outs = backend.pipe(self._engine, format, data)
#     125
#     126         return outs
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/site-packages/graphviz/backend.py in pipe(engine, format, data, quiet)
#     164             stderr_write_binary(errs)
#     165             sys.stderr.flush()
# --> 166         raise subprocess.CalledProcessError(proc.returncode, args, output=outs)
#     167
#     168     return outs
#
# CalledProcessError: Command '['dot', '-Tpng']' returned non-zero exit status 1.

# %%
from ast import literal_eval
import os
import re

doc_err_dict = defaultdict(list)
doc_err_ids_dict = defaultdict(list)
doc_men_cnt_dict = defaultdict(int)
doc_g_ent_rank_dict = defaultdict(int)
doc_teams_all_dict = defaultdict(list)
doc_teams_errors_dict = defaultdict(list)
doc_men_ent_dict = defaultdict(dict)

def escape_entity(entity):
    return str.encode(entity).decode('unicode-escape')

for key, val in wrong_results.items():
    
    q_id = literal_eval(res[key][0])[0]
    predicted_g_val = val[0]
    r_sorted_arr = np.sort(val)[::-1]
    g_ent_rank = np.where(r_sorted_arr==predicted_g_val)[0][0] + 1
#     men, doc_id = fetch_mention_by_q_id(q_id)
    men, g_ent, doc_id = fetch_mention_ent_by_q_id(q_id)
    
    if doc_id not in doc_men_ent_dict:
        for x in doc_ids:
            doc_men_ent_dict[x] = dict(fetch_men_ents_by_doc_id(x))
            for men_id, ent in doc_men_ent_dict[x].items():
                ent_labels = fetch_ent_cates_by_ent_id(escape_entity(ent))
                if ent_labels and "sports team" in ent_labels[0]:
                    doc_teams_all_dict[x].append(men_id)
    
    if doc_id not in doc_men_cnt_dict:
        doc_men_cnt_dict[doc_id] = fetch_mention_count_by_doc_id(doc_id)[0]
    
    
    pred_ent = literal_eval(res[key+np.argmax(val)][0])[1]
    
    doc_err_ids_dict[doc_id].append(q_id)
    
    if q_id in doc_teams_all_dict[doc_id]:
        doc_teams_errors_dict[doc_id].append(q_id)
        
    doc_err_dict[doc_id].append(str(q_id)+ ': ' + men + '->' + escape_entity(g_ent) + '->' + str(g_ent_rank) + '->' + escape_entity(pred_ent))
    if men.isupper():
        print(men, doc_id)
# Out:
# JAPAN 1163 SOCCER
# CHINA 1163 SOCCER
# OAKLAND 1239 Russ
# PHOENIX 1385 NHL
# BOSTON 1385 NHL
# CHICAGO 1385 NHL
# LPGA 1347 GOLF
# MONTREAL 1385 NHL
# TORONTO 1385 NHL
# VANCOUVER 1186 NHL
# PITTSBURGH 1385 NHL
# LOS ANGELES 1186 NHL
# ASIAN CUP 1382 SOCCER
# WEST INDIES 1180 CRICKET
# MONTREAL 1186 NHL
# EDS 1227 Electronic
# MELBOURNE 1180 CRICKET
# CHICAGO 1186 NHL
# FSA 1274 BALANCE
# PHILADELPHIA 1186 NHL
# ITALY 1164 RUGBY
# DALLAS 1186 NHL
# RTRS 1331 RTRS
# OTTAWA 1186 NHL
# CHICAGO 1386 NHL
# ATLANTIC 1383 NBA
# NLD 1267 Burmese
# NLD 1267 Burmese
# NEW YORK 1383 NBA
# WORLD GRAND PRIX 1359 BADMINTON
# EUROLEAGUE 1209 BASKETBALL
# DES MOINES 1277 Iowa-S
# WASHINGTON 1383 NBA
# BOSTON 1187 NHL
# PHILADELPHIA 1383 NBA
# NORTHERN IRELAND 1364 SOCCER
# NEW JERSEY 1383 NBA
# JAPAN 1165 SOCCER
# LEEDS 1171 SOCCER
# BOSTON 1383 NBA
# CENTRAL DIVISION 1383 NBA
# SYRIA 1165 SOCCER
# CHICAGO 1383 NBA
# AUSTRALIA 1375 RUGBY
# DETROIT 1383 NBA
# BARBARIANS 1375 RUGBY
# SAN DIEGO 1190 NFL
# BUFFALO 1190 NFL
# SAN FRANCISCO 1190 NFL
# MINNESOTA 1190 NFL
# DETROIT 1190 NFL
# KANSAS CITY 1190 NFL
# OAKLAND 1190 NFL
# NEW YORK 1191 NFL

# %%
from ast import literal_eval
import os
import re

doc_err_dict = defaultdict(list)
doc_men_cnt_dict = defaultdict(int)
doc_g_ent_rank_dict = defaultdict(int)

def escape_entity(entity):
    return str.encode(entity).decode('unicode-escape')

for key, val in wrong_results.items():
    
    q_id = literal_eval(res[key][0])[0]
    predicted_g_val = val[0]
#     sec_min_val, max_val = np.partition(val.flatten(), -2)[-2:]
    r_sorted_arr = np.sort(val)[::-1]
    g_ent_rank = np.where(r_sorted_arr==predicted_g_val)[0][0] + 1
#     res[key+len(val)]
    men, doc_id = fetch_mention_by_q_id(q_id)
    if doc_id not in doc_men_cnt_dict:
        doc_men_cnt_dict[doc_id] = fetch_mention_count_by_doc_id(doc_id)[0]
    men, ent, doc_id = fetch_mention_ent_by_q_id(q_id)
    pred_ent = literal_eval(res[key+np.argmax(val)][0])[1]
    doc_err_dict[doc_id].append(str(q_id)+ ': ' + men + '->' + escape_entity(ent) + '->' + str(g_ent_rank) + '->' + escape_entity(pred_ent))
    if men.isupper():
        print(men, doc_id)
# Out:
# JAPAN 1163 SOCCER
# CHINA 1163 SOCCER
# OAKLAND 1239 Russ
# BOSTON 1385 NHL
# BUFFALO 1385 NHL
# WASHINGTON 1385 NHL
# CHICAGO 1385 NHL
# LPGA 1347 GOLF
# MONTREAL 1385 NHL
# TORONTO 1385 NHL
# VANCOUVER 1186 NHL
# PITTSBURGH 1385 NHL
# MELBOURNE 1179 CRICKET
# BUFFALO 1186 NHL
# MONTREAL 1186 NHL
# AUSTRALIA 1180 CRICKET
# EDS 1227 Electronic
# CHICAGO 1186 NHL
# CUTTITTA 1164 RUGBY
# FSA 1274 BALANCE
# PHILADELPHIA 1186 NHL
# ITALY 1164 RUGBY
# DALLAS 1186 NHL
# HOBART 1181 CRICKET
# RTRS 1331 RTRS
# OTTAWA 1186 NHL
# CHICAGO 1386 NHL
# ATLANTIC 1383 NBA
# NLD 1267 Burmese
# NLD 1267 Burmese
# NEW YORK 1383 NBA
# BOSTON 1187 NHL
# PHILADELPHIA 1383 NBA
# NORTHERN IRELAND 1364 SOCCER
# NEW JERSEY 1383 NBA
# JAPAN 1165 SOCCER
# LEEDS 1171 SOCCER
# CENTRAL DIVISION 1383 NBA
# SYRIA 1165 SOCCER
# CHICAGO 1383 NBA
# AUSTRALIA 1375 RUGBY
# DETROIT 1383 NBA
# BARBARIANS 1375 RUGBY
# LOS ANGELES 1187 NHL
# CLEVELAND 1383 NBA
# ATLANTA 1383 NBA
# INDIANA 1383 NBA
# INDIANAPOLIS 1188 NFL
# EUROLEAGUE 1172 BASKETBALL
# WORLD CUP 1205 SOCCER
# HOUSTON 1383 NBA
# MINNESOTA 1383 NBA
# NEW YORK 1232 New
# VANCOUVER 1383 NBA
# SEATTLE 1383 NBA
# WASHINGTON 1190 NFL
# DALLAS 1190 NFL
# BUFFALO 1190 NFL
# SAN FRANCISCO 1190 NFL
# MINNESOTA 1190 NFL
# DETROIT 1190 NFL
# KANSAS CITY 1190 NFL
# OAKLAND 1190 NFL
# NEW YORK 1191 NFL

# %%
total_sports = 0
total_err_sports = 0
total_correct_sports = 0
for doc_id, mens in doc_err_dict.items():
    print('Doc ID: ' + doc_id)
    print('Total errors: ' + str(len(mens)) + '    total mentions: ' + str(doc_men_cnt_dict[doc_id]))
    total_sports += len(doc_teams_all_dict[doc_id])
    total_err_sports += len(doc_teams_errors_dict[doc_id])
    print('Total errors (sports teams): ' + str(len(doc_teams_errors_dict[doc_id])) + '    total mentions (sports teams):' + str(len(doc_teams_all_dict[doc_id])))
    print('All Errors mentions:\n{}'.format('\n'.join(mens)))
    print('Correct Mentions (sports teams):')
    correct_teams = [x for x in doc_teams_all_dict[doc_id] if x not in doc_teams_errors_dict[doc_id]]
    for q_id in correct_teams:
        total_correct_sports +=1
        men, ent, doc_id = fetch_mention_ent_by_q_id(q_id)
        print(str(q_id) + ": " + men + '->' + escape_entity(ent))
    print('\n')
# Out:
# Doc ID: 1163 SOCCER
# Total errors: 22    total mentions: 38
# Total errors (sports teams): 15    total mentions (sports teams):19
# All Errors mentions:
# 400495: JAPAN->Japan_national_football_team->2->Japan
# 400496: CHINA->China_PR_national_football_team->5->People's_Republic_of_China
# 400500: Japan->Japan_national_football_team->2->Japan
# 400501: Asian Cup->1996_AFC_Asian_Cup->4->2007_AFC_Asian_Cup
# 400502: Syria->Syria_national_football_team->2->Syria
# 400503: China->China_PR_national_football_team->5->People's_Republic_of_China
# 400505: China->China_PR_national_football_team->5->People's_Republic_of_China
# 400506: Uzbek->Uzbekistan_national_football_team->2->Uzbekistan
# 400511: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 400512: Asian Games->1994_Asian_Games->8->Asian_Games
# 400514: Japan->Japan_national_football_team->2->Japan
# 400515: Syria->Syria_national_football_team->2->Syria
# 400518: Syrian->Syria_national_football_team->2->Syria
# 400520: Syria->Syria_national_football_team->2->Syria
# 400524: Syria->Syria_national_football_team->2->Syria
# 400525: Japan->Japan_national_football_team->2->Japan
# 400526: Syrian->Syria_national_football_team->2->Syria
# 400527: Syrian->Syria_national_football_team->2->Syria
# 400529: Japan->Japan_national_football_team->2->Japan
# 400531: Syrian->Syria_national_football_team->2->Syria
# 400538: South Korea->Korea_Republic_national_football_team->3->South_Korea
# 400539: Indonesia->Indonesia_national_football_team->2->Indonesia
# Correct Mentions (sports teams):
# 400504: Uzbekistan->Uzbekistan_national_football_team
# 400513: Uzbekistan->Uzbekistan_national_football_team
# 400536: UAE->United_Arab_Emirates_national_football_team
# 400537: Kuwait->Kuwait_national_football_team
#
#
# Doc ID: 1251 Russia
# Total errors: 1    total mentions: 14
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402821: Krasnoyarsk->Krasnoyarsk_Krai->2->Krasnoyarsk
# Correct Mentions (sports teams):
#
#
# Doc ID: 1357 FREESTYLE
# Total errors: 1    total mentions: 34
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404895: World Cup->FIS_Freestyle_Skiing_World_Cup->2->1998_FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1380 SOCCER
# Total errors: 12    total mentions: 26
# Total errors (sports teams): 6    total mentions (sports teams):6
# All Errors mentions:
# 405720: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405721: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 405722: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405723: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405724: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405725: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 405727: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405734: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405737: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405739: Kuwait->Kuwait_national_football_team->2->Kuwait
# 405744: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405757: South Korea->Korea_Republic_national_football_team->2->South_Korea
# Correct Mentions (sports teams):
#
#
# Doc ID: 1326 British
# Total errors: 2    total mentions: 26
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404069: European->European_Union->2->Europe
# 404071: Cabinet->Cabinet_(government)->2->Canadian_Cabinet
# Correct Mentions (sports teams):
#
#
# Doc ID: 1239 Russ
# Total errors: 1    total mentions: 3
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402592: OAKLAND->Oakland,_New_Jersey->7->Oakland,_California
# Correct Mentions (sports teams):
#
#
# Doc ID: 1263 Chile
# Total errors: 1    total mentions: 13
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403010: Finance->Ministry_of_Finance_(Chile)->5->Financial_services
# Correct Mentions (sports teams):
#
#
# Doc ID: 1385 NHL
# Total errors: 16    total mentions: 51
# Total errors (sports teams): 13    total mentions (sports teams):37
# All Errors mentions:
# 405933: PHOENIX->Phoenix_Coyotes->2->Phoenix_Suns
# 405936: BOSTON->Boston_Bruins->3->Boston_Red_Sox
# 405941: CHICAGO->Chicago_Blackhawks->4->Chicago_White_Sox
# 405942: MONTREAL->Montreal_Canadiens->3->Montreal
# 405944: TORONTO->Toronto_Maple_Leafs->3->Toronto
# 405946: PITTSBURGH->Pittsburgh_Penguins->2->Pittsburgh_Pirates
# 405905: HARTFORD->Hartford_Wolf_Pack->2->Hartford_Whalers
# 405907: MONTREAL->Montreal_Canadiens->3->Montreal
# 405908: BOSTON->Boston_Bruins->3->Boston_Red_Sox
# 405909: PITTSBURGH->Pittsburgh_Penguins->2->Pittsburgh_Pirates
# 405911: ATLANTIC->Atlantic_Division_(NHL)->2->Atlantic_Records
# 405913: PHILADELPHIA->Philadelphia_Flyers->2->Philadelphia_Eagles
# 405919: DETROIT->Detroit_Red_Wings->2->Detroit_Tigers
# 405922: CHICAGO->Chicago_Blackhawks->4->Chicago_White_Sox
# 405923: TORONTO->Toronto_Maple_Leafs->3->Toronto
# 405924: PHOENIX->Phoenix_Coyotes->2->Phoenix_Suns
# Correct Mentions (sports teams):
# 405906: BUFFALO->Buffalo_Sabres
# 405910: OTTAWA->Ottawa_Senators
# 405912: FLORIDA->Florida_Panthers
# 405914: NEW JERSEY->New_Jersey_Devils
# 405915: WASHINGTON->Washington_Capitals
# 405916: NY RANGERS->New_York_Rangers
# 405918: TAMPA BAY->Tampa_Bay_Lightning
# 405920: DALLAS->Dallas_Stars
# 405926: COLORADO->Colorado_Avalanche
# 405927: VANCOUVER->Vancouver_Canucks
# 405928: EDMONTON->Edmonton_Oilers
# 405931: ANAHEIM->Anaheim_Ducks
# 405932: CALGARY->Calgary_Flames
# 405934: NEW JERSEY->New_Jersey_Devils
# 405935: CALGARY->Calgary_Flames
# 405937: BUFFALO->Buffalo_Sabres
# 405938: HARTFORD->Hartford_Whalers
# 405939: WASHINGTON->Washington_Capitals
# 405943: NY RANGERS->New_York_Rangers
# 405945: ANAHEIM->Anaheim_Ducks
# 405947: COLORADO->Colorado_Avalanche
# 405949: TAMPA BAY->Tampa_Bay_Lightning
# 405951: OTTAWA->Ottawa_Senators
# 405952: VANCOUVER->Vancouver_Canucks
#
#
# Doc ID: 1168 CRICKET
# Total errors: 6    total mentions: 54
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 400705: Pakistan->Pakistan->2->Pakistan_national_cricket_team
# 400707: New Zealand->New_Zealand_national_cricket_team->2->New_Zealand
# 400714: Vaughan->Justin_Vaughan->15->Michael_Vaughan
# 400735: Vaughan->Justin_Vaughan->15->Michael_Vaughan
# 400738: New Zealand->New_Zealand_national_cricket_team->2->New_Zealand
# 400702: NEW ZEALAND->New_Zealand_national_cricket_team->2->New_Zealand
# Correct Mentions (sports teams):
#
#
# Doc ID: 1173 RUGBY
# Total errors: 12    total mentions: 77
# Total errors (sports teams): 9    total mentions (sports teams):16
# All Errors mentions:
# 400928: Pontypridd->Pontypridd->2->Pontypridd_RFC
# 400934: Leicester->Leicester_Tigers->3->Leicester_City_F.C.
# 400939: Australia->Australia_national_rugby_union_team->2->Australia
# 400948: David Wilson->Dave_Wilson_(rugby_union)->2->David_Wilson_(New_Zealand_politician)
# 400867: RUGBY UNION->Rugby_union->2->Ireland
# 400880: Wales->Wales_national_rugby_union_team->2->Wales
# 400890: Australia->Australia_national_rugby_union_team->2->Australia
# 400896: Australia->Australia_national_rugby_union_team->2->Australia
# 400897: Italy->Italy_national_rugby_union_team->2->Italy
# 400898: Scotland->Scotland_national_rugby_union_team->2->Scotland
# 400899: Ireland->Ireland_national_rugby_union_team->3->Republic_of_Ireland
# 400900: Wales->Wales_national_rugby_union_team->2->Wales
# Correct Mentions (sports teams):
# 400905: All Black->New_Zealand_national_rugby_union_team
# 400874: Barbarians->Barbarian_F.C.
# 400882: Wallabies->Australia_national_rugby_union_team
# 400886: Wallabies->Australia_national_rugby_union_team
# 400888: Barbarians->Barbarian_F.C.
# 400901: Barbarians->Barbarian_F.C.
# 400908: Barbarians->Barbarian_F.C.
#
#
# Doc ID: 1208 SOCCER
# Total errors: 6    total mentions: 108
# Total errors (sports teams): 4    total mentions (sports teams):36
# All Errors mentions:
# 401966: Montenegrin->Montenegro->2->Montenegro_national_football_team
# 401973: Verona->Hellas_Verona_F.C.->2->Verona
# 401975: Verona->Hellas_Verona_F.C.->2->Verona
# 401978: Verona->Hellas_Verona_F.C.->2->Verona
# 401942: Roman->Rome->2->Ancient_Rome
# 401951: Roma->A.S._Roma->2->Rome
# Correct Mentions (sports teams):
# 401985: Cagliari->Cagliari_Calcio
# 401992: Atalanta->Atalanta_B.C.
# 401994: Sampdoria->U.C._Sampdoria
# 401995: Juventus->Juventus_F.C.
# 401996: Juventus->Juventus_F.C.
# 402002: Sampdoria->U.C._Sampdoria
# 402006: Vicenza->Vicenza_Calcio
# 402008: Vicenza->Vicenza_Calcio
# 401908: Bologna->Bologna_F.C._1909
# 401910: Vicenza->Vicenza_Calcio
# 401911: Bologna->Bologna_F.C._1909
# 401917: Bologna->Bologna_F.C._1909
# 401919: AC Milan->A.C._Milan
# 401920: Cagliari->Cagliari_Calcio
# 401921: Reggiana->A.C._Reggiana_1919
# 401922: Cagliari->Cagliari_Calcio
# 401923: Napoli->S.S.C._Napoli
# 401927: Reggiana->A.C._Reggiana_1919
# 401930: Fiorentina->ACF_Fiorentina
# 401932: Fiorentina->ACF_Fiorentina
# 401940: Lazio->S.S._Lazio
# 401941: AS Roma->A.S._Roma
# 401946: Lazio->S.S._Lazio
# 401956: AC Milan->A.C._Milan
# 401957: Udinese->Udinese_Calcio
# 401958: Milan->A.C._Milan
# 401961: Rosenborg->Rosenborg_BK
# 401964: Milan->A.C._Milan
# 401968: Milan->A.C._Milan
# 401969: Udinese->Udinese_Calcio
# 401972: Napoli->S.S.C._Napoli
# 401974: Napoli->S.S.C._Napoli
#
#
# Doc ID: 1312 Cyberspace
# Total errors: 1    total mentions: 23
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403891: James Love->James_Love->2->James_Love_(poet)
# Correct Mentions (sports teams):
#
#
# Doc ID: 1347 GOLF
# Total errors: 1    total mentions: 14
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404498: LPGA->LPGA_Championship->2->LPGA
# Correct Mentions (sports teams):
#
#
# Doc ID: 1327 Court
# Total errors: 1    total mentions: 10
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404096: Foreign Affairs->Minister_for_Foreign_Affairs_(Australia)->9->United_States_House_Committee_on_Foreign_Affairs
# Correct Mentions (sports teams):
#
#
# Doc ID: 1201 SOCCER
# Total errors: 6    total mentions: 61
# Total errors (sports teams): 5    total mentions (sports teams):21
# All Errors mentions:
# 401758: Scotland->Scotland->2->Scotland_national_football_team
# 401697: Germany->Germany_national_football_team->2->Germany
# 401700: Liberian->Liberia_national_football_team->2->Liberia
# 401707: Ukraine->Ukraine_national_football_team->2->Ukraine
# 401708: Germany->Germany_national_football_team->2->Germany
# 401710: Germany->Germany_national_football_team->2->Germany
# Correct Mentions (sports teams):
# 401691: PORTUGAL->Portugal_national_football_team
# 401694: Portugal->Portugal_national_football_team
# 401703: AC Milan->A.C._Milan
# 401705: Portugal->Portugal_national_football_team
# 401712: Barcelona->FC_Barcelona
# 401715: Braga->S.C._Braga
# 401723: Sporting->Sporting_Clube_de_Portugal
# 401725: Barcelona->FC_Barcelona
# 401730: Juventus->Juventus_F.C.
# 401733: Real Madrid->Real_Madrid_C.F.
# 401740: Barcelona->FC_Barcelona
# 401742: Oviedo->Real_Oviedo
# 401745: Salamanca->UD_Salamanca
# 401752: Sporting->Sporting_Clube_de_Portugal
# 401754: Fiorentina->ACF_Fiorentina
# 401757: Celtic Glasgow->Celtic_F.C.
#
#
# Doc ID: 1369 SOCCER
# Total errors: 3    total mentions: 41
# Total errors (sports teams): 3    total mentions (sports teams):37
# All Errors mentions:
# 405306: Stirling->Stirling_Albion_F.C.->2->Stirling
# 405308: Ayr->Ayr_United_F.C.->2->Ayr_F.C.
# 405301: Dundee->Dundee_United_F.C.->2->Dundee_F.C.
# Correct Mentions (sports teams):
# 405288: Rangers->Rangers_F.C.
# 405289: Celtic->Celtic_F.C.
# 405290: Aberdeen->Aberdeen_F.C.
# 405291: Hearts->Heart_of_Midlothian_F.C.
# 405292: Hibernian->Hibernian_F.C.
# 405293: Dundee United->Dundee_United_F.C.
# 405294: Motherwell->Motherwell_F.C.
# 405295: Dunfermline->Dunfermline_Athletic_F.C.
# 405296: Raith->Raith_Rovers_F.C.
# 405297: Kilmarnock->Kilmarnock_F.C.
# 405298: St Johnstone->St._Johnstone_F.C.
# 405299: Falkirk->Falkirk_F.C.
# 405300: Airdrieonians->Airdrieonians_F.C.
# 405303: St Mirren->St._Mirren_F.C.
# 405304: Greenock Morton->Greenock_Morton_F.C.
# 405305: Clydebank->Clydebank_F.C.
# 405307: East Fife->East_Fife_F.C.
# 405309: Livingston->Livingston_F.C.
# 405310: Hamilton->Hamilton_Academical_F.C.
# 405311: Clyde->Clyde_F.C.
# 405313: Stenhousemuir->Stenhousemuir_F.C.
# 405314: Stranraer->Stranraer_F.C.
# 405315: Dumbarton->Dumbarton_F.C.
# 405316: Brechin->Brechin_City_F.C.
# 405317: Berwick->Berwick_Rangers_F.C.
# 405318: Montrose->Montrose_F.C.
# 405319: Inverness Thistle->Inverness_Thistle_F.C.
# 405320: Ross County->Ross_County_F.C.
# 405321: Alloa->Alloa_Athletic_F.C.
# 405322: Cowdenbeath->Cowdenbeath_F.C.
# 405323: Albion->West_Bromwich_Albion_F.C.
# 405324: Forfar->Forfar_Athletic_F.C.
# 405326: Arbroath->Arbroath_F.C.
# 405327: East Stirling->East_Stirlingshire_F.C.
#
#
# Doc ID: 1186 NHL
# Total errors: 18    total mentions: 44
# Total errors (sports teams): 11    total mentions (sports teams):28
# All Errors mentions:
# 401331: VANCOUVER->Vancouver->2->Vancouver_Canucks
# 401333: LOS ANGELES->Los_Angeles->2->Los_Angeles_Kings
# 401342: MONTREAL->Montreal_Canadiens->3->Montreal
# 401343: CHICAGO->Chicago_Blackhawks->4->Chicago_Bears
# 401344: PHILADELPHIA->Philadelphia_Flyers->3->Philadelphia_Phillies
# 401345: DALLAS->Dallas->4->Dallas_Stars
# 401348: OTTAWA->Ottawa_67's->4->Ottawa_Senators
# 401306: NEW YORK->New_York->4->New_York_City
# 401310: BOSTON->Boston_Bruins->3->Boston_Red_Sox
# 401312: PITTSBURGH->Pittsburgh_Penguins->2->Pittsburgh_Pirates
# 401313: OTTAWA->Ottawa_67's->4->Ottawa_Senators
# 401314: ATLANTIC->Atlantic_Division_(NHL)->2->Atlantic_Records
# 401316: PHILADELPHIA->Philadelphia_Flyers->3->Philadelphia_Phillies
# 401322: CENTRAL DIVISION->Central_Division_(NHL)->2->National_League_Central
# 401323: DETROIT->Detroit_Red_Wings->2->Detroit_Tigers
# 401325: CHICAGO->Chicago_Blackhawks->4->Chicago_Bears
# 401327: TORONTO->Toronto_Maple_Leafs->3->Toronto
# 401328: PHOENIX->Phoenix_Coyotes->2->Phoenix_Suns
# Correct Mentions (sports teams):
# 401308: HARTFORD->Hartford_Whalers
# 401309: BUFFALO->Buffalo_Sabres
# 401315: FLORIDA->Florida_Panthers
# 401317: NEW JERSEY->New_Jersey_Devils
# 401318: WASHINGTON->Washington_Capitals
# 401319: NY RANGERS->New_York_Rangers
# 401321: TAMPA BAY->Tampa_Bay_Lightning
# 401324: DALLAS->Dallas_Stars
# 401330: COLORADO->Colorado_Avalanche
# 401332: EDMONTON->Edmonton_Oilers
# 401335: CALGARY->Calgary_Flames
# 401336: ANAHEIM->Anaheim_Ducks
# 401337: ANAHEIM->Anaheim_Ducks
# 401338: BUFFALO->Buffalo_Sabres
# 401341: WASHINGTON->Washington_Capitals
# 401347: COLORADO->Colorado_Avalanche
# 401349: EDMONTON->Edmonton_Oilers
#
#
# Doc ID: 1348 ALPINE
# Total errors: 2    total mentions: 9
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404513: Lillehammer->Lillehammer->2->1994_Winter_Olympics
# 404520: World Cup->FIS_Alpine_Ski_World_Cup->3->FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1381 SOCCER
# Total errors: 2    total mentions: 27
# Total errors (sports teams): 2    total mentions (sports teams):21
# All Errors mentions:
# 405780: Hapoel Jerusalem->Hapoel_Jerusalem_F.C.->2->Hapoel_Jerusalem_B.C.
# 405797: Hapoel Jerusalem->Hapoel_Jerusalem_F.C.->2->Hapoel_Jerusalem_B.C.
# Correct Mentions (sports teams):
# 405772: Zafririm Holon->Hapoel_Tzafririm_Holon_F.C.
# 405774: Maccabi Haifa->Maccabi_Haifa_F.C.
# 405775: Hapoel Taibe->Hapoel_Tayibe_F.C.
# 405777: Bnei Yehuda->Bnei_Yehuda_Tel_Aviv_F.C.
# 405778: Hapoel Tel Aviv->Hapoel_Tel_Aviv_F.C.
# 405779: Betar Jerusalem->Beitar_Jerusalem_F.C.
# 405781: Maccabi Tel Aviv->Maccabi_Tel_Aviv_F.C.
# 405783: Maccabi Herzliya->Maccabi_Herzliya_F.C.
# 405786: Maccabi Petah Tikva->Maccabi_Petah_Tikva_F.C.
# 405787: Hapoel Haifa->Hapoel_Haifa_F.C.
# 405788: Betar Jerusalem->Beitar_Jerusalem_F.C.
# 405791: Maccabi Tel Aviv->Maccabi_Tel_Aviv_F.C.
# 405792: Maccabi Petah Tikva->Maccabi_Petah_Tikva_F.C.
# 405793: Bnei Yehuda->Bnei_Yehuda_Tel_Aviv_F.C.
# 405794: Hapoel Haifa->Hapoel_Haifa_F.C.
# 405795: Maccabi Haifa->Maccabi_Haifa_F.C.
# 405799: Zafririm Holon->Hapoel_Tzafririm_Holon_F.C.
# 405800: Maccabi Herzliya->Maccabi_Herzliya_F.C.
# 405803: Hapoel Tel Aviv->Hapoel_Tel_Aviv_F.C.
#
#
# Doc ID: 1192 NCAA
# Total errors: 2    total mentions: 24
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401550: Nebraska->Nebraska_Cornhuskers_football->2->Nebraska
# 401538: Houston->Houston_Cougars_football->5->Houston
# Correct Mentions (sports teams):
#
#
# Doc ID: 1362 SOCCER
# Total errors: 1    total mentions: 30
# Total errors (sports teams): 0    total mentions (sports teams):14
# All Errors mentions:
# 405111: Colin Cameron->Colin_Cameron_(footballer)->2->Colin_Cameron_(politician)
# Correct Mentions (sports teams):
# 405090: Aberdeen->Aberdeen_F.C.
# 405092: Celtic->Celtic_F.C.
# 405094: Rangers->Rangers_F.C.
# 405096: Kilmarnock->Kilmarnock_F.C.
# 405098: Rangers->Rangers_F.C.
# 405100: Celtic->Celtic_F.C.
# 405102: Aberdeen->Aberdeen_F.C.
# 405104: Rangers->Rangers_F.C.
# 405106: Hibernian->Hibernian_F.C.
# 405108: Rangers->Rangers_F.C.
# 405110: Dunfermline->Dunfermline_Athletic_F.C.
# 405112: Hearts->Heart_of_Midlothian_F.C.
# 405114: Dundee United->Dundee_United_F.C.
# 405116: Celtic->Celtic_F.C.
#
#
# Doc ID: 1285 Half
# Total errors: 1    total mentions: 11
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403467: cocker spaniels->Cocker_Spaniel->2->American_Cocker_Spaniel
# Correct Mentions (sports teams):
#
#
# Doc ID: 1382 SOCCER
# Total errors: 8    total mentions: 17
# Total errors (sports teams): 3    total mentions (sports teams):9
# All Errors mentions:
# 405804: ASIAN CUP->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 405806: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 405815: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405816: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405817: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405821: Indonesia->Indonesia_national_football_team->2->Indonesia
# 405824: South Korea->Korea_Republic_national_football_team->2->South_Korea
# 405827: Indonesia->Indonesia_national_football_team->2->Indonesia
# Correct Mentions (sports teams):
# 405808: Kuwait->Kuwait_national_football_team
# 405809: UAE->United_Arab_Emirates_national_football_team
# 405807: United Arab Emirates->United_Arab_Emirates_national_football_team
# 405813: Kuwait->Kuwait_national_football_team
# 405825: UAE->United_Arab_Emirates_national_football_team
# 405826: Kuwait->Kuwait_national_football_team
#
#
# Doc ID: 1226 Major
# Total errors: 7    total mentions: 14
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402402: John Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# 402403: Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# 402405: Downing Street->10_Downing_Street->2->Downing_Street
# 402406: Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# 402407: Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# 402410: Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# 402412: Gorst->John_Michael_Gorst->2->John_Eldon_Gorst
# Correct Mentions (sports teams):
#
#
# Doc ID: 1179 CRICKET
# Total errors: 1    total mentions: 11
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401139: World Series->World_Series_Cricket->2->World_Series
# Correct Mentions (sports teams):
#
#
# Doc ID: 1349 ALPINE
# Total errors: 2    total mentions: 114
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404524: World Cup->FIS_Alpine_Ski_World_Cup->3->FIFA_World_Cup
# 404568: World Cup->FIS_Alpine_Ski_World_Cup->3->FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1180 CRICKET
# Total errors: 4    total mentions: 6
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401145: WEST INDIES->West_Indies_cricket_team->2->Caribbean
# 401147: MELBOURNE->Melbourne->2->Melbourne_Cricket_Ground
# 401148: West Indies->West_Indies_cricket_team->2->Caribbean
# 401149: World Series->World_Series_Cricket->2->World_Series
# Correct Mentions (sports teams):
#
#
# Doc ID: 1373 SOCCER
# Total errors: 3    total mentions: 83
# Total errors (sports teams): 2    total mentions (sports teams):72
# All Errors mentions:
# 405545: Boston->Boston_United_F.C.->4->Boston
# 405548: Enfield->Enfield_Town_F.C.->2->Enfield_Cricket_Club
# 405491: English->United_Kingdom->4->England
# Correct Mentions (sports teams):
# 405493: Arsenal->Arsenal_F.C.
# 405494: Derby->Derby_County_F.C.
# 405495: Chelsea->Chelsea_F.C.
# 405496: Everton->Everton_F.C.
# 405497: Coventry->Coventry_City_F.C.
# 405498: Tottenham->Tottenham_Hotspur_F.C.
# 405499: Leicester->Leicester_City_F.C.
# 405500: Blackburn->Blackburn_Rovers_F.C.
# 405501: Liverpool->Liverpool_F.C.
# 405502: Sheffield Wednesday->Sheffield_Wednesday_F.C.
# 405503: Middlesbrough->Middlesbrough_F.C.
# 405505: Southampton->Southampton_F.C.
# 405507: Sunderland->Sunderland_A.F.C.
# 405508: Wimbledon->Wimbledon_F.C.
# 405509: Barnsley->Barnsley_F.C.
# 405510: Southend->Southend_United_F.C.
# 405511: Birmingham->Birmingham_City_F.C.
# 405512: Grimsby->Grimsby_Town_F.C.
# 405513: Charlton->Charlton_Athletic_F.C.
# 405515: Crystal Palace->Crystal_Palace_F.C.
# 405516: Oxford->Oxford_United_F.C.
# 405518: Norwich->Norwich_City_F.C.
# 405519: Ipswich->Ipswich_Town_F.C.
# 405520: Wolverhampton->Wolverhampton_Wanderers_F.C.
# 405521: Manchester City->Manchester_City_F.C.
# 405522: Bradford->Bradford_City_A.F.C.
# 405523: Oldham->Oldham_Athletic_A.F.C.
# 405524: Queens Park Rangers->Queens_Park_Rangers_F.C.
# 405525: Reading->Reading_F.C.
# 405526: Port Vale->Port_Vale_F.C.
# 405527: Sheffield United->Sheffield_United_F.C.
# 405528: Portsmouth->Portsmouth_F.C.
# 405529: Stoke->Stoke_City_F.C.
# 405530: Tranmere->Tranmere_Rovers_F.C.
# 405531: West Bromwich->West_Bromwich_Albion_F.C.
# 405532: Bolton->Bolton_Wanderers_F.C.
# 405534: Barnet->Barnet_F.C.
# 405535: Wycombe->Wycombe_Wanderers_F.C.
# 405536: Blackpool->Blackpool_F.C.
# 405537: Hednesford->Hednesford_Town_F.C.
# 405538: Bristol City->Bristol_City_F.C.
# 405539: St Albans->St_Albans_City_F.C.
# 405540: Cambridge United->Cambridge_United_F.C.
# 405541: Woking->Woking_F.C.
# 405542: Carlisle->Carlisle_United_F.C.
# 405543: Darlington->Darlington_F.C.
# 405544: Chester->Chester_City_F.C.
# 405546: Chesterfield->Chesterfield_F.C.
# 405549: Peterborough->Peterborough_United_F.C.
# 405550: Hull->Hull_City_A.F.C.
# 405551: Crewe->Crewe_Alexandra_F.C.
# 405552: Leyton Orient->Leyton_Orient_F.C.
# 405553: Stevenage->Stevenage_F.C.
# 405554: Luton->Luton_Town_F.C.
# 405555: Boreham Wood->Boreham_Wood_F.C.
# 405556: Mansfield->Mansfield_Town_F.C.
# 405557: Stockport->Stockport_County_F.C.
# 405558: Notts County->Notts_County_F.C.
# 405559: Rochdale->Rochdale_A.F.C.
# 405560: Preston->Preston_North_End_F.C.
# 405561: York->York_City_F.C.
# 405562: Sudbury Town->Sudbury_Town_F.C.
# 405563: Brentford->Brentford_F.C.
# 405564: Walsall->Walsall_F.C.
# 405565: Burnley->Burnley_F.C.
# 405566: Watford->Watford_F.C.
# 405568: Wrexham->Wrexham_F.C.
# 405569: Scunthorpe->Scunthorpe_United_F.C.
# 405570: Cardiff->Cardiff_City_F.C.
# 405571: Gillingham->Gillingham_F.C.
#
#
# Doc ID: 1264 Indonesia
# Total errors: 1    total mentions: 55
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403072: Vatican->Vatican_City->2->Holy_See
# Correct Mentions (sports teams):
#
#
# Doc ID: 1216 POLAND
# Total errors: 2    total mentions: 45
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402205: Nazi->Nazi_Party->4->Nazi_Germany
# 402206: German->Nazi_Germany->3->Germany
# Correct Mentions (sports teams):
#
#
# Doc ID: 1351 NORDIC
# Total errors: 4    total mentions: 33
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404727: World Cup->Biathlon_World_Cup->10->1998_FIFA_World_Cup
# 404729: Belarus->Belarus->2->Belarus_national_football_team
# 404738: World Cup->Biathlon_World_Cup->10->1998_FIFA_World_Cup
# 404754: World Cup->Biathlon_World_Cup->10->1998_FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1227 Electronic
# Total errors: 1    total mentions: 9
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402416: EDS->HP_Enterprise_Services->2->Energy-dispersive_X-ray_spectroscopy
# Correct Mentions (sports teams):
#
#
# Doc ID: 1272 Texas
# Total errors: 1    total mentions: 7
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403309: Panhandle->Oklahoma_Panhandle->7->Panhandle,_Texas
# Correct Mentions (sports teams):
#
#
# Doc ID: 1386 NHL
# Total errors: 3    total mentions: 17
# Total errors (sports teams): 3    total mentions (sports teams):13
# All Errors mentions:
# 405957: Toronto->Toronto_Maple_Leafs->2->Toronto
# 405962: Montreal->Montreal_Canadiens->2->Montreal
# 405963: CHICAGO->Chicago_Blackhawks->2->Chicago
# Correct Mentions (sports teams):
# 405967: COLORADO->Colorado_Avalanche
# 405968: EDMONTON->Edmonton_Oilers
# 405969: Ottawa->Ottawa_Senators
# 405956: NY RANGERS->New_York_Rangers
# 405958: BUFFALO->Buffalo_Sabres
# 405959: Anaheim->Anaheim_Ducks
# 405960: Pittsburgh->Pittsburgh_Penguins
# 405961: WASHINGTON->Washington_Capitals
# 405964: Philadelphia->Philadelphia_Flyers
# 405965: DALLAS->Dallas_Stars
#
#
# Doc ID: 1330 NZ
# Total errors: 3    total mentions: 16
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404134: Labour->New_Zealand_Labour_Party->2->Labour_Party_(UK)
# 404138: Labour->New_Zealand_Labour_Party->2->Labour_Party_(UK)
# 404143: Labour->New_Zealand_Labour_Party->2->Labour_Party_(UK)
# Correct Mentions (sports teams):
#
#
# Doc ID: 1300 OPEC
# Total errors: 1    total mentions: 13
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403693: Isthmus->Isthmus_of_Tehuantepec->4->Isthmus_(newspaper)
# Correct Mentions (sports teams):
#
#
# Doc ID: 1274 BALANCE
# Total errors: 1    total mentions: 4
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403322: FSA->Financial_Services_Authority->2->Society_of_Antiquaries_of_London
# Correct Mentions (sports teams):
#
#
# Doc ID: 1164 RUGBY
# Total errors: 8    total mentions: 27
# Total errors (sports teams): 7    total mentions (sports teams):7
# All Errors mentions:
# 400542: ITALY->Italy_national_rugby_union_team->2->Italy
# 400544: Italy->Italy_national_rugby_union_team->2->Italy
# 400546: Scotland->Scotland_national_rugby_union_team->3->Scotland
# 400550: England->England_national_rugby_union_team->3->England
# 400555: England->England_national_rugby_union_team->3->England
# 400558: Italy->Italy_national_rugby_union_team->2->Italy
# 400559: England->England_national_rugby_union_team->3->England
# 400561: World Cup->Rugby_World_Cup->7->FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1169 SOCCER
# Total errors: 1    total mentions: 3
# Total errors (sports teams): 1    total mentions (sports teams):2
# All Errors mentions:
# 400778: Plymouth->Plymouth_Argyle_F.C.->2->Plymouth
# Correct Mentions (sports teams):
# 400779: Exeter->Exeter_City_F.C.
#
#
# Doc ID: 1301 Relations
# Total errors: 1    total mentions: 12
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403700: European->European_Union->2->Europe
# Correct Mentions (sports teams):
#
#
# Doc ID: 1228 RTRS
# Total errors: 4    total mentions: 7
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402429: World Series->World_Series_Cricket->2->World_Series
# 402430: West Indies->West_Indies_cricket_team->2->Caribbean
# 402431: Australia->Australia_national_cricket_team->3->Australia
# 402432: West Indies->West_Indies_cricket_team->2->Caribbean
# Correct Mentions (sports teams):
#
#
# Doc ID: 1202 SOCCER
# Total errors: 1    total mentions: 47
# Total errors (sports teams): 0    total mentions (sports teams):22
# All Errors mentions:
# 401785: Ronaldo->Ronaldo->2->Cristiano_Ronaldo
# Correct Mentions (sports teams):
# 401759: REAL MADRID->Real_Madrid_C.F.
# 401760: BARCELONA->FC_Barcelona
# 401764: Real Madrid->Real_Madrid_C.F.
# 401765: Barcelona->FC_Barcelona
# 401766: Real Madrid->Real_Madrid_C.F.
# 401767: Barcelona->FC_Barcelona
# 401768: Real Madrid->Real_Madrid_C.F.
# 401769: Barcelona->FC_Barcelona
# 401770: Real Madrid->Real_Madrid_C.F.
# 401771: Real Madrid->Real_Madrid_C.F.
# 401772: Real Madrid->Real_Madrid_C.F.
# 401773: Real Madrid->Real_Madrid_C.F.
# 401774: Barcelona->FC_Barcelona
# 401775: Real Madrid->Real_Madrid_C.F.
# 401776: Barcelona->FC_Barcelona
# 401777: Barcelona->FC_Barcelona
# 401778: Real Madrid->Real_Madrid_C.F.
# 401779: Barcelona->FC_Barcelona
# 401780: Barcelona->FC_Barcelona
# 401781: Barcelona->FC_Barcelona
# 401782: Real Madrid->Real_Madrid_C.F.
# 401783: Barcelona->FC_Barcelona
#
#
# Doc ID: 1331 RTRS
# Total errors: 3    total mentions: 24
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404145: RTRS->Radiotelevision_of_Bosnia-Herzegovina->2->Radio_Televizija_Republike_Srpske
# 404156: Fraser->Fraser,_Australian_Capital_Territory->4->Malcolm_Fraser
# 404168: Fraser->Fraser,_Australian_Capital_Territory->4->Malcolm_Fraser
# Correct Mentions (sports teams):
#
#
# Doc ID: 1175 SOCCER
# Total errors: 4    total mentions: 35
# Total errors (sports teams): 1    total mentions (sports teams):3
# All Errors mentions:
# 400993: Romania->Romania_national_football_team->2->Romania
# 401002: European->Europe->2->UEFA_Champions_League
# 401003: Macedonia->Republic_of_Macedonia->2->Macedonia_national_football_team
# 401013: Galatasaray->Galatasaray_S.K._(football_team)->2->Galatasaray_S.K.
# Correct Mentions (sports teams):
# 400991: MACEDONIA->Macedonia_national_football_team
# 400995: Macedonia->Macedonia_national_football_team
#
#
# Doc ID: 1383 NBA
# Total errors: 26    total mentions: 53
# Total errors (sports teams): 19    total mentions (sports teams):41
# All Errors mentions:
# 405831: ATLANTIC->Atlantic_Division_(NBA)->2->Atlantic_Records
# 405833: NEW YORK->New_York_Knicks->2->New_York_City
# 405835: WASHINGTON->Washington_Wizards->2->Washington_Capitals
# 405836: PHILADELPHIA->Philadelphia_76ers->4->Philadelphia_Eagles
# 405837: NEW JERSEY->New_Jersey_Nets->3->New_Jersey_Devils
# 405838: BOSTON->Boston_Celtics->2->Boston_Red_Sox
# 405839: CENTRAL DIVISION->Central_Division_(NBA)->2->National_League_Central
# 405840: CHICAGO->Chicago_Bulls->4->Chicago_White_Sox
# 405841: DETROIT->Detroit_Pistons->2->Detroit_Tigers
# 405842: CLEVELAND->Cleveland_Cavaliers->3->Cleveland_Indians
# 405843: ATLANTA->Atlanta_Hawks->2->Atlanta_Braves
# 405846: CHARLOTTE->New_Orleans_Hornets->3->Charlotte_Bobcats
# 405850: MINNESOTA->Minnesota_Timberwolves->3->Minnesota_Twins
# 405854: VANCOUVER->Memphis_Grizzlies->3->Vancouver_Canucks
# 405856: SEATTLE->Seattle_SuperSonics->3->Seattle_Mariners
# 405861: SACRAMENTO->San_Antonio_Spurs->5->Sacramento_Kings
# 405864: ATLANTA->Atlanta_Hawks->2->Atlanta_Braves
# 405866: NEW YORK->New_York_Knicks->2->New_York_City
# 405868: WASHINGTON->Washington_Wizards->2->Washington_Capitals
# 405869: DETROIT->Detroit_Pistons->2->Detroit_Tigers
# 405870: NEW JERSEY->New_Jersey_Nets->3->New_Jersey_Devils
# 405872: CHICAGO->Chicago_Bulls->4->Chicago_White_Sox
# 405873: VANCOUVER->Memphis_Grizzlies->3->Vancouver_Canucks
# 405875: PHILADELPHIA->Philadelphia_76ers->4->Philadelphia_Eagles
# 405879: CHARLOTTE->New_Orleans_Hornets->3->Charlotte_Bobcats
# 405880: SEATTLE->Seattle_SuperSonics->3->Seattle_Mariners
# Correct Mentions (sports teams):
# 405832: MIAMI->Miami_Heat
# 405834: ORLANDO->Orlando_Magic
# 405844: MILWAUKEE->Milwaukee_Bucks
# 405845: INDIANA->Indiana_Pacers
# 405847: TORONTO->Toronto_Raptors
# 405848: HOUSTON->Houston_Rockets
# 405849: UTAH->Utah_Jazz
# 405851: DALLAS->Dallas_Mavericks
# 405852: DENVER->Denver_Nuggets
# 405857: LA LAKERS->Los_Angeles_Lakers
# 405858: PORTLAND->Portland_Trail_Blazers
# 405859: LA CLIPPERS->Los_Angeles_Clippers
# 405860: GOLDEN STATE->Golden_State_Warriors
# 405862: PHOENIX->Phoenix_Suns
# 405863: TORONTO->Toronto_Raptors
# 405865: LA CLIPPERS->Los_Angeles_Clippers
# 405867: MILWAUKEE->Milwaukee_Bucks
# 405871: MIAMI->Miami_Heat
# 405874: DALLAS->Dallas_Mavericks
# 405876: HOUSTON->Houston_Rockets
# 405877: UTAH->Utah_Jazz
# 405878: DENVER->Denver_Nuggets
#
#
# Doc ID: 1267 Burmese
# Total errors: 3    total mentions: 21
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403117: NLD->National_League_for_Democracy->2->Netherlands
# 403119: Nobel->Nobel_Peace_Prize->3->Nobel_Prize
# 403121: NLD->National_League_for_Democracy->2->Netherlands
# Correct Mentions (sports teams):
#
#
# Doc ID: 1170 SOCCER
# Total errors: 2    total mentions: 19
# Total errors (sports teams): 1    total mentions (sports teams):9
# All Errors mentions:
# 400782: Dutch->Netherlands_national_football_team->3->Netherlands
# 400793: Barcelona->Barcelona->2->FC_Barcelona
# Correct Mentions (sports teams):
# 400785: Sheffield Wednesday->Sheffield_Wednesday_F.C.
# 400786: Liverpool->Liverpool_F.C.
# 400789: Wednesday->Sheffield_Wednesday_F.C.
# 400790: Udinese->Udinese_Calcio
# 400791: Feyenoord->Feyenoord
# 400794: Udinese->Udinese_Calcio
# 400796: Feyenoord->Feyenoord
# 400800: Udinese->Udinese_Calcio
#
#
# Doc ID: 1302 Two
# Total errors: 3    total mentions: 15
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403712: Stephenville->Stephenville_International_Airport->2->Stephenville,_Texas
# 403723: Stephenville->Stephenville_International_Airport->2->Stephenville,_Texas
# 403726: Stephenville->Stephenville_International_Airport->2->Stephenville,_Texas
# Correct Mentions (sports teams):
#
#
# Doc ID: 1289 Spain
# Total errors: 2    total mentions: 10
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403524: Basque->Basque_Country_(greater_region)->5->Basque_Country_(autonomous_community)
# 403528: Basque->Basque_Country_(greater_region)->5->Basque_Country_(autonomous_community)
# Correct Mentions (sports teams):
#
#
# Doc ID: 1359 BADMINTON
# Total errors: 2    total mentions: 18
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404973: WORLD GRAND PRIX->World_Badminton_Grand_Prix->2->FIVB_World_Grand_Prix_2009
# 404976: World Grand Prix->World_Badminton_Grand_Prix->2->FIVB_World_Grand_Prix_2009
# Correct Mentions (sports teams):
#
#
# Doc ID: 1268 Union
# Total errors: 1    total mentions: 40
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403132: Bill Jordan->William_Jordan,_Baron_Jordan->2->William_Joseph_Jordan
# Correct Mentions (sports teams):
#
#
# Doc ID: 1209 BASKETBALL
# Total errors: 6    total mentions: 18
# Total errors (sports teams): 3    total mentions (sports teams):6
# All Errors mentions:
# 402017: EUROLEAGUE->Euroleague_Basketball->2->Euroleague_2006â07
# 402019: EuroLeague->Euroleague_Basketball->2->Euroleague_2006â07
# 402020: Charleroi->Charleroi->2->R._Charleroi_S.C.
# 402021: Charleroi->Spirou_Charleroi->4->R._Charleroi_S.C.
# 402025: Charleroi->Spirou_Charleroi->4->R._Charleroi_S.C.
# 402034: Partizan Belgrade->KK_Partizan->2->FK_Partizan
# Correct Mentions (sports teams):
# 402023: Estudiantes Madrid->CB_Estudiantes
# 402029: Estudiantes->CB_Estudiantes
# 402038: Partizan->KK_Partizan
#
#
# Doc ID: 1277 Iowa-S
# Total errors: 1    total mentions: 4
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403371: DES MOINES->Des_Moines,_Iowa->2->Des_Moines_Menace
# Correct Mentions (sports teams):
#
#
# Doc ID: 1229 Cricket
# Total errors: 1    total mentions: 8
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402439: Pakistan->Pakistan->2->Pakistan_national_cricket_team
# Correct Mentions (sports teams):
#
#
# Doc ID: 1187 NHL
# Total errors: 2    total mentions: 15
# Total errors (sports teams): 1    total mentions (sports teams):6
# All Errors mentions:
# 401359: BOSTON->Boston_Bruins->3->Boston_Celtics
# 401364: Phoenix->Phoenix_Coyotes->2->Phoenix_Suns
# Correct Mentions (sports teams):
# 401358: Hartford->Hartford_Whalers
# 401360: FLORIDA->Florida_Panthers
# 401362: NEW JERSEY->New_Jersey_Devils
# 401363: Calgary->Calgary_Flames
# 401366: Tampa Bay->Tampa_Bay_Lightning
#
#
# Doc ID: 1290 Mussolini
# Total errors: 4    total mentions: 15
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403531: Mussolini->Benito_Mussolini->2->Alessandra_Mussolini
# 403542: Mussolini->Alessandra_Mussolini->2->Benito_Mussolini
# 403546: Mussolini->Alessandra_Mussolini->2->Benito_Mussolini
# 403549: Mussolini->Alessandra_Mussolini->2->Benito_Mussolini
# Correct Mentions (sports teams):
#
#
# Doc ID: 1182 CRICKET
# Total errors: 4    total mentions: 35
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401167: Australian->Australia->2->Australia_national_cricket_team
# 401179: Australian->Australia->2->Australia_national_cricket_team
# 401193: Australia->Australia->2->Australia_national_cricket_team
# 401197: World Series->World_Series_Cricket->2->World_Series
# Correct Mentions (sports teams):
#
#
# Doc ID: 1364 SOCCER
# Total errors: 2    total mentions: 19
# Total errors (sports teams): 0    total mentions (sports teams):14
# All Errors mentions:
# 405152: NORTHERN IRELAND->Northern_Ireland->2->Northern_Ireland_national_football_team
# 405154: Northern Ireland->Northern_Ireland->2->Northern_Ireland_national_football_team
# Correct Mentions (sports teams):
# 405156: Crusaders->Crusaders_F.C.
# 405157: Cliftonville->Cliftonville_F.C.
# 405158: Portadown->Portadown_F.C.
# 405159: Glenavon->Glenavon_F.C.
# 405160: Linfield->Linfield_F.C.
# 405161: Glentoran->Glentoran_F.C.
# 405162: Coleraine->Coleraine_F.C.
# 405163: Coleraine->Coleraine_F.C.
# 405164: Linfield->Linfield_F.C.
# 405165: Crusaders->Crusaders_F.C.
# 405166: Glenavon->Glenavon_F.C.
# 405167: Glentoran->Glentoran_F.C.
# 405168: Portadown->Portadown_F.C.
# 405170: Cliftonville->Cliftonville_F.C.
#
#
# Doc ID: 1374 RUGBY
# Total errors: 1    total mentions: 14
# Total errors (sports teams): 1    total mentions (sports teams):6
# All Errors mentions:
# 405576: Australia->Australia_national_rugby_union_team->2->Australia
# Correct Mentions (sports teams):
# 405578: Barbarians->Barbarian_F.C.
# 405581: Wallabies->Australia_national_rugby_union_team
# 405583: Wallaby->Australia_national_rugby_union_team
# 405584: Barbarians->Barbarian_F.C.
# 405585: Wallaby->Australia_national_rugby_union_team
#
#
# Doc ID: 1165 SOCCER
# Total errors: 12    total mentions: 37
# Total errors (sports teams): 11    total mentions (sports teams):11
# All Errors mentions:
# 400584: JAPAN->Japan_national_football_team->2->Japan
# 400585: SYRIA->Syria_national_football_team->2->Syria
# 400588: Japan->Japan_national_football_team->2->Japan
# 400589: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 400590: Syria->Syria_national_football_team->2->Syria
# 400593: Syrian->Syria_national_football_team->3->Syria
# 400596: Syria->Syria_national_football_team->2->Syria
# 400600: Japan->Japan_national_football_team->2->Japan
# 400601: Syrian->Syria_national_football_team->3->Syria
# 400607: Japan->Japan_national_football_team->2->Japan
# 400610: Japan->Japan_national_football_team->2->Japan
# 400624: Syria->Syria_national_football_team->2->Syria
# Correct Mentions (sports teams):
#
#
# Doc ID: 1171 SOCCER
# Total errors: 3    total mentions: 13
# Total errors (sports teams): 0    total mentions (sports teams):1
# All Errors mentions:
# 400801: LEEDS->Leeds_United_A.F.C.->2->Leeds
# 400804: Leeds->Leeds_United_A.F.C.->2->Leeds
# 400811: Leeds->Leeds_United_A.F.C.->2->Leeds
# Correct Mentions (sports teams):
# 400815: Middlesbrough->Middlesbrough_F.C.
#
#
# Doc ID: 1370 SOCCER
# Total errors: 2    total mentions: 96
# Total errors (sports teams): 2    total mentions (sports teams):86
# All Errors mentions:
# 405354: Barnsley->Burnley_F.C.->3->Barnsley_F.C.
# 405402: Wigan->Wigan_Athletic_F.C.->2->Wigan_Warriors
# Correct Mentions (sports teams):
# 405366: Port Vale->Port_Vale_F.C.
# 405367: Ipswich->Ipswich_Town_F.C.
# 405368: Manchester City->Manchester_City_F.C.
# 405369: Portsmouth->Portsmouth_F.C.
# 405370: Reading->Reading_F.C.
# 405371: West Bromwich->West_Bromwich_Albion_F.C.
# 405372: Southend->Southend_United_F.C.
# 405373: Grimsby->Grimsby_Town_F.C.
# 405374: Bradford->Bradford_City_A.F.C.
# 405375: Oldham->Oldham_Athletic_A.F.C.
# 405376: Brentford->Brentford_F.C.
# 405377: Millwall->Millwall_F.C.
# 405378: Bury->Bury_F.C.
# 405379: Luton->Luton_Town_F.C.
# 405380: Burnley->Burnley_F.C.
# 405381: Chesterfield->Chesterfield_F.C.
# 405382: Stockport->Stockport_County_F.C.
# 405383: Watford->Watford_F.C.
# 405384: Wrexham->Wrexham_F.C.
# 405385: Crewe->Crewe_Alexandra_F.C.
# 405386: Bristol City->Bristol_City_F.C.
# 405387: Bristol Rovers->Bristol_Rovers_F.C.
# 405388: Shrewsbury->Shrewsbury_Town_F.C.
# 405389: York->York_City_F.C.
# 405390: Blackpool->Blackpool_F.C.
# 405391: Walsall->Walsall_F.C.
# 405392: Gillingham->Gillingham_F.C.
# 405393: Preston->Preston_North_End_F.C.
# 405394: Bournemouth->A.F.C._Bournemouth
# 405395: Plymouth->Plymouth_Argyle_F.C.
# 405396: Peterborough->Peterborough_United_F.C.
# 405397: Notts County->Notts_County_F.C.
# 405398: Wycombe->Wycombe_Wanderers_F.C.
# 405400: Fulham->Fulham_F.C.
# 405401: Cambridge->Cambridge_United_F.C.
# 405403: Carlisle->Carlisle_United_F.C.
# 405404: Cardiff->Cardiff_City_F.C.
# 405405: Swansea->Swansea_City_A.F.C.
# 405406: Barnet->Barnet_F.C.
# 405407: Colchester->Colchester_United_F.C.
# 405408: Scunthorpe->Scunthorpe_United_F.C.
# 405409: Northampton->Northampton_Town_F.C.
# 405411: Lincoln->Lincoln_City_F.C.
# 405412: Chester->Chester_City_F.C.
# 405413: Hull->Hull_City_A.F.C.
# 405414: Torquay->Torquay_United_F.C.
# 405415: Rochdale->Rochdale_A.F.C.
# 405416: Exeter->Exeter_City_F.C.
# 405417: Doncaster->Doncaster_Rovers_F.C.
# 405418: Mansfield->Mansfield_Town_F.C.
# 405419: Leyton Orient->Leyton_Orient_F.C.
# 405420: Hereford->Hereford_United_F.C.
# 405421: Darlington->Darlington_F.C.
# 405422: Hartlepool->Hartlepool_United_F.C.
# 405423: Brighton->Brighton_&_Hove_Albion_F.C.
# 405348: Blackburn->Blackburn_Rovers_F.C.
# 405349: Southampton->Southampton_F.C.
# 405350: Coventry->Coventry_City_F.C.
# 405351: Nottingham Forest->Nottingham_Forest_F.C.
# 405352: Bolton->Bolton_Wanderers_F.C.
# 405353: Sheffield United->Sheffield_United_F.C.
# 405355: Crystal Palace->Crystal_Palace_F.C.
# 405356: Wolverhampton->Wolverhampton_Wanderers_F.C.
# 405357: Tranmere->Tranmere_Rovers_F.C.
# 405358: Norwich->Norwich_City_F.C.
# 405359: Birmingham->Birmingham_City_F.C.
# 405360: Oxford->Oxford_United_F.C.
# 405361: Stoke->Stoke_City_F.C.
# 405363: Charlton->Charlton_Athletic_F.C.
# 405365: Queens Park Rangers->Queens_Park_Rangers_F.C.
# 405332: Arsenal->Arsenal_F.C.
# 405333: Wimbledon->Wimbledon_F.C.
# 405334: Liverpool->Liverpool_F.C.
# 405336: Newcastle->Newcastle_United_F.C.
# 405337: Manchester United->Manchester_United_F.C.
# 405338: Chelsea->Chelsea_F.C.
# 405339: Everton->Everton_F.C.
# 405340: Sheffield Wednesday->Sheffield_Wednesday_F.C.
# 405341: Tottenham->Tottenham_Hotspur_F.C.
# 405342: Derby->Derby_County_F.C.
# 405343: Leicester->Leicester_City_F.C.
# 405345: Sunderland->Sunderland_A.F.C.
# 405346: West Ham->West_Ham_United_F.C.
# 405347: Middlesbrough->Middlesbrough_F.C.
#
#
# Doc ID: 1303 PLO
# Total errors: 3    total mentions: 42
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403732: Palestinian->Palestine->2->State_of_Palestine
# 403761: Palestinians->Palestine->2->State_of_Palestine
# 403774: Palestinian->Palestine->2->State_of_Palestine
# Correct Mentions (sports teams):
#
#
# Doc ID: 1315 Italian
# Total errors: 2    total mentions: 20
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403964: Mantua->Province_of_Mantua->5->Duchy_of_Mantua
# 403965: Austrian->Austrian_Empire->2->Austria
# Correct Mentions (sports teams):
#
#
# Doc ID: 1352 ALPINE
# Total errors: 1    total mentions: 8
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404763: World Cup->FIS_Alpine_Ski_World_Cup->4->FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1344 ALPINE
# Total errors: 4    total mentions: 8
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404409: World Cup->FIS_Alpine_Ski_World_Cup->3->FIFA_World_Cup
# 404412: World Cup->FIS_Alpine_Ski_World_Cup->3->FIFA_World_Cup
# 404414: Lillehammer->Lillehammer->2->1994_Winter_Olympics
# 404415: Winter Olympics->Alpine_skiing_at_the_1994_Winter_Olympics->9->1994_Winter_Olympics
# Correct Mentions (sports teams):
#
#
# Doc ID: 1375 RUGBY
# Total errors: 4    total mentions: 17
# Total errors (sports teams): 4    total mentions (sports teams):6
# All Errors mentions:
# 405588: AUSTRALIA->Australia_national_rugby_union_team->2->Australia
# 405589: BARBARIANS->New_Zealand_Barbarians->4->Barbarian_F.C.
# 405591: Australia->Australia_national_rugby_union_team->2->Australia
# 405594: Australia->Australia_national_rugby_union_team->2->Australia
# Correct Mentions (sports teams):
# 405601: Barbarians->Barbarian_F.C.
# 405592: Barbarians->Barbarian_F.C.
#
#
# Doc ID: 1316 Denmark
# Total errors: 1    total mentions: 4
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403979: Wednesday->Wednesday->3->Sheffield_Wednesday_F.C.
# Correct Mentions (sports teams):
#
#
# Doc ID: 1210 SQUASH
# Total errors: 1    total mentions: 15
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402048: Englishman->English_people->3->England
# Correct Mentions (sports teams):
#
#
# Doc ID: 1177 CRICKET
# Total errors: 3    total mentions: 28
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401048: World Series->World_Series_Cricket->2->World_Series
# 401069: Australia->Australia->2->Australia_national_cricket_team
# 401070: World Series->World_Series_Cricket->2->World_Series
# Correct Mentions (sports teams):
#
#
# Doc ID: 1188 NFL
# Total errors: 5    total mentions: 41
# Total errors (sports teams): 0    total mentions (sports teams):15
# All Errors mentions:
# 401370: INDIANAPOLIS->Indianapolis->3->Indianapolis_Colts
# 401381: Kansas City->Kansas_City,_Missouri->2->Kansas_City_Royals
# 401382: Cincinnati->Cincinnati->3->Cincinnati_Reds
# 401384: Philadelphia->Philadelphia->2->Philadelphia_Eagles
# 401389: Philadelphia->Philadelphia->2->Philadelphia_Eagles
# Correct Mentions (sports teams):
# 401369: EAGLES->Philadelphia_Eagles
# 401371: Indianapolis Colts->Indianapolis_Colts
# 401372: Philadelphia Eagles->Philadelphia_Eagles
# 401375: Colts->Indianapolis_Colts
# 401376: Eagles->Philadelphia_Eagles
# 401379: Colts->Indianapolis_Colts
# 401380: Indianapolis->Indianapolis_Colts
# 401383: Eagles->Philadelphia_Eagles
# 401385: Dallas Cowboys->Dallas_Cowboys
# 401386: Washington Redskins->Washington_Redskins
# 401387: New York Jets->New_York_Jets
# 401391: Colts->Indianapolis_Colts
# 401400: Miami Dolphins->Miami_Dolphins
# 401403: Philadelphia->Philadelphia_Eagles
# 401406: Eagles->Philadelphia_Eagles
#
#
# Doc ID: 1204 SOCCER
# Total errors: 1    total mentions: 23
# Total errors (sports teams): 1    total mentions (sports teams):20
# All Errors mentions:
# 401844: Extremadura->CF_Extremadura->2->Extremadura
# Correct Mentions (sports teams):
# 401823: Real Madrid->Real_Madrid_C.F.
# 401824: Barcelona->FC_Barcelona
# 401826: Real Betis->Real_Betis
# 401841: Sevilla->Sevilla_FC
# 401827: Atletico Madrid->Atlético_Madrid
# 401828: Athletic Bilbao->Athletic_Bilbao
# 401829: Real Sociedad->Real_Sociedad
# 401830: Valladolid->Real_Valladolid
# 401831: Racing Santander->Racing_de_Santander
# 401832: Rayo Vallecano->Rayo_Vallecano
# 401833: Valencia->Valencia_CF
# 401834: Celta Vigo->Celta_de_Vigo
# 401835: Tenerife->CD_Tenerife
# 401836: Espanyol->RCD_Espanyol
# 401837: Oviedo->Real_Oviedo
# 401838: Sporting->Sporting_de_Gijón
# 401840: Zaragoza->Real_Zaragoza
# 401842: Compostela->SD_Compostela
# 401843: Hercules->Hércules_CF
#
#
# Doc ID: 1317 Moslem
# Total errors: 1    total mentions: 8
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403986: Blida->Blida_Province->2->Blida
# Correct Mentions (sports teams):
#
#
# Doc ID: 1172 BASKETBALL
# Total errors: 12    total mentions: 45
# Total errors (sports teams): 7    total mentions (sports teams):12
# All Errors mentions:
# 400816: EUROLEAGUE->Euroleague_Basketball->5->EuroLeague_Women
# 400818: EuroLeague->Euroleague_Basketball->5->EuroLeague_Women
# 400827: Limoges->CSP_Limoges->3->Limoges_FC
# 400829: Panionios->Panionios_B.C.->2->Panionios
# 400841: Charleroi->Spirou_Charleroi->3->R._Charleroi_S.C.
# 400847: Villeurbanne->ASVEL_Lyon-Villeurbanne->2->Villeurbanne
# 400849: Barcelona->FC_Barcelona_Bàsquet->4->FC_Barcelona
# 400851: Split->KK_Split->2->Split_(city)
# 400853: Bayer Leverkusen->Bayer_Giants_Leverkusen->2->Bayer_04_Leverkusen
# 400859: Partizan Belgrade->KK_Partizan->2->FK_Partizan
# 400863: Sevilla->CB_Sevilla->2->Sevilla_FC
# ...
# All Errors mentions:
# 405678: VICTORIA->Victorian_Bushrangers->2->Victoria_(Australia)
# 405680: Australia->Australia->2->Australia_national_cricket_team
# 405681: Australia->Australia->2->Australia_national_cricket_team
# 405683: Victoria->Victorian_Bushrangers->2->Victoria_(Australia)
# 405686: Victoria->Victorian_Bushrangers->2->Victoria_(Australia)
# 405704: Victoria->Victorian_Bushrangers->2->Victoria_(Australia)
# Correct Mentions (sports teams):
#
#
# Doc ID: 1206 SOCCER
# Total errors: 1    total mentions: 30
# Total errors (sports teams): 0    total mentions (sports teams):3
# All Errors mentions:
# 401890: Italians->Italy_national_football_team->2->Italy
# Correct Mentions (sports teams):
# 401864: AC Milan->A.C._Milan
# 401887: Milan->A.C._Milan
# 401888: Rosenborg->Rosenborg_BK
#
#
# Doc ID: 1217 INTERVIEW-ZYWIEC
# Total errors: 2    total mentions: 29
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402278: Heineken->Heineken_Pilsener->2->Heineken_International
# 402283: Heineken->Heineken_Pilsener->2->Heineken_International
# Correct Mentions (sports teams):
#
#
# Doc ID: 1184 BADMINTON
# Total errors: 3    total mentions: 52
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401231: WORLD GRAND PRIX->World_Badminton_Grand_Prix->3->World_Grand_Prix_(darts)
# 401233: World Grand Prix->World_Badminton_Grand_Prix->3->World_Grand_Prix_(darts)
# 401263: Taiwan->Taiwan->2->Republic_of_China
# Correct Mentions (sports teams):
#
#
# Doc ID: 1189 NBA
# Total errors: 22    total mentions: 52
# Total errors (sports teams): 15    total mentions (sports teams):41
# All Errors mentions:
# 401410: NEW YORK->New_York->4->New_York_City
# 401412: ATLANTIC->Atlantic_Division_(NBA)->2->Atlantic_Records
# 401414: NEW YORK->New_York_Knicks->2->New_York_City
# 401416: WASHINGTON->Washington_Wizards->2->Washington_Capitals
# 401417: PHILADELPHIA->Philadelphia_76ers->3->Philadelphia_Phillies
# 401419: NEW JERSEY->New_Jersey_Nets->3->New_Jersey_Devils
# 401420: CHICAGO->Chicago_Bulls->4->Chicago_White_Sox
# 401421: DETROIT->Detroit_Pistons->2->Detroit_Tigers
# 401422: CLEVELAND->Cleveland_Cavaliers->3->Cleveland_Indians
# 401423: ATLANTA->Atlanta_Hawks->2->Atlanta_Braves
# 401424: CHARLOTTE->New_Orleans_Hornets->3->Charlotte_Bobcats
# 401430: MINNESOTA->Minnesota_Timberwolves->3->Minnesota_Twins
# 401434: VANCOUVER->Memphis_Grizzlies->4->Vancouver_Canucks
# 401435: PACIFIC->Pacific_Division_(NBA)->3->Pacific_Coast_League
# 401436: SEATTLE->Seattle_SuperSonics->2->Seattle_Mariners
# 401443: NEW JERSEY->New_Jersey_Nets->3->New_Jersey_Devils
# 401445: CLEVELAND->Cleveland_Cavaliers->3->Cleveland_Indians
# 401446: DETROIT->Detroit_Pistons->2->Detroit_Tigers
# 401447: NEW YORK->New_York_Knicks->2->New_York_City
# 401451: VANCOUVER->Memphis_Grizzlies->4->Vancouver_Canucks
# 401453: MINNESOTA->Minnesota_Timberwolves->3->Minnesota_Twins
# 401455: CHARLOTTE->New_Orleans_Hornets->3->Charlotte_Bobcats
# Correct Mentions (sports teams):
# 401413: MIAMI->Miami_Heat
# 401415: ORLANDO->Orlando_Magic
# 401418: BOSTON->Boston_Celtics
# 401425: MILWAUKEE->Milwaukee_Bucks
# 401426: INDIANA->Indiana_Pacers
# 401427: TORONTO->Toronto_Raptors
# 401428: HOUSTON->Houston_Rockets
# 401429: UTAH->Utah_Jazz
# 401431: DALLAS->Dallas_Mavericks
# 401432: DENVER->Denver_Nuggets
# 401437: LA LAKERS->Los_Angeles_Lakers
# 401438: PORTLAND->Portland_Trail_Blazers
# 401439: LA CLIPPERS->Los_Angeles_Clippers
# 401440: GOLDEN STATE->Golden_State_Warriors
# 401441: SACRAMENTO->Sacramento_Kings
# 401442: PHOENIX->Phoenix_Suns
# 401444: BOSTON->Boston_Celtics
# 401448: MIAMI->Miami_Heat
# 401449: PHOENIX->Phoenix_Suns
# 401450: SACRAMENTO->Sacramento_Kings
# 401454: UTAH->Utah_Jazz
# 401456: PORTLAND->Portland_Trail_Blazers
# 401457: INDIANA->Indiana_Pacers
# 401458: GOLDEN STATE->Golden_State_Warriors
# 401459: ORLANDO->Orlando_Magic
# 401460: LA LAKERS->Los_Angeles_Lakers
#
#
# Doc ID: 1391 SOCCER
# Total errors: 1    total mentions: 25
# Total errors (sports teams): 0    total mentions (sports teams):13
# All Errors mentions:
# 406051: UEFA Cup->1996–97_UEFA_Cup->7->UEFA_Europa_League
# Correct Mentions (sports teams):
# 406029: PSV->PSV_Eindhoven
# 406030: VOLENDAM->FC_Volendam
# 406037: PSV Eindhoven->PSV_Eindhoven
# 406038: Volendam->FC_Volendam
# 406043: PSV->PSV_Eindhoven
# 406044: Volendam->FC_Volendam
# 406045: Feyenoord->Feyenoord
# 406046: Ajax Amsterdam->AFC_Ajax
# 406047: PSV->PSV_Eindhoven
# 406048: Ajax->AFC_Ajax
# 406050: Feyenoord->Feyenoord
# 406052: Tenerife->CD_Tenerife
# 406053: De Graafschap Doetinchem->De_Graafschap
#
#
# Doc ID: 1323 Frankfurt
# Total errors: 2    total mentions: 4
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404042: Frankfurt->Frankfurt_Stock_Exchange->8->Frankfurt_am_Main
# 404044: Frankfurt->Frankfurt_Stock_Exchange->8->Frankfurt_am_Main
# Correct Mentions (sports teams):
#
#
# Doc ID: 1367 RUGBY
# Total errors: 4    total mentions: 20
# Total errors (sports teams): 1    total mentions (sports teams):4
# All Errors mentions:
# 405232: England->United_Kingdom->10->England
# 405241: New South Wales->New_South_Wales_rugby_league_team->2->New_South_Wales
# 405245: England->United_Kingdom->10->England
# 405246: England->United_Kingdom->10->England
# Correct Mentions (sports teams):
# 405234: Wallaby->Australia_national_rugby_union_team
# 405236: Saracens->Saracens_F.C.
# 405242: Wallaby->Australia_national_rugby_union_team
#
#
# Doc ID: 1238 Wall
# Total errors: 3    total mentions: 41
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402521: Wall Street->New_York_Stock_Exchange->2->Wall_Street
# 402527: Wall Street->New_York_Stock_Exchange->2->Wall_Street
# 402567: Mexico->Mexico_City->3->Mexico
# Correct Mentions (sports teams):
#
#
# Doc ID: 1199 SOCCER
# Total errors: 1    total mentions: 20
# Total errors (sports teams): 0    total mentions (sports teams):8
# All Errors mentions:
# 401671: Reich->Burkhard_Reich->10->Nazi_Germany
# Correct Mentions (sports teams):
# 401663: Bayer Leverkusen->Bayer_04_Leverkusen
# 401666: Werder Bremen->SV_Werder_Bremen
# 401668: 1860 Munich->TSV_1860_München
# 401670: Karlsruhe->Karlsruher_SC
# 401674: Freiburg->SC_Freiburg
# 401675: Schalke->FC_Schalke_04
# 401660: Bochum->VfL_Bochum
# 401677: Hansa Rostock->F.C._Hansa_Rostock
#
#
# Doc ID: 1356 CRICKET
# Total errors: 6    total mentions: 30
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 404865: South Africa->South_Africa_national_cricket_team->2->South_Africa
# 404867: India->India_national_cricket_team->2->India
# 404868: England->England_cricket_team->2->England
# 404874: South African->South_Africa_national_cricket_team->2->South_Africa
# 404876: England->England_cricket_team->2->England
# 404879: England->England_cricket_team->2->England
# Correct Mentions (sports teams):
#
#
# Doc ID: 1379 CRICKET
# Total errors: 1    total mentions: 13
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 405707: Australia->Australia->2->Australia_national_cricket_team
# Correct Mentions (sports teams):
#
#
# Doc ID: 1297 London
# Total errors: 1    total mentions: 13
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 403628: Newcastle->Newcastle_upon_Tyne->2->Newcastle,_New_South_Wales
# Correct Mentions (sports teams):
#
#
# Doc ID: 1167 SOCCER
# Total errors: 8    total mentions: 16
# Total errors (sports teams): 3    total mentions (sports teams):8
# All Errors mentions:
# 400682: ASIAN CUP->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 400684: United Arab Emirates->United_Arab_Emirates->2->United_Arab_Emirates_national_football_team
# 400685: Asian Cup->AFC_Asian_Cup->2->2007_AFC_Asian_Cup
# 400686: Japan->Japan_national_football_team->2->Japan
# 400688: Japan->Japan_national_football_team->2->Japan
# 400693: China->China_PR_national_football_team->4->People's_Republic_of_China
# 400698: Japan->Japan_national_football_team->2->Japan
# 400700: China->China_PR_national_football_team->4->People's_Republic_of_China
# Correct Mentions (sports teams):
# 400687: Syria->Syria_national_football_team
# 400691: Syria->Syria_national_football_team
# 400694: Uzbekistan->Uzbekistan_national_football_team
# 400697: Uzbekistan->Uzbekistan_national_football_team
# 400699: Syria->Syria_national_football_team
#
#
# Doc ID: 1393 SOCCER
# Total errors: 7    total mentions: 27
# Total errors (sports teams): 3    total mentions (sports teams):4
# All Errors mentions:
# 406085: IRISHMAN->Republic_of_Ireland->2->Ireland
# 406089: Englishman->English_people->2->England
# 406100: Ireland->Republic_of_Ireland_national_football_team->3->Republic_of_Ireland
# 406101: Ireland->Republic_of_Ireland_national_football_team->3->Republic_of_Ireland
# 406105: Irish->Republic_of_Ireland_national_football_team->5->Republic_of_Ireland
# 406106: England->England_national_football_team->2->England
# 406108: England->England_national_football_team->2->England
# Correct Mentions (sports teams):
# 406096: Republic of Ireland->Republic_of_Ireland_national_football_team
#
#
# Doc ID: 1384 NBA
# Total errors: 4    total mentions: 20
# Total errors (sports teams): 3    total mentions (sports teams):14
# All Errors mentions:
# 405887: Cleveland->Cleveland_Indians->2->Cleveland_Cavaliers
# 405888: New York->New_York_Knicks->3->New_York_City
# 405893: SAN ANTONIO->San_Antonio_Spurs->2->San_Antonio_Silver_Stars
# 405895: Minnesota->Minnesota_Timberwolves->2->Minnesota
# Correct Mentions (sports teams):
# 405891: SACRAMENTO->Sacramento_Kings
# 405894: UTAH->Utah_Jazz
# 405896: PORTLAND->Portland_Trail_Blazers
# 405898: Indiana->Indiana_Pacers
# 405899: GOLDEN STATE->Golden_State_Warriors
# 405900: LA LAKERS->Los_Angeles_Lakers
# 405901: Orlando->Orlando_Magic
# 405885: BOSTON->Boston_Celtics
# 405886: DETROIT->Detroit_Pistons
# 405889: MIAMI->Miami_Heat
# 405890: Phoenix->Phoenix_Suns
#
#
# Doc ID: 1361 ALPINE
# Total errors: 3    total mentions: 6
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 405080: World Cup->FIS_Alpine_Ski_World_Cup->2->FIFA_World_Cup
# 405082: World Cup->FIS_Alpine_Ski_World_Cup->2->FIFA_World_Cup
# 405083: World Cup->FIS_Alpine_Ski_World_Cup->2->FIFA_World_Cup
# Correct Mentions (sports teams):
#
#
# Doc ID: 1368 SOCCER
# Total errors: 6    total mentions: 36
# Total errors (sports teams): 1    total mentions (sports teams):14
# All Errors mentions:
# 405255: Sturridge->Dean_Sturridge->2->Daniel_Sturridge
# 405261: Branch->Michael_Branch->7->Graham_Branch
# 405263: Coventry->Coventry_City_F.C.->3->Coventry
# 405264: Whelan->Noel_Whelan->4->Ronnie_Whelan
# 405276: Leeds->Leeds_United_A.F.C.->3->Leeds
# 405281: Melville->Andy_Melville->18->Long_Island_Rough_Riders_(W-League)
# Correct Mentions (sports teams):
# 405251: Arsenal->Arsenal_F.C.
# 405254: Derby->Derby_County_F.C.
# 405257: Chelsea->Chelsea_F.C.
# 405260: Everton->Everton_F.C.
# 405265: Tottenham->Tottenham_Hotspur_F.C.
# 405268: Leicester->Leicester_City_F.C.
# 405270: Blackburn->Blackburn_Rovers_F.C.
# 405272: Liverpool->Liverpool_F.C.
# 405273: Sheffield Wednesday->Sheffield_Wednesday_F.C.
# 405275: Middlesbrough->Middlesbrough_F.C.
# 405277: Southampton->Southampton_F.C.
# 405280: Sunderland->Sunderland_A.F.C.
# 405282: Wimbledon->Wimbledon_F.C.
#
#
# Doc ID: 1214 RADIO
# Total errors: 2    total mentions: 12
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 402152: Oradea->Oradea_International_Airport->3->Oradea
# 402153: Sibiu->Sibiu_International_Airport->3->Sibiu
# Correct Mentions (sports teams):
#
#
# Doc ID: 1372 SOCCER
# Total errors: 2    total mentions: 41
# Total errors (sports teams): 2    total mentions (sports teams):36
# All Errors mentions:
# 405460: Dundee->Dundee_United_F.C.->2->Dundee_F.C.
# 405484: Whitehill->Whitehill_Welfare_F.C.->2->Cat_Whitehill
# Correct Mentions (sports teams):
# 405450: Dunfermline->Dunfermline_Athletic_F.C.
# 405451: Aberdeen->Aberdeen_F.C.
# 405452: Hearts->Heart_of_Midlothian_F.C.
# 405453: Raith->Raith_Rovers_F.C.
# 405454: Kilmarnock->Kilmarnock_F.C.
# 405455: Dundee United->Dundee_United_F.C.
# 405456: Motherwell->Motherwell_F.C.
# 405457: Celtic->Celtic_F.C.
# 405458: Rangers->Rangers_F.C.
# 405459: Hibernian->Hibernian_F.C.
# 405461: Falkirk->Falkirk_F.C.
# 405462: Greenock Morton->Greenock_Morton_F.C.
# 405463: St Johnstone->St._Johnstone_F.C.
# 405464: Airdrieonians->Airdrieonians_F.C.
# 405465: Clydebank->Clydebank_F.C.
# 405466: East Fife->East_Fife_F.C.
# 405468: Stirling->Stirling_Albion_F.C.
# 405469: St Mirren->St._Mirren_F.C.
# 405470: Livingston->Livingston_F.C.
# 405471: Stenhousemuir->Stenhousemuir_F.C.
# 405472: Stranraer->Stranraer_F.C.
# 405473: Brechin->Brechin_City_F.C.
# 405474: Ross County->Ross_County_F.C.
# 405475: Montrose->Montrose_F.C.
# 405476: Forfar->Forfar_Athletic_F.C.
# 405477: Alloa->Alloa_Athletic_F.C.
# 405478: Inverness Thistle->Inverness_Thistle_F.C.
# 405481: Alloa->Alloa_Athletic_F.C.
# 405482: Hawick->Hawick_RFC
# 405483: Elgin City->Elgin_City_F.C.
# 405485: Albion->West_Bromwich_Albion_F.C.
# 405486: Forfar->Forfar_Athletic_F.C.
# 405487: Huntly->Huntly_F.C.
# 405488: Clyde->Clyde_F.C.
#
#
# Doc ID: 1185 SOCCER
# Total errors: 2    total mentions: 5
# Total errors (sports teams): 0    total mentions (sports teams):0
# All Errors mentions:
# 401298: National stadium->National_stadium->3->Olympic_Stadium_(Tokyo)
# 401302: Zaire->Democratic_Republic_of_the_Congo->2->Congo_DR_national_football_team
# Correct Mentions (sports teams):
#
#
# Doc ID: 1190 NFL
# Total errors: 24    total mentions: 57
# Total errors (sports teams): 23    total mentions (sports teams):50
# All Errors mentions:
# 401462: NEW YORK->New_York->2->New_York_City
# 401466: BUFFALO->Buffalo_Bills->3->Buffalo_Sabres
# 401471: HOUSTON->Houston_Texans->2->Houston_Astros
# 401473: CINCINNATI->Cincinnati_Bengals->2->Cincinnati_Reds
# 401474: BALTIMORE->Baltimore_Ravens->3->Baltimore_Orioles
# 401476: KANSAS CITY->Kansas_City_Chiefs->3->Kansas_City,_Missouri
# 401477: SAN DIEGO->San_Diego_Chargers->2->San_Diego_Padres
# 401478: OAKLAND->Oakland_Raiders->2->Oakland_Athletics
# 401486: MINNESOTA->Minnesota_Vikings->3->Minnesota
# 401488: DETROIT->Detroit_Lions->4->Detroit_Tigers
# 401490: SAN FRANCISCO->San_Francisco_49ers->2->San_Francisco_Giants
# 401493: ATLANTA->Atlanta_Falcons->2->Atlanta_Braves
# 401497: BALTIMORE->Baltimore_Ravens->3->Baltimore_Orioles
# 401498: CINCINNATI->Cincinnati_Bengals->2->Cincinnati_Reds
# 401499: DENVER->Denver_Broncos->2->Denver_Nuggets
# 401502: HOUSTON->Tennessee_Titans->5->Houston_Astros
# 401505: ATLANTA->Atlanta_Falcons->2->Atlanta_Braves
# 401507: SAN DIEGO->San_Diego_Chargers->2->San_Diego_Padres
# 401515: BUFFALO->Buffalo_Bills->3->Buffalo_Sabres
# 401518: SAN FRANCISCO->San_Francisco_49ers->2->San_Francisco_Giants
# 401519: MINNESOTA->Minnesota_Vikings->3->Minnesota
# 401520: DETROIT->Detroit_Lions->4->Detroit_Tigers
# 401521: KANSAS CITY->Kansas_City_Chiefs->3->Kansas_City,_Missouri
# 401522: OAKLAND->Oakland_Raiders->2->Oakland_Athletics
# Correct Mentions (sports teams):
# 401465: NEW ENGLAND->New_England_Patriots
# 401467: INDIANAPOLIS->Indianapolis_Colts
# 401468: MIAMI->Miami_Dolphins
# 401469: NY JETS->New_York_Jets
# 401472: JACKSONVILLE->Jacksonville_Jaguars
# 401479: SEATTLE->Seattle_Seahawks
# 401480: DALLAS->Dallas_Cowboys
# 401481: WASHINGTON->Washington_Redskins
# 401482: PHILADELPHIA->Philadelphia_Eagles
# 401483: ARIZONA->Arizona_Cardinals
# 401484: NY GIANTS->New_York_Giants
# 401489: TAMPA BAY->Tampa_Bay_Buccaneers
# 401491: CAROLINA->Carolina_Panthers
# 401494: NEW ORLEANS->New_Orleans_Saints
# 401501: JACKSONVILLE->Jacksonville_Jaguars
# 401503: NY GIANTS->New_York_Giants
# 401504: MIAMI->Miami_Dolphins
# 401506: NEW ORLEANS->New_Orleans_Saints
# 401508: PITTSBURGH->Pittsburgh_Steelers
# 401509: WASHINGTON->Washington_Redskins
# 401510: TAMPA BAY->Tampa_Bay_Buccaneers
# 401511: DALLAS->Dallas_Cowboys
# 401512: ARIZONA->Arizona_Cardinals
# 401513: NY JETS->New_York_Jets
# 401514: NEW ENGLAND->New_England_Patriots
# 401516: SEATTLE->Seattle_Seahawks
# 401517: CAROLINA->Carolina_Panthers
#
#
# Doc ID: 1191 NFL
# Total errors: 2    total mentions: 5
# Total errors (sports teams): 1    total mentions (sports teams):2
# All Errors mentions:
# 401524: NEW YORK->New_York->2->New_York_City
# 401528: Philadelphia->Philadelphia_Eagles->2->Philadelphia
# Correct Mentions (sports teams):
# 401527: INDIANAPOLIS->Indianapolis_Colts

# %%
total_sports = 0
# total_err_sports = 0
# total_correct_sports = 0
for x, y in doc_teams_all_dict.items():
    total_sports += len(y)
    print(x)
#     doc_teams_all_dict[x].append(men_id)
# Out:
# 1199 SOCCER
# 1208 SOCCER
# 1209 BASKETBALL
# 1373 SOCCER
# 1191 NFL
# 1196 SOCCER
# 1167 SOCCER
# 1164 RUGBY
# 1369 SOCCER
# 1198 SOCCER
# 1370 SOCCER
# 1205 SOCCER
# 1364 SOCCER
# 1371 SOCCER
# 1170 SOCCER
# 1176 SOCCER
# 1380 SOCCER
# 1390 SOCCER
# 1195 SOCCER
# 1194 SOCCER
# 1169 SOCCER
# 1201 SOCCER
# 1366 SOCCER
# 1165 SOCCER
# 1172 BASKETBALL
# 1163 SOCCER
# 1385 NHL
# 1368 SOCCER
# 1202 SOCCER
# 1171 SOCCER
# 1389 SOCCER
# 1173 RUGBY
# 1392 SOCCER
# 1204 SOCCER
# 1386 NHL
# 1362 SOCCER
# 1206 SOCCER
# 1374 RUGBY
# 1365 RUGBY
# 1367 RUGBY
# 1207 GUNMEN
# 1375 RUGBY
# 1188 NFL
# 1190 NFL
# 1383 NBA
# 1384 NBA
# 1382 SOCCER
# 1391 SOCCER
# 1175 SOCCER
# 1377 SOCCER
# 1381 SOCCER
# 1186 NHL
# 1189 NBA
# 1187 NHL
# 1197 SOCCER
# 1393 SOCCER
# 1387 NHL
# 1372 SOCCER
# 1193 SOCCER
# 1363 SOCCER
# 1251 Russia
# 1357 FREESTYLE
# 1326 British
# 1239 Russ
# 1263 Chile
# 1168 CRICKET
# 1347 GOLF
# 1327 Court
# 1192 NCAA
# 1348 ALPINE
# 1285 Half
# 1226 Major
# 1179 CRICKET
# 1349 ALPINE
# 1264 Indonesia
# 1216 POLAND
# 1351 NORDIC
# 1227 Electronic
# 1272 Texas
# 1180 CRICKET
# 1330 NZ
# 1300 OPEC
# 1274 BALANCE
# 1301 Relations
# 1228 RTRS
# 1331 RTRS
# 1267 Burmese
# 1302 Two
# 1289 Spain
# 1359 BADMINTON
# 1268 Union
# 1277 Iowa-S
# 1229 Cricket
# 1290 Mussolini
# 1303 PLO
# 1315 Italian
# 1352 ALPINE
# 1344 ALPINE
# 1316 Denmark
# 1210 SQUASH
# 1177 CRICKET
# 1317 Moslem
# 1232 New
# 1258 Mexico
# 1334 Chinese
# 1166 FREESTYLE
# 1182 CRICKET
# 1246 Five
# 1212 GUNMEN
# 1318 Belgian
# 1183 CRICKET
# 1304 Turkey
# 1234 Clean
# 1305 Three
# 1235 Dirty
# 1178 CRICKET
# 1294 Hindu
# 1354 SKIING-CHINESE
# 1378 CRICKET
# 1217 INTERVIEW-ZYWIEC
# 1184 BADMINTON
# 1323 Frankfurt
# 1238 Wall
# 1356 CRICKET
# 1379 CRICKET
# 1297 London
# 1213 HAVEL
# 1361 ALPINE
# 1214 RADIO
# 1185 SOCCER

# %%
for key, val in wrong_results.items():
    q_id = literal_eval(res[key][0])[0]
    print(literal_eval(res[key+np.argmax(val)][0])[1])
    break
# Out:
# John_Lewis_(department_store)

# %%
from ast import literal_eval
import os
import re

doc_err_dict = defaultdict(list)
doc_men_cnt_dict = defaultdict(int)
doc_g_ent_rank_dict = defaultdict(int)

re_train_errs_list = []

def escape_entity(entity):
    return str.encode(entity).decode('unicode-escape')

for key, val in wrong_results.items():
    re_train_errs_list.append(d_test[key: key + len(val),])

# %%
re_train_errs_list = np.array([y for x in re_train_errs_list for y in x])

# %%
re_train_errs_list
# Out:
# array([[  3.95657000e+05,   5.38699841e-03,   2.27000000e+02,
#           9.66352165e-01,   1.44129634e-05,   1.22903721e+01,
#           2.41088505e+01,   0.00000000e+00,   2.21415951e+01,
#           4.17763426e+01,   1.69897000e+00,   4.82183793e-02,
#           1.17646963e-01,   1.26847481e-02,   1.59468097e-02,
#           4.91472388e-02,   1.00000000e+00],
#        [  3.95657000e+05,   9.66352165e-01,   2.27000000e+02,
#           9.66352165e-01,   1.75960339e-03,   7.72787276e+00,
#           1.60356614e+01,   0.00000000e+00,   9.14542201e+00,
#           1.73143251e+01,   1.09691001e+00,   6.05353448e-03,
#           1.04339988e-02,   1.68593449e-03,   2.97329727e-03,
#           3.56879173e-02,   0.00000000e+00]])

# %%
dtest_re = trans_data(re_train_errs_list)
# Out:
# [[  5.38699841e-03   2.27000000e+02   9.66352165e-01 ...,   1.26847481e-02
#     1.59468097e-02   4.91472388e-02]
#  [  9.66352165e-01   2.27000000e+02   9.66352165e-01 ...,   1.68593449e-03
#     2.97329727e-03   3.56879173e-02]
#  [  6.05688430e-03   2.27000000e+02   9.66352165e-01 ...,   5.64931261e-03
#     1.02734407e-02   6.30971696e-02]
#  ...,
#  [  3.85208026e-04   1.03000000e+02   7.35362113e-01 ...,   9.47476211e-03
#     5.50338912e-02   1.66723449e-01]
#  [  3.85208026e-04   1.03000000e+02   7.35362113e-01 ...,   1.30768280e-02
#     1.07783010e-02   8.24229005e-02]
#  [  3.85208026e-04   1.03000000e+02   7.35362113e-01 ...,   2.41756367e-02
#     8.38351525e-02   2.13256234e-01]]
# [ 1.  0.  0. ...,  0.  0.  0.]
# [50 50  3 50 50 50 42  2  2 14  2 50  2 50 50  6  6 23 50 42  2 50 50 50 50
#  50  2  3  2 12 50 50 50 50 50 50 44  8 50 17 50 50 14  8 50  2 50  7 50 50
#  25  5 25  7  2 50  4 28 50 24 50  2  2 50  7 48 28 50 50 50 50 42 50  4  8
#  50 50 50 50  4 10 50 17 24 19 50  4 50  5 20  5  4 50 50 50 10 50 50 50 50
#  50 20 50 50 50 50 50 50 50 50 50 19  5 14 50 19 50 20 50 50 50 50 50 50 50
#  50 50 50  5 50 50 50 50 15 20 50 50 50 50 50 46 20 50 20 50 14 50 50 50 50
#  30 50 50 50 50 14 50 50 50  2 50 37 50 50  8 50 50 50 46  8  8 13  8 50 50
#  50 50  2 50  2  5 10 13 10 47  8 50 17 50 50 46 50 50 50 50 30 50 25 10 50
#   3  8  2 37  5 50 50 50  5 50 50  3 50 46 50 23  6 50  5 50  5  5 47 50  8
#  14 50 14 50 50 50 50 47 47 50 10  3 19  8 50 50 12  7  5 50 50 49 14 50 50
#  50 50 50 29 12 50  3  8 12  3 50  3 50 12 12  5 50 50 12 14 50  5 50  4 50
#  12 50 50 48 50 17 50 50 50 40 50 50 50 50 50 50 23  8 50 50 13 50  3  6 50
#   5 50 50 28 50 23  5 23 49 50 50 23  2 50 50 50  3 17 50 17  4 50  6 50 50
#  50 50 10 50 24 50 10 50 50 50 50  5 50 28 50 50 30 50 50 50  4 37 50 17 50
#  50 50 50 50  4 50 20 14  7 23 50  9 28 50 50 50 50 50 50  5 50 50 50  3 33
#  20 50 50 50 38 50 10  2 50 50 50 50  8  8  8  8 50 11  2  5 50 50 11 50 17
#  50  5 50 50 50  4 11 50 50 50 50  9 50 50 50 39  6  6 50  6 50  6 11 50  6
#   6  6 50 11  6 50 50 50 50 50 50 50 50 50 50 50 50]

# %%
num_round=150
param = {'max_depth':6, 'eta':0.01, 'silent':0, 'objective':'rank:pairwise', 'min_child_weight':0.01}
model_new = xgb.train(param, dtest_re, num_round, xgb_model=model)

# %%
preds = model.predict(dtest)
a = evalerror_detail_log(preds, dtest, 4791)
print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
# Out:
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767

# %%
preds = model_new.predict(dtest)
a = evalerror_detail_log(preds, dtest, 4791)
print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
# Out:
# correct_num: 4372, precision: 0.9247038917089678, recall: 0.9125443539970779, f1: 0.9185838848618552

# %%
preds = model.predict(dtest_b)
a = evalerror_detail_log(preds, dtest_b, 4485)
print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
# Out:
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711

# %%
preds = model_new.predict(dtest_b)
a = evalerror_detail_log(preds, dtest_b, 4485)
print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
# Out:
# correct_num: 3884, precision: 0.8735942420152947, recall: 0.8659977703455964, f1: 0.8697794199977606

# %%
n_estimators = range(10, 200, 20)
max_depth = [2, 4, 6]
for x in n_estimators:
    num_round = x
    for dep in max_depth:
        param = {'max_depth':dep, 'eta':0.01, 'silent':0, 'objective':'rank:pairwise', 'min_child_weight':0.01}
        model_new = xgb.train(param, dtest_re, num_round, xgb_model=model)
        preds = model_new.predict(dtest)
        a = evalerror_detail_log(preds, dtest, 4791)
        print("correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767")
        print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
        print('\n')
        print("correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711")
        preds = model_new.predict(dtest_b)
        a = evalerror_detail_log(preds, dtest_b, 4485)
        print("correct_num: {}, precision: {}, recall: {}, f1: {}".format(a[0], a[1], a[2], a[3]))
        print('________________________________________________________')
# Out:
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4294, precision: 0.9082064297800339, recall: 0.8962638280108537, f1: 0.9021956087824351
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3950, precision: 0.8884390463337831, recall: 0.8807134894091416, f1: 0.8845593998432427
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4290, precision: 0.9073604060913706, recall: 0.8954289292423294, f1: 0.9013551843681058
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3954, precision: 0.8893387314439946, recall: 0.8816053511705686, f1: 0.8854551561975141
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4292, precision: 0.9077834179357022, recall: 0.8958463786265916, f1: 0.9017753965752704
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3951, precision: 0.888663967611336, recall: 0.8809364548494983, f1: 0.8847833389318106
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4300, precision: 0.9094754653130288, recall: 0.8975161761636402, f1: 0.9034562454039289
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3962, precision: 0.8911381016644174, recall: 0.8833890746934225, f1: 0.8872466689060576
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4297, precision: 0.9088409475465313, recall: 0.8968900020872469, f1: 0.902825927093182
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3976, precision: 0.8942869995501574, recall: 0.886510590858417, f1: 0.8903818161460083
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4298, precision: 0.9090524534686971, recall: 0.897098726779378, f1: 0.9030360331967644
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3977, precision: 0.8945119208277102, recall: 0.8867335562987737, f1: 0.8906057552345762
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4315, precision: 0.9126480541455161, recall: 0.9006470465456063, f1: 0.9066078369576637
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3963, precision: 0.8913630229419703, recall: 0.8836120401337793, f1: 0.8874706079946256
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4308, precision: 0.9111675126903553, recall: 0.8991859737006888, f1: 0.9051370942325875
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3976, precision: 0.8942869995501574, recall: 0.886510590858417, f1: 0.8903818161460083
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4316, precision: 0.9128595600676819, recall: 0.9008557712377374, f1: 0.9068179430612459
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3985, precision: 0.8963112910481331, recall: 0.8885172798216276, f1: 0.8923972679431194
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4320, precision: 0.9137055837563451, recall: 0.9016906700062617, f1: 0.9076583674755752
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3959, precision: 0.8904633378317589, recall: 0.8827201783723523, f1: 0.8865748516403538
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4312, precision: 0.9120135363790186, recall: 0.9000208724692131, f1: 0.9059775186469166
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3903, precision: 0.8778677462887989, recall: 0.8702341137123746, f1: 0.874034262680551
# ________________________________________________________
# correct_num: 4286, precision: 0.9065143824027073, recall: 0.894594030473805, f1: 0.9005147599537767
# correct_num: 4354, precision: 0.9208967851099831, recall: 0.9087873095387184, f1: 0.9148019749973736
#
#
# correct_num: 3946, precision: 0.8875393612235718, recall: 0.8798216276477147, f1: 0.8836636434889711
# correct_num: 3862, precision: 0.8686459739091318, recall: 0.861092530657748, f1: 0.8648527600492665
# ________________________________________________________

# %%
total_sports, total_err_sports, total_correct_sports
# Out:
# (966, 192, 624)

# %%
get_men_tokens_redis('aida_conll','1239 Russ')
# Out:
# {'': [4],
#  '1996 - 12 - 06': [7],
#  'a. curts cooke': [12],
#  'chief': [15],
#  'co inc': [9],
#  'company': [23],
#  'consulting': [21],
#  'continue': [25],
#  'cooke': [19],
#  'director': [27],
#  'effective july 1 , 1997': [18],
#  'friday': [11],
#  'gift': [29],
#  'july': [3],
#  'july 1 , 1998': [24],
#  'maker': [30],
#  'n.j.': [6],
#  'oakland': [5],
#  'officer': [17],
#  'operating': [16],
#  'president': [1, 14],
#  'provide': [20],
#  'retire': [2, 13],
#  'russ berrie': [0, 8],
#  'say': [10, 31],
#  'serve': [26],
#  'service': [22],
#  'toy': [28]}

# %%
'john lewis partnership'.upper()
# Out:
# 'JOHN LEWIS PARTNERSHIP'

# %%
import spacy

print(spacy.__version__)
# Out:
# 2.0.2

# %%
nlp = spacy.load('en_core_web_md')

# %%
doc_text = '''Russ Berrie president to retire in July.
 OAKLAND, N.J. 1996-12-06
 Russ Berrie and Co Inc said on Friday that A. Curts Cooke will retire as president and chief operating officer effective July 1, 1997.
 Cooke will provide consulting services to the company through July 1, 1998, and will continue to serve as a director, the toy and gift maker said.
 '''

# %%
doc = nlp(doc_text)

# %%
from collections import defaultdict
filter_ent_types = ('DATE', 'TIME', 'PERCENT', 'MONEY', 'QUANTITY', 'ORDINAL', 'CARDINAL')
x = defaultdict(list)
for ent in doc.ents:
    if ent.label_ not in filter_ent_types:
        x[ent.text].append(ent.start_char)
    print(ent, ent.label_)
# Out:
# Russ Berrie PERSON
# July DATE
# OAKLAND ORG
# N.J. GPE
# 1996 DATE
# Russ Berrie PERSON
# Co Inc ORG
# Friday DATE
# A. Curts Cooke PERSON
# July 1, 1997 DATE
# Cooke PERSON
# July 1, 1998 DATE

# %%
x
# Out:
# defaultdict(list,
#             {'A. Curts Cooke': [111],
#              'Co Inc': [84],
#              'Cooke': [204],
#              'N.J.': [51],
#              'OAKLAND': [42],
#              'Russ Berrie': [0, 68]})

# %%
a = np.array([0.3,  0.3,  0. ,  0.3,  0.3,  0. ])

# %%
b = np.array([True, True, False, True, True, False], dtype=np.bool)

# %%
a = np.array([[2,  0.1, 1], [1,  0.3, 1],  [1 ,  0.4, 0], [3, 1,1], [3, 2, 0]])
b = np.array([[1,  0, 1],  [1 ,  4, 0],  [2,  1, 1], [3, 0.1,1], [3, 0.2, 0]])

# %%
def combine_features(original_feas, new_features):
    men_id_feas_dict = defaultdict(list)
    for fea in new_features:
        men_id_feas_dict[fea[0]].append(fea)
    comb_feas = None
    pre_men_id = 0
#     print(men_id_feas_dict)
    for fea_idx, fea in enumerate(original_feas):
#         print(fea_idx)
        if pre_men_id == fea[0]:
            continue
        else:
            pre_men_id = fea[0]
            fea_size = len(men_id_feas_dict[fea[0]])
#             print(pre_men_id)
#             print(fea_size)
#             print(original_feas[fea_idx: fea_idx + fea_size, :-1])
#             s = men_id_feas_dict[fea[0]]
#             print(np.array(s)[:, 1:])
            res = np.append(original_feas[fea_idx: fea_idx + fea_size, :-1], np.array(men_id_feas_dict[fea[0]])[:, 1:], axis=1)
            comb_feas = np.concatenate((comb_feas, res), axis=0) if comb_feas is not None else res
    return comb_feas

# %%
combine_features(a, b)
# Out:
# array([[ 2. ,  0.1,  1. ,  1. ],
#        [ 1. ,  0.3,  0. ,  1. ],
#        [ 1. ,  0.4,  4. ,  0. ],
#        [ 3. ,  1. ,  0.1,  1. ],
#        [ 3. ,  2. ,  0.2,  0. ]])

# %%
import numpy as np
a = np.array([[2,  0.1, 1], [1,  0.3, 1],  [1 ,  0.4, 0], [3, 1,1], [3, 2, 0]])
b = np.array([[1,  0, 1],  [1 ,  4, 0],  [2,  1, 1], [3, 0.1,1], [3, 0.2, 0]])

# %%
np.concatenate((a, b), axis=1)
# Out:
# array([[ 2. ,  0.1,  1. ,  1. ,  0. ,  1. ],
#        [ 1. ,  0.3,  1. ,  1. ,  4. ,  0. ],
#        [ 1. ,  0.4,  0. ,  2. ,  1. ,  1. ],
#        [ 3. ,  1. ,  1. ,  3. ,  0.1,  1. ],
#        [ 3. ,  2. ,  0. ,  3. ,  0.2,  0. ]])

# %%
import spacy
from spacy import displacy

ex = {'text': 'But Google is starting from behind.',
       'ents': [{'start': 4, 'end': 10, 'label': 'ORG'}],
       'title': None}
html = displacy.render(ex, style='ent', manual=True)

# %%
print(html)
# Out:
# <div class="entities" style="line-height: 2.5">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is starting from behind.</div>

# %%
import re
doc = '[[Beij,. "(ing]] is a [[city]].'

# %%
for m in re.finditer(r'\[\[([^\]])*\]\]', doc):
    print(m.start(), m.end())
# Out:
# 0 16
# 22 30

# %%
len(doc.split())
# Out:
# 5

# %%
ss = conn.hmget('men-ner-stanford-aida_conll', '1163 SOCCER')[0]

# %%
ss = json.loads(ss)

# %%
ss.keys()
# Out:
# dict_keys(['nader jokhadar', 'bitar', 'kuwait', 'nadim ladki', 'world cup', 'shu kamo', 'oleg shatskiku', 'hiroshige yanagimoto', 'asian games', 'fifa', 'syrian', 'uzbek', 'hassan abbas', 'united arab emirates', 'uzbekistan', 'chinese', 'indonesia', 'china', 'soviet', 'salem bitar', 'al-ain', 'takuya takagi', 'japan', 'south korea', 'syrians', 'igor shkvyrin', 'syria', 'asian cup'])

# %%
import spacy

nlp = spacy.load('en_core_web_md')

# %%
s = nlp('Emirates')

# %%
for t in s:
    print(t.lemma_)
# Out:
# emirate

# %%
import inflect
p = inflect.engine()

# %%
p.singular_noun('United Arab Emirates')
# Out:
# 'syrian'
