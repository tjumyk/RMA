# %%
#!/usr/bin/python
import numpy as np
import scipy.sparse
import pickle
import xgboost as xgb
import csv
from collections import defaultdict
import redis
import json
import time
import sklearn.utils
### simple example
# load file from text file, also binary buffer generated by xgboost
# dtrain = xgb.DMatrix('./demo/rank_aida/mq2008.train')

# dtest = xgb.DMatrix('./demo/rank_aida/mq2008.test')

# %%
conn = redis.Redis(password='unswkg', host='43.240.97.73', port=8379, decode_responses=True)

def get_feature_results(exp_id, d_t, data_source='aida_conll'):
    fea_res = conn.lrange('result:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t), 0, -1)
    fea_vecs = [json.loads(res) for res in fea_res]
    return fea_vecs

# %%
def get_dataset_info(exp_id, d_t, data_source='aida_conll', can_size=50):
    valid_mens_size = conn.scard('valid_qry_ids:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    no_g_can_info_size = conn.scard('no_g_candidate_info:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    missed_g_candidate_size = conn.scard('missed_g_candidate:::::' + str(exp_id) + ':::::' + data_source + 
                                         ':::::' + str(d_t) + ':::::' + str(can_size))
    no_candidate_size = conn.scard('no_candidate:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t))
    return valid_mens_size, no_candidate_size, no_g_can_info_size, missed_g_candidate_size

# %%
def fetch_all_features(exp_id, data_type, data_source='aida_conll'):
    res_feas = get_feature_results(exp_id, data_type, data_source)
    res_feas_ids = [[res[0].strip('(').split(', ')[0]] + res[1:-1] + [res[-1]] for res in res_feas]
    res_feas_ids = np.array(res_feas_ids, dtype=np.float64)
    return res_feas_ids

# %%
def trans_data(data):
    d_np = data[:, 1:-1]
    print(d_np)
    d_labels = data[:, -1]
    print(d_labels)
    idxs = np.where(d_labels == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_labels)) - idxs
    print(d_groups)
    xgb_data = xgb.DMatrix(data=d_np, label=d_labels)
    xgb_data.set_group(d_groups)
    return xgb_data

# %%
def evalerror(preds, dt, d_tal_size):
    d_l = dt.get_label()
    idxs = np.where(d_l == 1)[0]
    d_groups = np.append(np.delete(idxs, 0), len(d_l)) - idxs
    matched_ids = []
    q_id = 0
    for x in d_groups:
        pre_res = preds[q_id: x + q_id]
        if(preds[q_id] == max(pre_res)):
            if len([x for x in pre_res if x == preds[q_id]]) == 1:
                matched_ids.append(q_id)
        q_id += x
    precision = float(len(matched_ids)) / len(d_groups)
    recall = float(len(matched_ids)) / d_tal_size
    f1 = 2 * precision * recall / (precision + recall)
    return len(matched_ids), precision, recall, f1

# %%
def build_doc_fea_vecs_dict(data, doc_men_dict):
    doc_fea_vecs_dict = {}
    st = time.time()
    for key, val in doc_men_dict.items():
        ix = np.isin(data[:, 0], val)
        doc_fea_vecs_dict[key] = data[np.where(ix)[0],]
    print(time.time() - st)
    return doc_fea_vecs_dict

def data_sampling_boostrapping(data, doc_men_dict, doc_fea_vecs_dict, n_bootstraps=3):
    datas = []
#     doc_fea_vecs_dict = {}
#     st = time.time()
#     i = 0
#     for key, val in doc_men_dict.items():
#         i += 1
#         if not i %1000:
#             print(i)
# #         print(val)
#         ix = np.isin(data[:, 0], val)
# #         print(np.where(ix)[0])
#         doc_fea_vecs_dict[key] = data[np.where(ix)[0],]
#     print(time.time() - st)
    
    doc_ids_list = list(doc_fea_vecs_dict.keys())
    
    print(len(doc_ids_list))
    for n_bootstrap in range(0, n_bootstraps):
        print("Doing bootstrapping for the {} time...".format(n_bootstrap + 1))
        n_bootstrap = 0    
        doc_id_smps_training = sklearn.utils.resample(doc_ids_list, random_state=n_bootstrap)
        print("Distinct training doc size {}...".format(len(set(doc_id_smps_training))))
        print("Constructing training mentions...")
        st = time.time()
        mens_training = np.concatenate([doc_fea_vecs_dict[x] for x in doc_id_smps_training])
        print("Finished Constructing training mentions, time cost {}...".format(time.time() - st))
        doc_id_smps_testing = [x for x in doc_ids_list if x not in doc_id_smps_training]
        print("Distinct testing doc size {}...".format(len(set(doc_id_smps_testing))))
        st = time.time()
        mens_testing = np.concatenate([doc_fea_vecs_dict[x] for x in doc_id_smps_testing])
        print("Finished Constructing testing mentions, time cost {}...".format(time.time() - st))
        datas.append((mens_training, mens_testing))
    return datas
#     men_ids_training = [x for xs in doc_id_smps_training for x in doc_men_dict[xs]]
#     print("Training mentions size {}...".format(len(men_ids_training)))

#     men_ids_testing = [x for xs in doc_id_smps_testing for x in doc_men_dict[xs]]
#     print("Testing mentions size {}...".format(len(men_ids_testing)))

#     men_ids_training = np.array(men_ids_training, dtype=np.float64)
#     men_ids_testing = np.array(men_ids_testing, dtype=np.float64)
#         for idx in men_ids_training:
#     print("Constructing training mentions...")
#         s = []
#     st = time.time()
#     a = 0
#     for id_, idx in enumerate(men_ids_training):
#         if not id_ %1000:
#             print(time.time() - st)
#             st = time.time()
#             print(a)
#         a += len(np.where(data[:, 0] == idx)[0])
#     print(a)
#     return
#         for x in 
#         for id_, idx in enumerate(men_ids_training):
#             if not id_ % 1000:
#                 print(time.time() - st)
#                 st = time.time()
#             for x in np.where(data[:, 0] == idx)[0]:
#                 s.append(data[x,])
#     mens_training = np.array([data[x, ] for idx in men_ids_training for x in np.where(data[:, 0] == idx)[0]])
#     print("Finished Constructing training mentions, time cost {}...".format(time.time() - st))
#     print("Constructing testing mentions...")
#     st = time.time()
#     mens_testing = np.array([data[x, ] for idx in men_ids_testing for x in np.where(data[:, 0] == idx)[0]])
#     print("Finished Constructing testing mentions, time cost {}...".format(time.time() - st))
    datas.append((mens_training, mens_testing))
    return mens_training, mens_testing

# %%
def read_doc_men_dict_file(dict_filename):
    doc_men_dict = defaultdict(list)
    with open(dict_filename, 'r') as f:
        csv_reader = csv.reader(f)
        for k, v in csv_reader:
            doc_men_dict[k].append(float(v))
    return doc_men_dict

# %%
d_train = fetch_all_features('basic_feature_phrases_tf_idf_entropy_reduced_fea', 'train', 'wiki_uiuc')

# %%
valid_mens_size, no_candidate_size, no_g_can_info_size, missed_g_candidate_size = get_dataset_info('basic_feature_phrases_tf_idf_entropy_reduced_fea', 'test', 'wiki_uiuc')

# %%
dict_filename = './wiki_uiuc_training_doc_id_men_id.csv'

# %%
doc_men_dict = read_doc_men_dict_file(dict_filename)
doc_fea_vecs_dict = build_doc_fea_vecs_dict(d_train, doc_men_dict)
# Out:
# 408.1616179943085
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-2d39711d86d1> in <module>()
#       1 doc_men_dict = read_doc_men_dict_file(dict_filename)
#       2 doc_fea_vecs_dict = build_doc_fea_vecs_dict(d_train, doc_men_dict)
# ----> 3 d_train_resample, d_test_resample = data_sampling_boostrapping(d_train, doc_men_dict, doc_fea_vecs_dict)
#
# <ipython-input-46-7e2001877893> in data_sampling_boostrapping(data, doc_men_dict, doc_fea_vecs_dict, n_bootstraps)
#      29 #         print("Doing bootstrapping for the {} time...".format(n_bootstrap + 1))
#      30     n_bootstrap = 0
# ---> 31     doc_id_smps_training = sklearn.utils.resample(doc_ids_list, random_state=n_bootstrap)
#      32     print("Distinct training doc size {}...".format(len(set(doc_id_smps_training))))
#      33     print("Constructing training mentions...")
#
# NameError: name 'doc_ids_list' is not defined

# %%
d_train_resample, d_test_resample = data_sampling_boostrapping(d_train, doc_men_dict, doc_fea_vecs_dict)
# Out:
# 9938
# Distinct training doc size 6295...
# Constructing training mentions...
# Finished Constructing training mentions, time cost 0.13133621215820312...
# Distinct testing doc size 3643...
# Finished Constructing testing mentions, time cost 0.023510217666625977...

# %%
dtrain = trans_data(d_train_resample)
dtest = trans_data(d_test_resample)
# print(dtrain_g)
# print(dtest_g)
# Out:
# [[  4.34889436e-01   8.00000000e+00   4.34889436e-01 ...,   7.06169561e-04
#     8.95117505e-03   8.45491765e-02]
#  [  2.87469298e-01   8.00000000e+00   4.34889436e-01 ...,   1.66394036e-03
#     1.30014895e-02   1.06551622e-01]
#  [  1.03194103e-01   8.00000000e+00   4.34889436e-01 ...,   5.80435908e-03
#     3.69313494e-02   1.53816297e-01]
#  ...,
#  [  9.97191012e-01   2.00000000e+00   9.97191012e-01 ...,   2.13496451e-03
#     1.06748225e-02   6.26477541e-02]
#  [  2.80898879e-03   2.00000000e+00   9.97191012e-01 ...,   1.17589842e-03
#     1.17589842e-03   3.90625000e-02]
#  [  1.00000000e+00   1.00000000e+00   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# [ 1.  0.  0. ...,  1.  0.  1.]
# [8 1 2 ..., 1 2 1]
# [[  9.44444418e-01   2.00000000e+00   9.44444418e-01 ...,   2.57422606e-03
#     2.00789633e-02   1.86762442e-01]
#  [  5.55555560e-02   2.00000000e+00   9.44444418e-01 ...,   9.49621437e-04
#     2.37405359e-03   6.94006309e-02]
#  [  1.00000000e+00   1.00000000e+00   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  ...,
#  [  9.99999978e-03   3.00000000e+00   8.50000024e-01 ...,   3.71300587e-03
#     1.53758945e-02   6.22948444e-02]
#  [  1.00000000e+00   1.00000000e+00   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  1.00000000e+00   1.00000000e+00   1.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]]
# [ 1.  0.  1. ...,  0.  1.  1.]
# [2 1 2 ..., 3 1 1]

# %%
n_estimators = range(100, 5000, 400)
max_depth = [4, 6, 8, 10]

# %%
for x in n_estimators:
    num_round = x
    for dep in max_depth:
        param = {'max_depth':dep, 'eta':0.01, 'silent':0, 'objective':'rank:pairwise', 'min_child_weight':0.01}
        bst = xgb.train(param, dtrain, num_round)
        preds = bst.predict(dtrain)
        a = evalerror(preds, dtrain, 18541)
        print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, dep, a[0], a[1]))
        preds = bst.predict(dtest)
        a = evalerror(preds, dtest, 4485)
        print("n_estimators: {}, max_depth: {}, acc_testing: {}, corr_num: {}".format(num_round, dep, a[0], a[1]))
        print("---------------------------------")
# Out:
# n_estimators: 100, max_depth: 4, acc_training: 0.7711558168383582, corr_num: 14298
# n_estimators: 100, max_depth: 4, acc_testing: 0.7163879598662207, corr_num: 3213
# ---------------------------------
# n_estimators: 100, max_depth: 6, acc_training: 0.8203441022598565, corr_num: 15210
# n_estimators: 100, max_depth: 6, acc_testing: 0.7868450390189521, corr_num: 3529
# ---------------------------------
# n_estimators: 100, max_depth: 8, acc_training: 0.879564209050213, corr_num: 16308
# n_estimators: 100, max_depth: 8, acc_testing: 0.8133779264214047, corr_num: 3648
# ---------------------------------
# n_estimators: 100, max_depth: 10, acc_training: 0.9209859230893696, corr_num: 17076
# n_estimators: 100, max_depth: 10, acc_testing: 0.8251950947603122, corr_num: 3701
# ---------------------------------
# n_estimators: 500, max_depth: 4, acc_training: 0.8502238282724772, corr_num: 15764
# n_estimators: 500, max_depth: 4, acc_testing: 0.8013377926421404, corr_num: 3594
# ---------------------------------
# n_estimators: 500, max_depth: 6, acc_training: 0.8929399708753574, corr_num: 16556
# n_estimators: 500, max_depth: 6, acc_testing: 0.8401337792642141, corr_num: 3768
# ---------------------------------
# n_estimators: 500, max_depth: 8, acc_training: 0.9354403753842835, corr_num: 17344
# n_estimators: 500, max_depth: 8, acc_testing: 0.8479375696767001, corr_num: 3803
# ---------------------------------
# n_estimators: 500, max_depth: 10, acc_training: 0.9666684644841163, corr_num: 17923
# n_estimators: 500, max_depth: 10, acc_testing: 0.8416945373467113, corr_num: 3775
# ---------------------------------
# n_estimators: 900, max_depth: 4, acc_training: 0.8740089531308991, corr_num: 16205
# n_estimators: 900, max_depth: 4, acc_testing: 0.8323299888517279, corr_num: 3733
# ---------------------------------
# n_estimators: 900, max_depth: 6, acc_training: 0.9174262445391295, corr_num: 17010
# n_estimators: 900, max_depth: 6, acc_testing: 0.8552954292084727, corr_num: 3836
# ---------------------------------
# n_estimators: 900, max_depth: 8, acc_training: 0.960519928806429, corr_num: 17809
# n_estimators: 900, max_depth: 8, acc_testing: 0.862876254180602, corr_num: 3870
# ---------------------------------
# n_estimators: 900, max_depth: 10, acc_training: 0.9795048810743757, corr_num: 18161
# n_estimators: 900, max_depth: 10, acc_testing: 0.8564102564102564, corr_num: 3841
# ---------------------------------
# n_estimators: 1300, max_depth: 4, acc_training: 0.8929399708753574, corr_num: 16556
# n_estimators: 1300, max_depth: 4, acc_testing: 0.8535117056856187, corr_num: 3828
# ---------------------------------
# n_estimators: 1300, max_depth: 6, acc_training: 0.9357100480017259, corr_num: 17349
# n_estimators: 1300, max_depth: 6, acc_testing: 0.862876254180602, corr_num: 3870
# ---------------------------------
# n_estimators: 1300, max_depth: 8, acc_training: 0.9720619168329648, corr_num: 18023
# n_estimators: 1300, max_depth: 8, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 1300, max_depth: 10, acc_training: 0.9815004584434497, corr_num: 18198
# n_estimators: 1300, max_depth: 10, acc_testing: 0.8597547380156075, corr_num: 3856
# ---------------------------------
# n_estimators: 1700, max_depth: 4, acc_training: 0.8996817863114179, corr_num: 16681
# n_estimators: 1700, max_depth: 4, acc_testing: 0.8615384615384616, corr_num: 3864
# ---------------------------------
# n_estimators: 1700, max_depth: 6, acc_training: 0.9457418693705841, corr_num: 17535
# n_estimators: 1700, max_depth: 6, acc_testing: 0.869788182831661, corr_num: 3901
# ---------------------------------
# n_estimators: 1700, max_depth: 8, acc_training: 0.9771856965643708, corr_num: 18118
# n_estimators: 1700, max_depth: 8, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 1700, max_depth: 10, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 1700, max_depth: 10, acc_testing: 0.8617614269788183, corr_num: 3865
# ---------------------------------
# n_estimators: 2100, max_depth: 4, acc_training: 0.9047516315193356, corr_num: 16775
# n_estimators: 2100, max_depth: 4, acc_testing: 0.8633221850613155, corr_num: 3872
# ---------------------------------
# n_estimators: 2100, max_depth: 6, acc_training: 0.9528072919475756, corr_num: 17666
# n_estimators: 2100, max_depth: 6, acc_testing: 0.8740245261984393, corr_num: 3920
# ---------------------------------
# n_estimators: 2100, max_depth: 8, acc_training: 0.9790194703629793, corr_num: 18152
# n_estimators: 2100, max_depth: 8, acc_testing: 0.8724637681159421, corr_num: 3913
# ---------------------------------
# n_estimators: 2100, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2100, max_depth: 10, acc_testing: 0.8653288740245262, corr_num: 3881
# ---------------------------------
# n_estimators: 2500, max_depth: 4, acc_training: 0.9131654171835392, corr_num: 16931
# n_estimators: 2500, max_depth: 4, acc_testing: 0.8662207357859532, corr_num: 3885
# ---------------------------------
# n_estimators: 2500, max_depth: 6, acc_training: 0.9581468097729356, corr_num: 17765
# n_estimators: 2500, max_depth: 6, acc_testing: 0.8749163879598663, corr_num: 3924
# ---------------------------------
# n_estimators: 2500, max_depth: 8, acc_training: 0.9806375060676339, corr_num: 18182
# n_estimators: 2500, max_depth: 8, acc_testing: 0.8735785953177257, corr_num: 3918
# ---------------------------------
# n_estimators: 2500, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2500, max_depth: 10, acc_testing: 0.8655518394648829, corr_num: 3882
# ---------------------------------
# n_estimators: 2900, max_depth: 4, acc_training: 0.9192060838142495, corr_num: 17043
# n_estimators: 2900, max_depth: 4, acc_testing: 0.8691192865105909, corr_num: 3898
# ---------------------------------
# n_estimators: 2900, max_depth: 6, acc_training: 0.962299768081549, corr_num: 17842
# n_estimators: 2900, max_depth: 6, acc_testing: 0.8778149386845039, corr_num: 3937
# ---------------------------------
# n_estimators: 2900, max_depth: 8, acc_training: 0.9812307858260072, corr_num: 18193
# n_estimators: 2900, max_depth: 8, acc_testing: 0.8735785953177257, corr_num: 3918
# ---------------------------------
# n_estimators: 2900, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 2900, max_depth: 10, acc_testing: 0.8651059085841695, corr_num: 3880
# ---------------------------------
# n_estimators: 3300, max_depth: 4, acc_training: 0.9238444528342592, corr_num: 17129
# n_estimators: 3300, max_depth: 4, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 3300, max_depth: 6, acc_training: 0.9659673156787659, corr_num: 17910
# n_estimators: 3300, max_depth: 6, acc_testing: 0.8784838350055741, corr_num: 3940
# ---------------------------------
# n_estimators: 3300, max_depth: 8, acc_training: 0.9815004584434497, corr_num: 18198
# n_estimators: 3300, max_depth: 8, acc_testing: 0.8722408026755852, corr_num: 3912
# ---------------------------------
# n_estimators: 3300, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 3300, max_depth: 10, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 3700, max_depth: 4, acc_training: 0.9272423278140338, corr_num: 17192
# n_estimators: 3700, max_depth: 4, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 3700, max_depth: 6, acc_training: 0.9683943692357478, corr_num: 17955
# n_estimators: 3700, max_depth: 6, acc_testing: 0.8791527313266444, corr_num: 3943
# ---------------------------------
# n_estimators: 3700, max_depth: 8, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 3700, max_depth: 8, acc_testing: 0.8711259754738016, corr_num: 3907
# ---------------------------------
# n_estimators: 3700, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 3700, max_depth: 10, acc_testing: 0.8675585284280937, corr_num: 3891
# ---------------------------------
# n_estimators: 4100, max_depth: 4, acc_training: 0.9311256135052047, corr_num: 17264
# n_estimators: 4100, max_depth: 4, acc_testing: 0.8740245261984393, corr_num: 3920
# ---------------------------------
# n_estimators: 4100, max_depth: 6, acc_training: 0.9709832263631951, corr_num: 18003
# n_estimators: 4100, max_depth: 6, acc_testing: 0.8804905239687848, corr_num: 3949
# ---------------------------------
# n_estimators: 4100, max_depth: 8, acc_training: 0.9817161965374036, corr_num: 18202
# n_estimators: 4100, max_depth: 8, acc_testing: 0.8709030100334448, corr_num: 3906
# ---------------------------------
# n_estimators: 4100, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4100, max_depth: 10, acc_testing: 0.8668896321070234, corr_num: 3888
# ---------------------------------
# n_estimators: 4500, max_depth: 4, acc_training: 0.9352246372903296, corr_num: 17340
# n_estimators: 4500, max_depth: 4, acc_testing: 0.8746934225195094, corr_num: 3923
# ---------------------------------
# n_estimators: 4500, max_depth: 6, acc_training: 0.972763065638315, corr_num: 18036
# n_estimators: 4500, max_depth: 6, acc_testing: 0.8793756967670011, corr_num: 3944
# ---------------------------------
# n_estimators: 4500, max_depth: 8, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4500, max_depth: 8, acc_testing: 0.8706800445930881, corr_num: 3905
# ---------------------------------
# n_estimators: 4500, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4500, max_depth: 10, acc_testing: 0.867335562987737, corr_num: 3890
# ---------------------------------
# n_estimators: 4900, max_depth: 4, acc_training: 0.9377595598942884, corr_num: 17387
# n_estimators: 4900, max_depth: 4, acc_testing: 0.8764771460423635, corr_num: 3931
# ---------------------------------
# n_estimators: 4900, max_depth: 6, acc_training: 0.9743811013429696, corr_num: 18066
# n_estimators: 4900, max_depth: 6, acc_testing: 0.8798216276477147, corr_num: 3946
# ---------------------------------
# n_estimators: 4900, max_depth: 8, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4900, max_depth: 8, acc_testing: 0.8711259754738016, corr_num: 3907
# ---------------------------------
# n_estimators: 4900, max_depth: 10, acc_training: 0.9817701310608921, corr_num: 18203
# n_estimators: 4900, max_depth: 10, acc_testing: 0.8677814938684504, corr_num: 3892
# ---------------------------------

# %%
num_round=4900
param = {'max_depth':6, 'eta':0.01, 'silent':0, 'objective':'rank:pairwise', 'min_child_weight':0.01}
model = xgb.train(param, dtrain, num_round)

# %%
d_train = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'train', 'aida_conll')
d_test = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'test', 'aida_conll')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-5ceeb41cfef4> in <module>()
# ----> 1 d_train = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'train', 'aida_conll')
#       2 d_test = fetch_all_features('basic_feature_phrases_tf_idf_entropy_conll_new', 'test', 'aida_conll')
#
# <ipython-input-43-803a048d867b> in fetch_all_features(exp_id, data_type, data_source)
#       1 def fetch_all_features(exp_id, data_type, data_source='aida_conll'):
# ----> 2     res_feas = get_feature_results(exp_id, data_type, data_source)
#       3     res_feas_ids = [[res[0].strip('(').split(', ')[0]] + res[1:-1] + [res[-1]] for res in res_feas]
#       4     res_feas_ids = np.array(res_feas_ids, dtype=np.float64)
#       5     return res_feas_ids
#
# <ipython-input-41-0e474eb411b2> in get_feature_results(exp_id, d_t, data_source)
#       3 def get_feature_results(exp_id, d_t, data_source='aida_conll'):
#       4     fea_res = conn.lrange('result:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t), 0, -1)
# ----> 5     fea_vecs = [json.loads(res) for res in fea_res]
#       6     return fea_vecs
#
# <ipython-input-41-0e474eb411b2> in <listcomp>(.0)
#       3 def get_feature_results(exp_id, d_t, data_source='aida_conll'):
#       4     fea_res = conn.lrange('result:::::' + str(exp_id) + ':::::' + data_source + ':::::' + str(d_t), 0, -1)
# ----> 5     fea_vecs = [json.loads(res) for res in fea_res]
#       6     return fea_vecs
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /import/sigmod01/1/scratch/z5109197/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     343         return obj
#     344
# --> 345     def raw_decode(self, s, idx=0):
#     346         """Decode a JSON document from ``s`` (a ``str`` beginning with
#     347         a JSON document) and return a 2-tuple of the Python
#
# KeyboardInterrupt:

# %%
model_name = './no_poly_4900_6.mdl'
# with open(model_name, 'wb') as f:
#     pickle.dump(model, f)
model = pickle.load(open(model_name, 'rb'))
preds = model.predict(dtrain)
a = evalerror(preds, dtrain, 18541)
print("n_estimators: {}, max_depth: {}, acc_training: {}, corr_num: {}".format(num_round, 6, a[0], a[1]))
preds = model.predict(dtest)
a = evalerror(preds, dtest, 148)
print("n_estimators: {}, max_depth: {}, acc_testing: {}, corr_num: {}".format(num_round, 6, a[0], a[1]))
print("---------------------------------")
# Out:
# n_estimators: 4900, max_depth: 6, acc_training: 0.9743811013429696, corr_num: 18066
# n_estimators: 4900, max_depth: 6, acc_testing: 0.4864864864864865, corr_num: 72
# ---------------------------------

# %%
import sklearn.utils

# %%
wiki_idxs_all = range(0, 9938)

# %%
training_idx = sklearn.utils.resample(wiki_idxs_all)

# %%
test_idx = range(0, 5)

# %%
w = [1, 2,3,4,5]

sum(w[:0])
# Out:
# 0

# %%
d_test = fetch_all_features('basic_feature_phrases_tf_idf_entropy_reduced_fea', 'test', 'kore')

# %%
print(set(a))
# Out:
# {1.0, 2.0, 7.0, 8.0, 9.0, 10.0, 11.0, 12.0, 13.0, 16.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 29.0, 31.0, 32.0, 33.0, 34.0, 35.0, 37.0, 38.0, 39.0, 40.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 62.0, 64.0, 65.0, 68.0, 69.0, 71.0, 72.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 81.0, 84.0, 85.0, 86.0, 87.0, 88.0, 90.0, 91.0, 92.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0, 100.0, 101.0, 102.0, 104.0, 105.0, 106.0, 110.0, 112.0, 113.0, 114.0, 115.0, 117.0, 118.0, 119.0, 120.0, 121.0, 122.0, 123.0, 124.0, 125.0, 126.0, 127.0, 128.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 141.0, 142.0, 143.0, 144.0, 145.0, 146.0, 147.0}

# %%
[x for x in range(0, 2)]
# Out:
# [0, 1]

# %%
a = [(1,2), (1, 3)]

# %%
from collections import defaultdict
d = defaultdict(list)
for k, v in a:
    d[k].append(v)

# %%
import csv
file = '/Users/dzs/Desktop/doc_id2men_id.csv'

with open(file, 'r') as f:
    csv_reader = csv.reader(f)
    for item in csv_reader:
        print(item)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-155-fa94dd53a6fa> in <module>()
#       2 file = '/Users/dzs/Desktop/doc_id2men_id.csv'
#       3
# ----> 4 with open(file, 'r') as f:
#       5     csv_reader = csv.reader(f)
#       6     for item in csv_reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/dzs/Desktop/doc_id2men_id.csv'

# %%
import numpy
a = numpy.empty(shape=(5,2))

# %%
a = [1,2,3,4]
# Out:
# array([[  4.32801506e-321,   4.33295571e-321],
#        [  4.33789637e-321,   4.34283703e-321],
#        [  4.34777768e-321,   4.35271834e-321],
#        [  4.35765900e-321,   4.36259965e-321],
#        [  4.36754031e-321,   4.37248097e-321]])

# %%
np.__version__
# Out:
# '1.11.3'

# %%
a = np.array([[1,2], [5, 6]])
b = np.array([[3,4]])
c= [a, b]

# %%
c
# Out:
# [array([[1, 2],
#         [5, 6]]), array([[3, 4]])]

# %%
np.concatenate(c, axis=0)
# Out:
# array([[1, 2],
#        [5, 6],
#        [3, 4]])
